# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="internet_graph"
method_="mip"
dim_=300
id_=2
ver_="fmin"

# %%
form_="fminc2"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c2 = table
#mip_internet_c2

#print(mip_internet_c2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminmisetc2"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_misetc2 = table
#mip_internet_misetc2

#print(mip_internet_misetc2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminmisetc3"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_misetc3 = table
#mip_internet_misetc3

#print(mip_internet_misetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminmiset"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_miset = table
#mip_internet_miset

#print(mip_internet_miset[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmincutmisetc3"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_cutmisetc3 = table
#mip_internet_cutmisetc3

#print(mip_internet_cut_misetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmincutbmisetc3"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_cutbmisetc3 = table
#mip_internet_cutbmisetc3

#print(mip_internet_cutb_misetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
mip_merge = pd.DataFrame()

mip_merge = pd.merge(
    mip_internet_c2, mip_internet_misetc2,
    on=['vertice'], 
    suffixes=("", "_f"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_misetc3,
    on=['vertice'], 
    suffixes=("", "_g"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_miset,
    on=['vertice'], 
    suffixes=("", "_h"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_cutmisetc3,
    on=['vertice'], 
    suffixes=("", "_i"),
    )


mip_merge = pd.merge(
    mip_merge, mip_internet_cutbmisetc3,
    on=['vertice'], 
    suffixes=("", "_j"),
    )

mip_merge[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_f','gap_f','time_f','opt_f','tk_f','tmax_f',
    'bs_g','gap_g','time_g','opt_g','tk_g','tmax_g',
    'bs_h','gap_h','time_h','opt_h','tk_h','tmax_h',
    'bs_i','gap_i','time_i','opt_i','tk_i','tmax_i',
    'bs_j','gap_j','time_j','opt_j','tk_j','tmax_j',
    ]]
# Out:
#     vertice     bs  gap   time  opt  tk  tmax   bs_f  gap_f  time_f  ...  \
# 0         0  227.0  0.0  74.59  1.0 NaN   NaN  227.0    0.0   57.19  ...
# 1         1  227.0  0.0  40.69  1.0 NaN   NaN  227.0    0.0   36.19  ...
# 2         2  227.0  0.0  64.43  1.0 NaN   NaN  227.0    0.0   54.27  ...
# 3         3  227.0  0.0  48.45  1.0 NaN   NaN  227.0    0.0   37.01  ...
# 4         4  227.0  0.0  62.43  1.0 NaN   NaN  227.0    0.0   39.18  ...
# ..      ...    ...  ...    ...  ...  ..   ...    ...    ...     ...  ...
# 295     295    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.00  ...
# 296     296    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.00  ...
# 297     297    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.00  ...
# 298     298    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.00  ...
# 299     299    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.00  ...
#
#      time_i  opt_i  tk_i  tmax_i   bs_j  gap_j  time_j  opt_j  tk_j  tmax_j
# 0     96.11    1.0   NaN     NaN  227.0    0.0   90.23    1.0   NaN     NaN
# 1     37.22    1.0   NaN     NaN  227.0    0.0   33.60    1.0   NaN     NaN
# 2     90.74    1.0   NaN     NaN  227.0    0.0   83.13    1.0   NaN     NaN
# 3     35.81    1.0   NaN     NaN  227.0    0.0   32.36    1.0   NaN     NaN
# 4     22.36    1.0   NaN     NaN  227.0    0.0   19.52    1.0   NaN     NaN
# ..      ...    ...   ...     ...    ...    ...     ...    ...   ...     ...
# 295    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 296    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 297    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 298    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 299    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
#
# [300 rows x 37 columns]

# %%
mip_concat = pd.DataFrame()
mip_concat = pd.concat([mip_concat, mip_internet_c2.loc[300:300]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_misetc2.loc[300:300]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_misetc3.loc[300:300]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_miset.loc[300:300]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_cutmisetc3.loc[300:300]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_cutbmisetc3.loc[300:300]], ignore_index=True)
mip_concat
# Out:
#                      vertice       bb       bs  gap     time    nodes    opt  \
# 0           mip_fminc2_300_2  13941.0  13941.0  0.0  4046.62  17978.0  300.0
# 1      mip_fminmisetc2_300_2  13941.0  13941.0  0.0  3551.03   2166.0  300.0
# 2      mip_fminmisetc3_300_2  13941.0  13941.0  0.0  3397.10   2326.0  300.0
# 3        mip_fminmiset_300_2  12381.0  12381.0  0.0    12.68   2540.0  300.0
# 4   mip_fmincutmisetc3_300_2  13941.0  13941.0  0.0  7614.64   3959.0  300.0
# 5  mip_fmincutbmisetc3_300_2  13941.0  13941.0  0.0  7428.29   4151.0  300.0
#
#       tk    tmax
# 0  227.0  100.75
# 1  227.0   93.60
# 2  227.0  101.60
# 3  209.0    0.26
# 4  227.0  294.70
# 5  227.0  292.79

# %%
print(
mip_concat[[
    'vertice','bs','gap','time','opt','tk','tmax',
    ]].to_latex(index=False,float_format="%.1f")
)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
#                   vertice &      bs &  gap &   time &   opt &    tk &  tmax \\
# \midrule
#          mip\_fminc2\_300\_2 & 13941.0 &  0.0 & 4046.6 & 300.0 & 227.0 & 100.8 \\
#     mip\_fminmisetc2\_300\_2 & 13941.0 &  0.0 & 3551.0 & 300.0 & 227.0 &  93.6 \\
#     mip\_fminmisetc3\_300\_2 & 13941.0 &  0.0 & 3397.1 & 300.0 & 227.0 & 101.6 \\
#       mip\_fminmiset\_300\_2 & 12381.0 &  0.0 &   12.7 & 300.0 & 209.0 &   0.3 \\
#  mip\_fmincutmisetc3\_300\_2 & 13941.0 &  0.0 & 7614.6 & 300.0 & 227.0 & 294.7 \\
# mip\_fmincutbmisetc3\_300\_2 & 13941.0 &  0.0 & 7428.3 & 300.0 & 227.0 & 292.8 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_24792/1047115439.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   mip_concat[[
