# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="karate"
method_="mip"

# %%
form_="fminc2"

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_fminc2 = table
mip_karate_fminc2

#print(mip_karate_fmin[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#    vertice     bb     bs  gap  time  nodes   opt    tk  tmax
# 0        0   21.0   21.0  0.0  0.02    1.0   1.0   NaN   NaN
# 1        1   21.0   21.0  0.0  0.14    9.0   1.0   NaN   NaN
# 2        2   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 3        3    3.0    3.0  0.0  0.00    0.0   1.0   NaN   NaN
# 4        4    2.0    2.0  0.0  0.00    1.0   1.0   NaN   NaN
# 5        5    3.0    3.0  0.0  0.00    0.0   1.0   NaN   NaN
# 6        6    3.0    3.0  0.0  0.00    0.0   1.0   NaN   NaN
# 7        7    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 8        8   19.0   19.0  0.0  0.07    7.0   1.0   NaN   NaN
# 9        9   19.0   19.0  0.0  0.16    9.0   1.0   NaN   NaN
# 10      10    2.0    2.0  0.0  0.00    0.0   1.0   NaN   NaN
# 11      11    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 12      12    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 13      13   19.0   19.0  0.0  0.09    5.0   1.0   NaN   NaN
# 14      14    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 15      15    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 16      16    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 17      17    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 18      18    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 19      19   19.0   19.0  0.0  0.06    7.0   1.0   NaN   NaN
# 20      20    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 21      21    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 22      22    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 23      23   19.0   19.0  0.0  0.28    6.0   1.0   NaN   NaN
# 24      24   19.0   19.0  0.0  0.13   16.0   1.0   NaN   NaN
# 25      25   19.0   19.0  0.0  0.17   13.0   1.0   NaN   NaN
# 26      26    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 27      27   19.0   19.0  0.0  0.10    7.0   1.0   NaN   NaN
# 28      28   19.0   19.0  0.0  0.12    6.0   1.0   NaN   NaN
# 29      29    2.0    2.0  0.0  0.00    0.0   1.0   NaN   NaN
# 30      30   19.0   19.0  0.0  0.21   11.0   1.0   NaN   NaN
# 31      31   19.0   19.0  0.0  0.02    1.0   1.0   NaN   NaN
# 32      32   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 33      33   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 34     mip  335.0  335.0  0.0  1.60  102.0  34.0  21.0  0.28

# %%
form_="fminmiset"

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_fminmiset = table
mip_karate_fminmiset

#print(mip_karate_fminmisetn0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#    vertice     bb     bs  gap  time  nodes   opt    tk  tmax
# 0        0   20.0   20.0  0.0  0.01    1.0   1.0   NaN   NaN
# 1        1   20.0   20.0  0.0  0.03    1.0   1.0   NaN   NaN
# 2        2   18.0   18.0  0.0  0.01    1.0   1.0   NaN   NaN
# 3        3    3.0    3.0  0.0  0.00    0.0   1.0   NaN   NaN
# 4        4    2.0    2.0  0.0  0.00    0.0   1.0   NaN   NaN
# 5        5    3.0    3.0  0.0  0.00    0.0   1.0   NaN   NaN
# 6        6    3.0    3.0  0.0  0.00    0.0   1.0   NaN   NaN
# 7        7    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 8        8   18.0   18.0  0.0  0.01    1.0   1.0   NaN   NaN
# 9        9   18.0   18.0  0.0  0.05    1.0   1.0   NaN   NaN
# 10      10    2.0    2.0  0.0  0.00    0.0   1.0   NaN   NaN
# 11      11    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 12      12    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 13      13   18.0   18.0  0.0  0.06    7.0   1.0   NaN   NaN
# 14      14    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 15      15    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 16      16    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 17      17    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 18      18    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 19      19   18.0   18.0  0.0  0.03    5.0   1.0   NaN   NaN
# 20      20    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 21      21    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 22      22    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 23      23   18.0   18.0  0.0  0.05    1.0   1.0   NaN   NaN
# 24      24   19.0   19.0  0.0  0.05   10.0   1.0   NaN   NaN
# 25      25   19.0   19.0  0.0  0.05    7.0   1.0   NaN   NaN
# 26      26    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 27      27   18.0   18.0  0.0  0.05    3.0   1.0   NaN   NaN
# 28      28   18.0   18.0  0.0  0.03    1.0   1.0   NaN   NaN
# 29      29    2.0    2.0  0.0  0.00    0.0   1.0   NaN   NaN
# 30      30   18.0   18.0  0.0  0.04    3.0   1.0   NaN   NaN
# 31      31   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 32      32   18.0   18.0  0.0  0.00    1.0   1.0   NaN   NaN
# 33      33   18.0   18.0  0.0  0.00    1.0   1.0   NaN   NaN
# 34     mip  322.0  322.0  0.0  0.48   45.0  34.0  20.0  0.06

# %%
form_="fminmisetc2"

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_fminmisetc2 = table
mip_karate_fminmisetc2

#print(mip_karate_fminmiset[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#    vertice     bb     bs  gap  time  nodes   opt    tk  tmax
# 0        0   21.0   21.0  0.0  0.02    1.0   1.0   NaN   NaN
# 1        1   21.0   21.0  0.0  0.14    3.0   1.0   NaN   NaN
# 2        2   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 3        3    3.0    3.0  0.0  0.00    0.0   1.0   NaN   NaN
# 4        4    2.0    2.0  0.0  0.00    1.0   1.0   NaN   NaN
# 5        5    3.0    3.0  0.0  0.00    0.0   1.0   NaN   NaN
# 6        6    3.0    3.0  0.0  0.00    0.0   1.0   NaN   NaN
# 7        7    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 8        8   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 9        9   19.0   19.0  0.0  0.17    7.0   1.0   NaN   NaN
# 10      10    2.0    2.0  0.0  0.00    0.0   1.0   NaN   NaN
# 11      11    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 12      12    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 13      13   19.0   19.0  0.0  0.10    3.0   1.0   NaN   NaN
# 14      14    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 15      15    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 16      16    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 17      17    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 18      18    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 19      19   19.0   19.0  0.0  0.14    5.0   1.0   NaN   NaN
# 20      20    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 21      21    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 22      22    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 23      23   19.0   19.0  0.0  0.19    5.0   1.0   NaN   NaN
# 24      24   19.0   19.0  0.0  0.26    7.0   1.0   NaN   NaN
# 25      25   19.0   19.0  0.0  0.16    6.0   1.0   NaN   NaN
# 26      26    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 27      27   19.0   19.0  0.0  0.22    3.0   1.0   NaN   NaN
# 28      28   19.0   19.0  0.0  0.14    3.0   1.0   NaN   NaN
# 29      29    2.0    2.0  0.0  0.00    0.0   1.0   NaN   NaN
# 30      30   19.0   19.0  0.0  0.12    8.0   1.0   NaN   NaN
# 31      31   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 32      32   19.0   19.0  0.0  0.02    1.0   1.0   NaN   NaN
# 33      33   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 34     mip  335.0  335.0  0.0  1.72   57.0  34.0  21.0  0.26

# %%
form_="fminmisetc3"

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_fminmisetc3 = table
mip_karate_fminmisetc3

#print(mip_karate_fminmisetn1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#    vertice     bb     bs  gap  time  nodes   opt    tk  tmax
# 0        0   21.0   21.0  0.0  0.01    1.0   1.0   NaN   NaN
# 1        1   21.0   21.0  0.0  0.14    3.0   1.0   NaN   NaN
# 2        2   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 3        3    3.0    3.0  0.0  0.00    0.0   1.0   NaN   NaN
# 4        4    2.0    2.0  0.0  0.00    1.0   1.0   NaN   NaN
# 5        5    3.0    3.0  0.0  0.00    0.0   1.0   NaN   NaN
# 6        6    3.0    3.0  0.0  0.00    0.0   1.0   NaN   NaN
# 7        7    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 8        8   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 9        9   19.0   19.0  0.0  0.16    5.0   1.0   NaN   NaN
# 10      10    2.0    2.0  0.0  0.00    0.0   1.0   NaN   NaN
# 11      11    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 12      12    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 13      13   19.0   19.0  0.0  0.05    5.0   1.0   NaN   NaN
# 14      14    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 15      15    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 16      16    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 17      17    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 18      18    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 19      19   19.0   19.0  0.0  0.09    5.0   1.0   NaN   NaN
# 20      20    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 21      21    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 22      22    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 23      23   19.0   19.0  0.0  0.11    9.0   1.0   NaN   NaN
# 24      24   19.0   19.0  0.0  0.13    7.0   1.0   NaN   NaN
# 25      25   19.0   19.0  0.0  0.10    7.0   1.0   NaN   NaN
# 26      26    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 27      27   19.0   19.0  0.0  0.15    3.0   1.0   NaN   NaN
# 28      28   19.0   19.0  0.0  0.05    5.0   1.0   NaN   NaN
# 29      29    2.0    2.0  0.0  0.00    0.0   1.0   NaN   NaN
# 30      30   19.0   19.0  0.0  0.08    7.0   1.0   NaN   NaN
# 31      31   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 32      32   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 33      33   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 34     mip  335.0  335.0  0.0  1.12   63.0  34.0  21.0  0.16

# %%
form_="fmax"

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_fmax = table
mip_karate_fmax

#print(mip_karate_fmax[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#    vertice     bb     bs  gap  time  nodes   opt    tk  tmax
# 0        0   21.0   21.0  0.0  0.02    1.0   1.0   NaN   NaN
# 1        1   21.0   21.0  0.0  0.16   11.0   1.0   NaN   NaN
# 2        2   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 3        3    3.0    3.0  0.0  0.00    1.0   1.0   NaN   NaN
# 4        4    2.0    2.0  0.0  0.00    1.0   1.0   NaN   NaN
# 5        5    3.0    3.0  0.0  0.00    1.0   1.0   NaN   NaN
# 6        6    3.0    3.0  0.0  0.00    1.0   1.0   NaN   NaN
# 7        7    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 8        8   19.0   19.0  0.0  0.08    3.0   1.0   NaN   NaN
# 9        9   19.0   19.0  0.0  0.20   10.0   1.0   NaN   NaN
# 10      10    2.0    2.0  0.0  0.00    1.0   1.0   NaN   NaN
# 11      11    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 12      12    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 13      13   19.0   19.0  0.0  0.08    7.0   1.0   NaN   NaN
# 14      14    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 15      15    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 16      16    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 17      17    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 18      18    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 19      19   19.0   19.0  0.0  0.09    7.0   1.0   NaN   NaN
# 20      20    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 21      21    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 22      22    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 23      23   19.0   19.0  0.0  0.19    8.0   1.0   NaN   NaN
# 24      24   19.0   19.0  0.0  0.15   14.0   1.0   NaN   NaN
# 25      25   19.0   19.0  0.0  0.20   10.0   1.0   NaN   NaN
# 26      26    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 27      27   19.0   19.0  0.0  0.12    7.0   1.0   NaN   NaN
# 28      28   19.0   19.0  0.0  0.12    5.0   1.0   NaN   NaN
# 29      29    2.0    2.0  0.0  0.00    1.0   1.0   NaN   NaN
# 30      30   19.0   19.0  0.0  0.12    6.0   1.0   NaN   NaN
# 31      31   19.0   19.0  0.0  0.02    1.0   1.0   NaN   NaN
# 32      32   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 33      33   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 34     mip  335.0  335.0  0.0  1.58   99.0  34.0  21.0   0.2

# %%
form_="fmaxmisetn0"

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_fmaxmisetn0 = table
mip_karate_fmaxmisetn0

#print(mip_internet_fmaxmisetn0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#    vertice     bb     bs  gap  time  nodes   opt    tk  tmax
# 0        0   21.0   21.0  0.0  0.02    1.0   1.0   NaN   NaN
# 1        1   21.0   21.0  0.0  0.24    2.0   1.0   NaN   NaN
# 2        2   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 3        3    3.0    3.0  0.0  0.01    1.0   1.0   NaN   NaN
# 4        4    2.0    2.0  0.0  0.01    1.0   1.0   NaN   NaN
# 5        5    3.0    3.0  0.0  0.01    1.0   1.0   NaN   NaN
# 6        6    3.0    3.0  0.0  0.01    1.0   1.0   NaN   NaN
# 7        7    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 8        8   19.0   19.0  0.0  0.15    1.0   1.0   NaN   NaN
# 9        9   19.0   19.0  0.0  0.27    5.0   1.0   NaN   NaN
# 10      10    2.0    2.0  0.0  0.01    1.0   1.0   NaN   NaN
# 11      11    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 12      12    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 13      13   19.0   19.0  0.0  0.10    3.0   1.0   NaN   NaN
# 14      14    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 15      15    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 16      16    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 17      17    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 18      18    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 19      19   19.0   19.0  0.0  0.10    5.0   1.0   NaN   NaN
# 20      20    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 21      21    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 22      22    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 23      23   19.0   19.0  0.0  0.34    5.0   1.0   NaN   NaN
# 24      24   19.0   19.0  0.0  0.60    3.0   1.0   NaN   NaN
# 25      25   19.0   19.0  0.0  0.37    9.0   1.0   NaN   NaN
# 26      26    1.0    1.0  0.0  0.00    0.0   1.0   NaN   NaN
# 27      27   19.0   19.0  0.0  0.20    1.0   1.0   NaN   NaN
# 28      28   19.0   19.0  0.0  0.20    1.0   1.0   NaN   NaN
# 29      29    2.0    2.0  0.0  0.01    1.0   1.0   NaN   NaN
# 30      30   19.0   19.0  0.0  0.24    3.0   1.0   NaN   NaN
# 31      31   19.0   19.0  0.0  0.02    1.0   1.0   NaN   NaN
# 32      32   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 33      33   19.0   19.0  0.0  0.01    1.0   1.0   NaN   NaN
# 34     mip  335.0  335.0  0.0  2.94   49.0  34.0  21.0   0.6

# %%
result = pd.DataFrame()

result = pd.merge(
    mip_karate_fminc2, mip_karate_fminmiset,
    on=['vertice'], 
    suffixes=("", "_a"),
    )

result = pd.merge(
    result, mip_karate_fminmisetc2,
    on=['vertice'], 
    suffixes=("", "_b"),
    )

result = pd.merge(
    result, mip_karate_fminmisetc3,
    on=['vertice'], 
    suffixes=("", "_c"),
    )

# %%
result[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_a','gap_a','time_a','opt_a','tk_a','tmax_a',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c'
    ]]
# Out:
#    vertice     bs  gap  time   opt    tk  tmax   bs_a  gap_a  time_a  ...
# 0        0   21.0  0.0  0.02   1.0   NaN   NaN   20.0    0.0    0.01  ...  \
# 1        1   21.0  0.0  0.14   1.0   NaN   NaN   20.0    0.0    0.03  ...
# 2        2   19.0  0.0  0.01   1.0   NaN   NaN   18.0    0.0    0.01  ...
# 3        3    3.0  0.0  0.00   1.0   NaN   NaN    3.0    0.0    0.00  ...
# 4        4    2.0  0.0  0.00   1.0   NaN   NaN    2.0    0.0    0.00  ...
# 5        5    3.0  0.0  0.00   1.0   NaN   NaN    3.0    0.0    0.00  ...
# 6        6    3.0  0.0  0.00   1.0   NaN   NaN    3.0    0.0    0.00  ...
# 7        7    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.00  ...
# 8        8   19.0  0.0  0.07   1.0   NaN   NaN   18.0    0.0    0.01  ...
# 9        9   19.0  0.0  0.16   1.0   NaN   NaN   18.0    0.0    0.05  ...
# 10      10    2.0  0.0  0.00   1.0   NaN   NaN    2.0    0.0    0.00  ...
# 11      11    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.00  ...
# 12      12    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.00  ...
# 13      13   19.0  0.0  0.09   1.0   NaN   NaN   18.0    0.0    0.06  ...
# 14      14    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.00  ...
# 15      15    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.00  ...
# 16      16    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.00  ...
# 17      17    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.00  ...
# 18      18    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.00  ...
# 19      19   19.0  0.0  0.06   1.0   NaN   NaN   18.0    0.0    0.03  ...
# 20      20    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.00  ...
# 21      21    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.00  ...
# 22      22    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.00  ...
# 23      23   19.0  0.0  0.28   1.0   NaN   NaN   18.0    0.0    0.05  ...
# 24      24   19.0  0.0  0.13   1.0   NaN   NaN   19.0    0.0    0.05  ...
# 25      25   19.0  0.0  0.17   1.0   NaN   NaN   19.0    0.0    0.05  ...
# 26      26    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.00  ...
# 27      27   19.0  0.0  0.10   1.0   NaN   NaN   18.0    0.0    0.05  ...
# 28      28   19.0  0.0  0.12   1.0   NaN   NaN   18.0    0.0    0.03  ...
# 29      29    2.0  0.0  0.00   1.0   NaN   NaN    2.0    0.0    0.00  ...
# 30      30   19.0  0.0  0.21   1.0   NaN   NaN   18.0    0.0    0.04  ...
# 31      31   19.0  0.0  0.02   1.0   NaN   NaN   19.0    0.0    0.01  ...
# 32      32   19.0  0.0  0.01   1.0   NaN   NaN   18.0    0.0    0.00  ...
# 33      33   19.0  0.0  0.01   1.0   NaN   NaN   18.0    0.0    0.00  ...
# 34     mip  335.0  0.0  1.60  34.0  21.0  0.28  322.0    0.0    0.48  ...
#
#     time_b  opt_b  tk_b  tmax_b   bs_c  gap_c  time_c  opt_c  tk_c  tmax_c
# 0     0.02    1.0   NaN     NaN   21.0    0.0    0.01    1.0   NaN     NaN
# 1     0.14    1.0   NaN     NaN   21.0    0.0    0.14    1.0   NaN     NaN
# 2     0.01    1.0   NaN     NaN   19.0    0.0    0.01    1.0   NaN     NaN
# 3     0.00    1.0   NaN     NaN    3.0    0.0    0.00    1.0   NaN     NaN
# 4     0.00    1.0   NaN     NaN    2.0    0.0    0.00    1.0   NaN     NaN
# 5     0.00    1.0   NaN     NaN    3.0    0.0    0.00    1.0   NaN     NaN
# 6     0.00    1.0   NaN     NaN    3.0    0.0    0.00    1.0   NaN     NaN
# 7     0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 8     0.01    1.0   NaN     NaN   19.0    0.0    0.01    1.0   NaN     NaN
# 9     0.17    1.0   NaN     NaN   19.0    0.0    0.16    1.0   NaN     NaN
# 10    0.00    1.0   NaN     NaN    2.0    0.0    0.00    1.0   NaN     NaN
# 11    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 12    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 13    0.10    1.0   NaN     NaN   19.0    0.0    0.05    1.0   NaN     NaN
# 14    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 15    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 16    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 17    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 18    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 19    0.14    1.0   NaN     NaN   19.0    0.0    0.09    1.0   NaN     NaN
# 20    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 21    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 22    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 23    0.19    1.0   NaN     NaN   19.0    0.0    0.11    1.0   NaN     NaN
# 24    0.26    1.0   NaN     NaN   19.0    0.0    0.13    1.0   NaN     NaN
# 25    0.16    1.0   NaN     NaN   19.0    0.0    0.10    1.0   NaN     NaN
# 26    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 27    0.22    1.0   NaN     NaN   19.0    0.0    0.15    1.0   NaN     NaN
# 28    0.14    1.0   NaN     NaN   19.0    0.0    0.05    1.0   NaN     NaN
# 29    0.00    1.0   NaN     NaN    2.0    0.0    0.00    1.0   NaN     NaN
# 30    0.12    1.0   NaN     NaN   19.0    0.0    0.08    1.0   NaN     NaN
# 31    0.01    1.0   NaN     NaN   19.0    0.0    0.01    1.0   NaN     NaN
# 32    0.02    1.0   NaN     NaN   19.0    0.0    0.01    1.0   NaN     NaN
# 33    0.01    1.0   NaN     NaN   19.0    0.0    0.01    1.0   NaN     NaN
# 34    1.72   34.0  21.0    0.26  335.0    0.0    1.12   34.0  21.0    0.16
#
# [35 rows x 25 columns]

# %%
print(
result[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_a','gap_a','time_a','opt_a','tk_a','tmax_a',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrrr}
# \toprule
# vertice & bs & gap & time & opt & tk & tmax & bs_a & gap_a & time_a & opt_a & tk_a & tmax_a & bs_b & gap_b & time_b & opt_b & tk_b & tmax_b & bs_c & gap_c & time_c & opt_c & tk_c & tmax_c \\
# \midrule
# 0 & 21.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 20.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 21.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 21.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 1 & 21.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 20.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 21.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 21.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 2 & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 18.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 3 & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 4 & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 5 & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 6 & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 7 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 8 & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 18.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 9 & 19.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 18.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.2 & 1.0 & NaN & NaN \\
# 10 & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 11 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 12 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 13 & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 18.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 14 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 15 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 16 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 17 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 18 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 19 & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 18.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 20 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 21 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 22 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 23 & 19.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 18.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 24 & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 25 & 19.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 26 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 27 & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 18.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 28 & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 18.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 29 & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 30 & 19.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 18.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 31 & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 32 & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 18.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 33 & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 18.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 19.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# mip & 335.0 & 0.0 & 1.6 & 34.0 & 21.0 & 0.3 & 322.0 & 0.0 & 0.5 & 34.0 & 20.0 & 0.1 & 335.0 & 0.0 & 1.7 & 34.0 & 21.0 & 0.3 & 335.0 & 0.0 & 1.1 & 34.0 & 21.0 & 0.2 \\
# \bottomrule
# \end{tabular}

# %%
with open('../result/karate_mip.tex', 'w') as tf:
     tf.write(
          result[[
          'vertice',
          'bs','time',#'opt',#'tk','tmax',
          'bs_a','time_a',#'opt_a',#'tk_a','tmax_a',
          'bs_b','time_b',#'opt_b',#'tk_b','tmax_b',
          'bs_c','time_c',#'opt_c',#'tk_c','tmax_c',
          ]].to_latex(index=False,float_format="%.1f")
    )
