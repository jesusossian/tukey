# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="internet_graph"
method_="mip"
dim_=200
id_=4
ver_="fmin"

# %%
form_="fminc0"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c0 = table
#mip_internet_c0

#print(mip_internet_c0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminc0noclq"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c0noclq = table
#mip_internet_c0noclq

#print(mip_internet_c0noclq[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminc1"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c1 = table
mip_internet_c1

#print(mip_internet_c1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#               vertice      bb      bs  gap     time   nodes    opt     tk
# 0                   0   147.0   147.0  0.0    28.23   119.0    1.0    NaN  \
# 1                   1   142.0   142.0  0.0    22.50    68.0    1.0    NaN
# 2                   2   155.0   155.0  0.0    32.10   123.0    1.0    NaN
# 3                   3   140.0   140.0  0.0    59.84   144.0    1.0    NaN
# 4                   4   147.0   147.0  0.0    24.20    59.0    1.0    NaN
# ..                ...     ...     ...  ...      ...     ...    ...    ...
# 196               196     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 197               197     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 198               198     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 199               199     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 200  mip_fminc1_200_4  5950.0  5950.0  0.0  2354.44  4947.0  200.0  155.0
#
#        tmax
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 196     NaN
# 197     NaN
# 198     NaN
# 199     NaN
# 200  107.03
#
# [201 rows x 9 columns]

# %%
form_="fminc1noclq"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c1noclq = table
#mip_internet_c1noclq

#print(mip_internet_c1noclq[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminc2"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c2 = table
#mip_internet_c2

#print(mip_internet_c2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminmisetc2"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_misetc2 = table
#mip_internet_misetc2

#print(mip_internet_misetc2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminmisetc3"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_misetc3 = table
#mip_internet_misetc3

#print(mip_internet_misetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminmiset"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_miset = table
#mip_internet_miset

#print(mip_internet_miset[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmincutmisetc3"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_cutmisetc3 = table
#mip_internet_cutmisetc3

#print(mip_internet_cut_misetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmincutbmisetc3"

file=f"../result/{inst_}/{method_}/{ver_}/{dim_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_cutbmisetc3 = table
#mip_internet_cutbmisetc3

#print(mip_internet_cutb_misetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
mip_merge = pd.DataFrame()

mip_merge = pd.merge(
    mip_internet_c0, mip_internet_c0noclq,
    on=['vertice'], 
    suffixes=("", "_b"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_c1,
    on=['vertice'], 
    suffixes=("", "_c"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_c1noclq,
    on=['vertice'], 
    suffixes=("", "_d"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_c2,
    on=['vertice'], 
    suffixes=("", "_e"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_misetc2,
    on=['vertice'], 
    suffixes=("", "_f"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_misetc3,
    on=['vertice'], 
    suffixes=("", "_g"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_miset,
    on=['vertice'], 
    suffixes=("", "_h"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_cutmisetc3,
    on=['vertice'], 
    suffixes=("", "_i"),
    )


mip_merge = pd.merge(
    mip_merge, mip_internet_cutbmisetc3,
    on=['vertice'], 
    suffixes=("", "_j"),
    )

mip_merge[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    #'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',
    'bs_f','gap_f','time_f','opt_f','tk_f','tmax_f',
    'bs_g','gap_g','time_g','opt_g','tk_g','tmax_g',
    'bs_h','gap_h','time_h','opt_h','tk_h','tmax_h',
    'bs_i','gap_i','time_i','opt_i','tk_i','tmax_i',
    'bs_j','gap_j','time_j','opt_j','tk_j','tmax_j',
    ]]
# Out:
#     vertice     bs  gap   time  opt  tk  tmax   bs_b  gap_b  time_b  ...
# 0         0  147.0  0.0  31.75  1.0 NaN   NaN  147.0    0.0   31.73  ...  \
# 1         1  142.0  0.0  20.22  1.0 NaN   NaN  142.0    0.0   20.08  ...
# 2         2  155.0  0.0  33.16  1.0 NaN   NaN  155.0    0.0   33.10  ...
# 3         3  140.0  0.0  48.43  1.0 NaN   NaN  140.0    0.0   47.28  ...
# 4         4  147.0  0.0  21.88  1.0 NaN   NaN  147.0    0.0   21.72  ...
# ..      ...    ...  ...    ...  ...  ..   ...    ...    ...     ...  ...
# 195     195    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.67  ...
# 196     196    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.67  ...
# 197     197    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.69  ...
# 198     198    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.71  ...
# 199     199    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.71  ...
#
#      time_i  opt_i  tk_i  tmax_i   bs_j  gap_j  time_j  opt_j  tk_j  tmax_j
# 0      4.83    1.0   NaN     NaN  147.0    0.0    4.74    1.0   NaN     NaN
# 1      2.68    1.0   NaN     NaN  142.0    0.0    2.46    1.0   NaN     NaN
# 2     57.84    1.0   NaN     NaN  155.0    0.0   59.47    1.0   NaN     NaN
# 3      2.16    1.0   NaN     NaN  140.0    0.0    1.81    1.0   NaN     NaN
# 4      4.30    1.0   NaN     NaN  147.0    0.0    4.01    1.0   NaN     NaN
# ..      ...    ...   ...     ...    ...    ...     ...    ...   ...     ...
# 195    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 196    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 197    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 198    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 199    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
#
# [200 rows x 55 columns]

# %%
print(
mip_merge[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',
    'bs_f','gap_f','time_f','opt_f','tk_f','tmax_f',
    'bs_g','gap_g','time_g','opt_g','tk_g','tmax_g',
    'bs_h','gap_h','time_h','opt_h','tk_h','tmax_h',
    'bs_i','gap_i','time_i','opt_i','tk_i','tmax_i',
    'bs_j','gap_j','time_j','opt_j','tk_j','tmax_j',
    ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr}
# \toprule
# vertice & bs & gap & time & opt & tk & tmax & bs_b & gap_b & time_b & opt_b & tk_b & tmax_b & bs_c & gap_c & time_c & opt_c & tk_c & tmax_c & bs_d & gap_d & time_d & opt_d & tk_d & tmax_d & bs_e & gap_e & time_e & opt_e & tk_e & tmax_e & bs_f & gap_f & time_f & opt_f & tk_f & tmax_f & bs_g & gap_g & time_g & opt_g & tk_g & tmax_g & bs_h & gap_h & time_h & opt_h & tk_h & tmax_h & bs_i & gap_i & time_i & opt_i & tk_i & tmax_i & bs_j & gap_j & time_j & opt_j & tk_j & tmax_j \\
# \midrule
# 0 & 147.0 & 0.0 & 31.8 & 1.0 & NaN & NaN & 147.0 & 0.0 & 31.7 & 1.0 & NaN & NaN & 147.0 & 0.0 & 28.2 & 1.0 & NaN & NaN & 147.0 & 0.0 & 26.1 & 1.0 & NaN & NaN & 147.0 & 0.0 & 13.7 & 1.0 & NaN & NaN & 147.0 & 0.0 & 13.9 & 1.0 & NaN & NaN & 147.0 & 0.0 & 9.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 147.0 & 0.0 & 4.8 & 1.0 & NaN & NaN & 147.0 & 0.0 & 4.7 & 1.0 & NaN & NaN \\
# 1 & 142.0 & 0.0 & 20.2 & 1.0 & NaN & NaN & 142.0 & 0.0 & 20.1 & 1.0 & NaN & NaN & 142.0 & 0.0 & 22.5 & 1.0 & NaN & NaN & 142.0 & 0.0 & 21.1 & 1.0 & NaN & NaN & 142.0 & 0.0 & 12.7 & 1.0 & NaN & NaN & 142.0 & 0.0 & 8.1 & 1.0 & NaN & NaN & 142.0 & 0.0 & 7.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 142.0 & 0.0 & 2.7 & 1.0 & NaN & NaN & 142.0 & 0.0 & 2.5 & 1.0 & NaN & NaN \\
# 2 & 155.0 & 0.0 & 33.2 & 1.0 & NaN & NaN & 155.0 & 0.0 & 33.1 & 1.0 & NaN & NaN & 155.0 & 0.0 & 32.1 & 1.0 & NaN & NaN & 155.0 & 0.0 & 30.1 & 1.0 & NaN & NaN & 155.0 & 0.0 & 14.1 & 1.0 & NaN & NaN & 155.0 & 0.0 & 15.8 & 1.0 & NaN & NaN & 155.0 & 0.0 & 10.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 155.0 & 0.0 & 57.8 & 1.0 & NaN & NaN & 155.0 & 0.0 & 59.5 & 1.0 & NaN & NaN \\
# 3 & 140.0 & 0.0 & 48.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 47.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 59.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 57.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 24.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 24.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.8 & 1.0 & NaN & NaN \\
# 4 & 147.0 & 0.0 & 21.9 & 1.0 & NaN & NaN & 147.0 & 0.0 & 21.7 & 1.0 & NaN & NaN & 147.0 & 0.0 & 24.2 & 1.0 & NaN & NaN & 147.0 & 0.0 & 22.6 & 1.0 & NaN & NaN & 147.0 & 0.0 & 15.1 & 1.0 & NaN & NaN & 147.0 & 0.0 & 12.0 & 1.0 & NaN & NaN & 147.0 & 0.0 & 9.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 147.0 & 0.0 & 4.3 & 1.0 & NaN & NaN & 147.0 & 0.0 & 4.0 & 1.0 & NaN & NaN \\
# 5 & 140.0 & 0.0 & 39.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 39.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 41.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 40.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 17.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 16.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.6 & 1.0 & NaN & NaN \\
# 6 & 140.0 & 0.0 & 45.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 44.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 47.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 46.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 12.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 15.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 15.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.8 & 1.0 & NaN & NaN \\
# 7 & 140.0 & 0.0 & 41.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 42.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 39.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 39.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 15.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 11.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.6 & 1.0 & NaN & NaN \\
# 8 & 140.0 & 0.0 & 31.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 31.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 21.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 20.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 10.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.4 & 1.0 & NaN & NaN \\
# 9 & 140.0 & 0.0 & 38.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 38.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 24.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 23.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 19.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 15.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.6 & 1.0 & NaN & NaN \\
# 10 & 140.0 & 0.0 & 26.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 27.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 26.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 25.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 11.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 8.0 & 1.0 & NaN & NaN & 138.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 5.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 5.8 & 1.0 & NaN & NaN \\
# 11 & 2.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.5 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.5 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 2.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 12 & 140.0 & 0.0 & 53.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 52.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 54.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 52.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 19.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 16.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 10.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.7 & 1.0 & NaN & NaN \\
# 13 & 140.0 & 0.0 & 55.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 55.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 55.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 54.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 11.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.8 & 1.0 & NaN & NaN \\
# 14 & 140.0 & 0.0 & 53.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 53.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 50.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 48.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.6 & 1.0 & NaN & NaN & 125.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.7 & 1.0 & NaN & NaN \\
# 15 & 140.0 & 0.0 & 80.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 80.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 89.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 90.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 17.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 18.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 19.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.8 & 1.0 & NaN & NaN \\
# 16 & 140.0 & 0.0 & 77.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 76.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 62.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 62.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.9 & 1.0 & NaN & NaN \\
# 17 & 140.0 & 0.0 & 66.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 66.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 49.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 48.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 12.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 20.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.5 & 1.0 & NaN & NaN \\
# 18 & 140.0 & 0.0 & 56.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 56.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 52.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 51.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 16.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 16.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.0 & 1.0 & NaN & NaN \\
# 19 & 140.0 & 0.0 & 51.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 51.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 46.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 46.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 15.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 16.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 12.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.5 & 1.0 & NaN & NaN \\
# 20 & 140.0 & 0.0 & 82.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 82.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 67.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 67.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 16.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 15.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.9 & 1.0 & NaN & NaN \\
# 21 & 140.0 & 0.0 & 46.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 47.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 50.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 52.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 16.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 15.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.8 & 1.0 & NaN & NaN \\
# 22 & 144.0 & 0.0 & 36.2 & 1.0 & NaN & NaN & 144.0 & 0.0 & 36.4 & 1.0 & NaN & NaN & 144.0 & 0.0 & 32.5 & 1.0 & NaN & NaN & 144.0 & 0.0 & 31.9 & 1.0 & NaN & NaN & 144.0 & 0.0 & 21.5 & 1.0 & NaN & NaN & 144.0 & 0.0 & 20.5 & 1.0 & NaN & NaN & 144.0 & 0.0 & 15.9 & 1.0 & NaN & NaN & 134.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 144.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 144.0 & 0.0 & 0.4 & 1.0 & NaN & NaN \\
# 23 & 144.0 & 0.0 & 52.3 & 1.0 & NaN & NaN & 144.0 & 0.0 & 51.6 & 1.0 & NaN & NaN & 144.0 & 0.0 & 57.4 & 1.0 & NaN & NaN & 144.0 & 0.0 & 62.9 & 1.0 & NaN & NaN & 144.0 & 0.0 & 17.8 & 1.0 & NaN & NaN & 144.0 & 0.0 & 10.9 & 1.0 & NaN & NaN & 144.0 & 0.0 & 10.8 & 1.0 & NaN & NaN & 134.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 144.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 144.0 & 0.0 & 0.5 & 1.0 & NaN & NaN \\
# 24 & 140.0 & 0.0 & 37.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 36.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 45.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 53.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 10.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 9.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.0 & 1.0 & NaN & NaN \\
# 25 & 140.0 & 0.0 & 56.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 55.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 80.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 94.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 17.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 15.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.8 & 1.0 & NaN & NaN \\
# 26 & 140.0 & 0.0 & 70.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 69.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 55.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 67.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 21.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 20.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 16.4 & 1.0 & NaN & NaN & 138.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 4.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 4.2 & 1.0 & NaN & NaN \\
# 27 & 140.0 & 0.0 & 85.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 85.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 87.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 100.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 17.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 12.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.8 & 1.0 & NaN & NaN \\
# 28 & 147.0 & 0.0 & 71.3 & 1.0 & NaN & NaN & 147.0 & 0.0 & 71.3 & 1.0 & NaN & NaN & 147.0 & 0.0 & 58.4 & 1.0 & NaN & NaN & 147.0 & 0.0 & 66.9 & 1.0 & NaN & NaN & 147.0 & 0.0 & 13.2 & 1.0 & NaN & NaN & 147.0 & 0.0 & 18.8 & 1.0 & NaN & NaN & 147.0 & 0.0 & 12.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 147.0 & 0.0 & 6.2 & 1.0 & NaN & NaN & 147.0 & 0.0 & 5.8 & 1.0 & NaN & NaN \\
# 29 & 142.0 & 0.0 & 67.2 & 1.0 & NaN & NaN & 142.0 & 0.0 & 68.3 & 1.0 & NaN & NaN & 142.0 & 0.0 & 77.6 & 1.0 & NaN & NaN & 142.0 & 0.0 & 88.5 & 1.0 & NaN & NaN & 142.0 & 0.0 & 14.1 & 1.0 & NaN & NaN & 142.0 & 0.0 & 17.7 & 1.0 & NaN & NaN & 142.0 & 0.0 & 17.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 142.0 & 0.0 & 2.8 & 1.0 & NaN & NaN & 142.0 & 0.0 & 2.6 & 1.0 & NaN & NaN \\
# 30 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 31 & 140.0 & 0.0 & 50.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 51.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 39.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 46.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.0 & 1.0 & NaN & NaN \\
# 32 & 140.0 & 0.0 & 77.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 79.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 67.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 76.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 16.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.5 & 1.0 & NaN & NaN \\
# 33 & 140.0 & 0.0 & 79.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 80.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 77.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 95.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 21.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 20.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 21.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.0 & 1.0 & NaN & NaN \\
# 34 & 140.0 & 0.0 & 46.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 47.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 56.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 63.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 19.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 16.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.2 & 1.0 & NaN & NaN \\
# 35 & 142.0 & 0.0 & 95.0 & 1.0 & NaN & NaN & 142.0 & 0.0 & 95.7 & 1.0 & NaN & NaN & 142.0 & 0.0 & 107.0 & 1.0 & NaN & NaN & 142.0 & 0.0 & 121.1 & 1.0 & NaN & NaN & 142.0 & 0.0 & 19.9 & 1.0 & NaN & NaN & 142.0 & 0.0 & 31.2 & 1.0 & NaN & NaN & 142.0 & 0.0 & 18.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 142.0 & 0.0 & 3.5 & 1.0 & NaN & NaN & 142.0 & 0.0 & 3.1 & 1.0 & NaN & NaN \\
# 36 & 140.0 & 0.0 & 84.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 83.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 94.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 112.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 20.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 22.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 19.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.8 & 1.0 & NaN & NaN \\
# 37 & 140.0 & 0.0 & 98.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 96.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 97.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 114.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 17.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 15.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.5 & 1.0 & NaN & NaN \\
# 38 & 140.0 & 0.0 & 90.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 89.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 68.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 69.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 16.4 & 1.0 & NaN & NaN & 140.0 & 0.0 & 27.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.3 & 1.0 & NaN & NaN \\
# 39 & 140.0 & 0.0 & 64.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 63.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 49.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 51.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 14.3 & 1.0 & NaN & NaN & 140.0 & 0.0 & 16.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 13.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.7 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.2 & 1.0 & NaN & NaN \\
# 40 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 41 & 140.0 & 0.0 & 86.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 87.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 103.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 105.8 & 1.0 & NaN & NaN & 140.0 & 0.0 & 15.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 18.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 11.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 2.0 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.8 & 1.0 & NaN & NaN \\
# 42 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 43 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 44 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 45 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 46 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 47 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 48 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 49 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 50 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 51 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 52 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 53 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 54 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 55 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 56 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 57 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 58 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 59 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 60 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 61 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 62 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 63 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 64 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 65 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 66 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 67 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 68 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 69 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 70 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 71 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 72 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 73 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 74 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 75 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 76 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 77 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 78 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 79 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 80 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 81 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 82 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 83 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 84 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 85 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 86 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 87 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 88 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.4 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 89 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 90 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 91 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 92 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.4 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 93 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 94 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.4 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 95 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.4 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 96 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 97 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 98 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.4 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 99 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 100 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 101 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 102 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 103 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 104 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 105 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 106 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.4 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 107 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 108 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.4 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 109 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.4 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 110 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 111 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 112 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 113 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 114 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 115 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 116 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 117 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 118 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 119 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 120 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 121 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 122 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 123 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 124 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 125 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# ...
# 157 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 158 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 159 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 160 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 161 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 162 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 163 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 164 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 165 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 166 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 167 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 168 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 169 & 140.0 & 0.0 & 80.6 & 1.0 & NaN & NaN & 140.0 & 0.0 & 80.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 59.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 61.2 & 1.0 & NaN & NaN & 140.0 & 0.0 & 22.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 24.5 & 1.0 & NaN & NaN & 140.0 & 0.0 & 18.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.9 & 1.0 & NaN & NaN & 140.0 & 0.0 & 1.7 & 1.0 & NaN & NaN \\
# 170 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 171 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 172 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 173 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 174 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 175 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 176 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 177 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 178 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 179 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 180 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 181 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 182 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 183 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 184 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 185 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 186 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 187 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 188 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 189 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 190 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 191 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 192 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 193 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 194 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 195 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 196 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 197 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 198 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 199 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# \bottomrule
# \end{tabular}

# %%
mip_concat = pd.DataFrame()
mip_concat = pd.concat([mip_concat, mip_internet_c0.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c0noclq.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c1.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c1noclq.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c2.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_misetc2.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_misetc3.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_miset.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_cutmisetc3.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_cutbmisetc3.loc[200:200]], ignore_index=True)
mip_concat
# Out:
#                      vertice      bb      bs  gap     time   nodes    opt
# 0           mip_fminc0_200_4  5950.0  5950.0  0.0  2386.40  5141.0  200.0  \
# 1      mip_fminc0noclq_200_4  5950.0  5950.0  0.0  2491.33  5141.0  200.0
# 2           mip_fminc1_200_4  5950.0  5950.0  0.0  2354.44  4947.0  200.0
# 3      mip_fminc1noclq_200_4  5950.0  5950.0  0.0  2549.80  4947.0  200.0
# 4           mip_fminc2_200_4  5950.0  5950.0  0.0   670.84  5811.0  200.0
# 5      mip_fminmisetc2_200_4  5950.0  5950.0  0.0   692.58   920.0  200.0
# 6      mip_fminmisetc3_200_4  5950.0  5950.0  0.0   569.25   985.0  200.0
# 7        mip_fminmiset_200_4  5293.0  5293.0  0.0     4.59  1263.0  200.0
# 8   mip_fmincutmisetc3_200_4  5950.0  5950.0  0.0   157.97  1805.0  200.0
# 9  mip_fmincutbmisetc3_200_4  5950.0  5950.0  0.0   146.89  1826.0  200.0
#
#       tk    tmax
# 0  155.0   98.61
# 1  155.0   96.63
# 2  155.0  107.03
# 3  155.0  121.10
# 4  155.0   24.74
# 5  155.0   31.17
# 6  155.0   21.84
# 7  138.0    0.15
# 8  155.0   57.84
# 9  155.0   59.47

# %%
print(
mip_concat[[
    'vertice','bs','gap','time','opt','tk','tmax',
    ]].to_latex(index=False,float_format="%.1f")
)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# vertice & bs & gap & time & opt & tk & tmax \\
# \midrule
# mip_fminc0_200_4 & 5950.0 & 0.0 & 2386.4 & 200.0 & 155.0 & 98.6 \\
# mip_fminc0noclq_200_4 & 5950.0 & 0.0 & 2491.3 & 200.0 & 155.0 & 96.6 \\
# mip_fminc1_200_4 & 5950.0 & 0.0 & 2354.4 & 200.0 & 155.0 & 107.0 \\
# mip_fminc1noclq_200_4 & 5950.0 & 0.0 & 2549.8 & 200.0 & 155.0 & 121.1 \\
# mip_fminc2_200_4 & 5950.0 & 0.0 & 670.8 & 200.0 & 155.0 & 24.7 \\
# mip_fminmisetc2_200_4 & 5950.0 & 0.0 & 692.6 & 200.0 & 155.0 & 31.2 \\
# mip_fminmisetc3_200_4 & 5950.0 & 0.0 & 569.2 & 200.0 & 155.0 & 21.8 \\
# mip_fminmiset_200_4 & 5293.0 & 0.0 & 4.6 & 200.0 & 138.0 & 0.1 \\
# mip_fmincutmisetc3_200_4 & 5950.0 & 0.0 & 158.0 & 200.0 & 155.0 & 57.8 \\
# mip_fmincutbmisetc3_200_4 & 5950.0 & 0.0 & 146.9 & 200.0 & 155.0 & 59.5 \\
# \bottomrule
# \end{tabular}
