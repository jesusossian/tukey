# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="internet_graph"
method_="rf"
dim_=200
ver_="fmin"

# %%
form_="fminrfc2"
id_=1

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bs','time']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bs':table["bs"].sum(),
    'time':table['time'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
rf_internet_c2_1 = table
rf_internet_c2_1

#print(mip_internet_c0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                vertice      bs    time     tk   tmax
# 0                    0   199.0    6.55    NaN    NaN
# 1                    1   199.0    6.62    NaN    NaN
# 2                    2   199.0    6.54    NaN    NaN
# 3                    3   199.0    7.95    NaN    NaN
# 4                    4   199.0    9.88    NaN    NaN
# ..                 ...     ...     ...    ...    ...
# 196                196     1.0    0.00    NaN    NaN
# 197                197     1.0    0.00    NaN    NaN
# 198                198     1.0    0.00    NaN    NaN
# 199                199     1.0    0.00    NaN    NaN
# 200  rf_fminrfc2_200_1  7067.0  233.75  199.0  11.18
#
# [201 rows x 5 columns]

# %%
form_="fminrfc2"
id_=2

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bs','time']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bs':table["bs"].sum(),
    'time':table['time'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
rf_internet_c2_2 = table
rf_internet_c2_2

#print(mip_internet_c0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                vertice      bs    time     tk   tmax
# 0                    0   199.0    6.85    NaN    NaN
# 1                    1   199.0    7.52    NaN    NaN
# 2                    2   199.0    8.35    NaN    NaN
# 3                    3   199.0    6.96    NaN    NaN
# 4                    4   199.0    6.78    NaN    NaN
# ..                 ...     ...     ...    ...    ...
# 196                196     1.0    0.00    NaN    NaN
# 197                197     1.0    0.00    NaN    NaN
# 198                198     1.0    0.00    NaN    NaN
# 199                199     1.0    0.00    NaN    NaN
# 200  rf_fminrfc2_200_2  7828.0  242.06  199.0  10.07
#
# [201 rows x 5 columns]

# %%
form_="fminrfc2"
id_=3

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bs','time']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bs':table["bs"].sum(),
    'time':table['time'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
rf_internet_c2_3 = table
rf_internet_c2_3

#print(mip_internet_c0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                vertice      bs    time     tk  tmax
# 0                    0   199.0    7.04    NaN   NaN
# 1                    1   199.0    6.69    NaN   NaN
# 2                    2   199.0    8.38    NaN   NaN
# 3                    3   199.0    8.34    NaN   NaN
# 4                    4   199.0    7.89    NaN   NaN
# ..                 ...     ...     ...    ...   ...
# 196                196     1.0    0.00    NaN   NaN
# 197                197     1.0    0.00    NaN   NaN
# 198                198     1.0    0.00    NaN   NaN
# 199                199     1.0    0.00    NaN   NaN
# 200  rf_fminrfc2_200_3  7187.0  214.85  199.0  8.67
#
# [201 rows x 5 columns]

# %%
form_="fminrfc2"
id_=4

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bs','time']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bs':table["bs"].sum(),
    'time':table['time'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
rf_internet_c2_4 = table
rf_internet_c2_4

#print(mip_internet_c0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                vertice      bs    time     tk  tmax
# 0                    0   199.0    6.57    NaN   NaN
# 1                    1   199.0    6.38    NaN   NaN
# 2                    2   199.0    6.27    NaN   NaN
# 3                    3   199.0    7.24    NaN   NaN
# 4                    4   199.0    6.23    NaN   NaN
# ..                 ...     ...     ...    ...   ...
# 196                196     1.0    0.00    NaN   NaN
# 197                197     1.0    0.00    NaN   NaN
# 198                198     1.0    0.00    NaN   NaN
# 199                199     1.0    0.00    NaN   NaN
# 200  rf_fminrfc2_200_4  7512.0  250.14  199.0  9.84
#
# [201 rows x 5 columns]

# %%
form_="fminrfc2"
id_=5

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bs','time']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bs':table["bs"].sum(),
    'time':table['time'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
rf_internet_c2_5 = table
rf_internet_c2_5

#print(mip_internet_c0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                vertice      bs    time     tk  tmax
# 0                    0   199.0    7.93    NaN   NaN
# 1                    1   199.0    7.65    NaN   NaN
# 2                    2   199.0    6.89    NaN   NaN
# 3                    3   199.0    6.93    NaN   NaN
# 4                    4   199.0    7.53    NaN   NaN
# ..                 ...     ...     ...    ...   ...
# 196                196     1.0    0.00    NaN   NaN
# 197                197     1.0    0.00    NaN   NaN
# 198                198     1.0    0.00    NaN   NaN
# 199                199     1.0    0.00    NaN   NaN
# 200  rf_fminrfc2_200_5  7587.0  267.89  199.0  9.92
#
# [201 rows x 5 columns]

# %%
rf_concat = pd.DataFrame()
rf_concat = pd.concat([rf_concat, rf_internet_c2_1.loc[200:200]], ignore_index=True)
rf_concat = pd.concat([rf_concat, rf_internet_c2_2.loc[200:200]], ignore_index=True)
rf_concat = pd.concat([rf_concat, rf_internet_c2_3.loc[200:200]], ignore_index=True)
rf_concat = pd.concat([rf_concat, rf_internet_c2_4.loc[200:200]], ignore_index=True)
rf_concat = pd.concat([rf_concat, rf_internet_c2_5.loc[200:200]], ignore_index=True)
rf_concat
# Out:
#              vertice      bs    time     tk   tmax
# 0  rf_fminrfc2_200_1  7067.0  233.75  199.0  11.18
# 1  rf_fminrfc2_200_2  7828.0  242.06  199.0  10.07
# 2  rf_fminrfc2_200_3  7187.0  214.85  199.0   8.67
# 3  rf_fminrfc2_200_4  7512.0  250.14  199.0   9.84
# 4  rf_fminrfc2_200_5  7587.0  267.89  199.0   9.92

# %%
print(
rf_concat[[
    'vertice','bs','time','tk','tmax',
    ]].to_latex(index=False,float_format="%.1f")
)
# Out:
# \begin{tabular}{lrrrr}
# \toprule
#           vertice &     bs &  time &    tk &  tmax \\
# \midrule
# rf\_fminrfc2\_200\_1 & 7067.0 & 233.8 & 199.0 &  11.2 \\
# rf\_fminrfc2\_200\_2 & 7828.0 & 242.1 & 199.0 &  10.1 \\
# rf\_fminrfc2\_200\_3 & 7187.0 & 214.9 & 199.0 &   8.7 \\
# rf\_fminrfc2\_200\_4 & 7512.0 & 250.1 & 199.0 &   9.8 \\
# rf\_fminrfc2\_200\_5 & 7587.0 & 267.9 & 199.0 &   9.9 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_60327/2687900321.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   rf_concat[[
