# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="internet_graph"
method_="mip"
dim_=200
id_=1
ver_="fmax"

# %%
form_="fmaxc0"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c0 = table
mip_internet_c0

#print(mip_internet_c0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#               vertice      bb      bs  gap     time   nodes    opt     tk
# 0                   0   143.0   143.0  0.0    22.63    47.0    1.0    NaN  \
# 1                   1   124.0   124.0  0.0    16.06     1.0    1.0    NaN
# 2                   2   127.0   127.0  0.0     4.24     1.0    1.0    NaN
# 3                   3   124.0   124.0  0.0    29.82    19.0    1.0    NaN
# 4                   4   124.0   124.0  0.0    44.01    37.0    1.0    NaN
# ..                ...     ...     ...  ...      ...     ...    ...    ...
# 196               196     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 197               197     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 198               198     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 199               199     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 200  mip_fmaxc0_200_1  5092.0  5092.0  0.0  1694.27  1302.0  200.0  149.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  91.64
#
# [201 rows x 9 columns]

# %%
form_="fmaxc0noclq"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c0noclq = table
mip_internet_c0noclq

#print(mip_internet_c0noclq[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap     time   nodes    opt
# 0                        0   143.0   143.0  0.0    20.75    47.0    1.0  \
# 1                        1   124.0   124.0  0.0    14.80     1.0    1.0
# 2                        2   127.0   127.0  0.0     3.94     1.0    1.0
# 3                        3   124.0   124.0  0.0    28.01    19.0    1.0
# 4                        4   124.0   124.0  0.0    43.22    37.0    1.0
# ..                     ...     ...     ...  ...      ...     ...    ...
# 196                    196     1.0     1.0  0.0     0.69     1.0    1.0
# 197                    197     1.0     1.0  0.0     0.69     1.0    1.0
# 198                    198     1.0     1.0  0.0     0.65     1.0    1.0
# 199                    199     1.0     1.0  0.0     0.64     1.0    1.0
# 200  mip_fmaxc0noclq_200_1  5092.0  5092.0  0.0  1818.67  1460.0  200.0
#
#         tk    tmax
# 0      NaN     NaN
# 1      NaN     NaN
# 2      NaN     NaN
# 3      NaN     NaN
# 4      NaN     NaN
# ..     ...     ...
# 196    NaN     NaN
# 197    NaN     NaN
# 198    NaN     NaN
# 199    NaN     NaN
# 200  149.0  100.47
#
# [201 rows x 9 columns]

# %%
form_="fmaxc1"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c1 = table
mip_internet_c1

#print(mip_internet_c1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#               vertice      bb      bs  gap     time   nodes    opt     tk
# 0                   0   143.0   143.0  0.0    19.08    38.0    1.0    NaN  \
# 1                   1   124.0   124.0  0.0    14.83     1.0    1.0    NaN
# 2                   2   127.0   127.0  0.0     2.58     1.0    1.0    NaN
# 3                   3   124.0   124.0  0.0    30.50    11.0    1.0    NaN
# 4                   4   124.0   124.0  0.0    34.05    17.0    1.0    NaN
# ..                ...     ...     ...  ...      ...     ...    ...    ...
# 196               196     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 197               197     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 198               198     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 199               199     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 200  mip_fmaxc1_200_1  5092.0  5092.0  0.0  1434.36  1344.0  200.0  149.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  71.06
#
# [201 rows x 9 columns]

# %%
form_="fmaxc1noclq"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c1noclq = table
mip_internet_c1noclq

#print(mip_internet_c1noclq[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap     time   nodes    opt
# 0                        0   143.0   143.0  0.0    18.19    38.0    1.0  \
# 1                        1   124.0   124.0  0.0    14.23     1.0    1.0
# 2                        2   127.0   127.0  0.0     2.48     1.0    1.0
# 3                        3   124.0   124.0  0.0    29.43    11.0    1.0
# 4                        4   124.0   124.0  0.0    32.88    17.0    1.0
# ..                     ...     ...     ...  ...      ...     ...    ...
# 196                    196     1.0     1.0  0.0     0.26     1.0    1.0
# 197                    197     1.0     1.0  0.0     0.25     1.0    1.0
# 198                    198     1.0     1.0  0.0     0.26     1.0    1.0
# 199                    199     1.0     1.0  0.0     0.26     1.0    1.0
# 200  mip_fmaxc1noclq_200_1  5092.0  5092.0  0.0  1469.66  1502.0  200.0
#
#         tk   tmax
# 0      NaN    NaN
# 1      NaN    NaN
# 2      NaN    NaN
# 3      NaN    NaN
# 4      NaN    NaN
# ..     ...    ...
# 196    NaN    NaN
# 197    NaN    NaN
# 198    NaN    NaN
# 199    NaN    NaN
# 200  149.0  70.97
#
# [201 rows x 9 columns]

# %%
form_="fmaxc2"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c2 = table
mip_internet_c2

#print(mip_internet_c2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#               vertice      bb      bs  gap    time   nodes    opt     tk
# 0                   0   143.0   143.0  0.0   11.35    61.0    1.0    NaN  \
# 1                   1   124.0   124.0  0.0    6.18     1.0    1.0    NaN
# 2                   2   127.0   127.0  0.0    3.44     1.0    1.0    NaN
# 3                   3   124.0   124.0  0.0   15.90    15.0    1.0    NaN
# 4                   4   124.0   124.0  0.0   14.43    67.0    1.0    NaN
# ..                ...     ...     ...  ...     ...     ...    ...    ...
# 196               196     1.0     1.0  0.0    0.00     0.0    1.0    NaN
# 197               197     1.0     1.0  0.0    0.00     0.0    1.0    NaN
# 198               198     1.0     1.0  0.0    0.00     0.0    1.0    NaN
# 199               199     1.0     1.0  0.0    0.00     0.0    1.0    NaN
# 200  mip_fmaxc2_200_1  5092.0  5092.0  0.0  583.64  2260.0  200.0  149.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  29.99
#
# [201 rows x 9 columns]

# %%
form_="fmaxmisetc2"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_misetc2 = table
mip_internet_misetc2

#print(mip_internet_misetc2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap    time  nodes    opt     tk
# 0                        0   143.0   143.0  0.0    8.44   11.0    1.0    NaN  \
# 1                        1   124.0   124.0  0.0    4.20    1.0    1.0    NaN
# 2                        2   127.0   127.0  0.0    2.30    1.0    1.0    NaN
# 3                        3   124.0   124.0  0.0   14.52    9.0    1.0    NaN
# 4                        4   124.0   124.0  0.0   15.40    9.0    1.0    NaN
# ..                     ...     ...     ...  ...     ...    ...    ...    ...
# 196                    196     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 197                    197     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 198                    198     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 199                    199     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 200  mip_fmaxmisetc2_200_1  5092.0  5092.0  0.0  541.94  449.0  200.0  149.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  25.15
#
# [201 rows x 9 columns]

# %%
form_="fmaxmisetc3"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_misetc3 = table
mip_internet_misetc3

#print(mip_internet_misetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap    time  nodes    opt     tk
# 0                        0   143.0   143.0  0.0    6.11   13.0    1.0    NaN  \
# 1                        1   124.0   124.0  0.0    5.67    1.0    1.0    NaN
# 2                        2   127.0   127.0  0.0    2.30    1.0    1.0    NaN
# 3                        3   124.0   124.0  0.0   11.07   11.0    1.0    NaN
# 4                        4   124.0   124.0  0.0   13.83   11.0    1.0    NaN
# ..                     ...     ...     ...  ...     ...    ...    ...    ...
# 196                    196     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 197                    197     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 198                    198     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 199                    199     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 200  mip_fmaxmisetc3_200_1  5092.0  5092.0  0.0  607.62  480.0  200.0  149.0
#
#      tmax
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 196   NaN
# 197   NaN
# 198   NaN
# 199   NaN
# 200  30.0
#
# [201 rows x 9 columns]

# %%
form_="fmaxmiset"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_miset = table
mip_internet_miset

#print(mip_internet_miset[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                  vertice      bb      bs  gap  time  nodes    opt     tk  tmax
# 0                      0   137.0   137.0  0.0  0.08   11.0    1.0    NaN   NaN
# 1                      1   120.0   120.0  0.0  0.09    5.0    1.0    NaN   NaN
# 2                      2   122.0   122.0  0.0  0.03    1.0    1.0    NaN   NaN
# 3                      3   120.0   120.0  0.0  0.14    9.0    1.0    NaN   NaN
# 4                      4   120.0   120.0  0.0  0.13   17.0    1.0    NaN   NaN
# ..                   ...     ...     ...  ...   ...    ...    ...    ...   ...
# 196                  196     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 197                  197     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 198                  198     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 199                  199     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 200  mip_fmaxmiset_200_1  4931.0  4931.0  0.0  4.59  629.0  200.0  146.0  0.17
#
# [201 rows x 9 columns]

# %%
mip_merge = pd.DataFrame()

mip_merge = pd.merge(
    mip_internet_c0, mip_internet_c0noclq,
    on=['vertice'], 
    suffixes=("", "_b"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_c1,
    on=['vertice'], 
    suffixes=("", "_c"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_c1noclq,
    on=['vertice'], 
    suffixes=("", "_d"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_c2,
    on=['vertice'], 
    suffixes=("", "_e"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_misetc2,
    on=['vertice'], 
    suffixes=("", "_f"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_misetc3,
    on=['vertice'], 
    suffixes=("", "_g"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_miset,
    on=['vertice'], 
    suffixes=("", "_h"),
    )


mip_merge[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',
    ]]
# Out:
#     vertice     bs  gap   time  opt  tk  tmax   bs_b  gap_b  time_b  ...
# 0         0  143.0  0.0  22.63  1.0 NaN   NaN  143.0    0.0   20.75  ...  \
# 1         1  124.0  0.0  16.06  1.0 NaN   NaN  124.0    0.0   14.80  ...
# 2         2  127.0  0.0   4.24  1.0 NaN   NaN  127.0    0.0    3.94  ...
# 3         3  124.0  0.0  29.82  1.0 NaN   NaN  124.0    0.0   28.01  ...
# 4         4  124.0  0.0  44.01  1.0 NaN   NaN  124.0    0.0   43.22  ...
# ..      ...    ...  ...    ...  ...  ..   ...    ...    ...     ...  ...
# 195     195    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.68  ...
# 196     196    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.69  ...
# 197     197    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.69  ...
# 198     198    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.65  ...
# 199     199    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.64  ...
#
#      time_d  opt_d  tk_d  tmax_d   bs_e  gap_e  time_e  opt_e  tk_e  tmax_e
# 0     18.19    1.0   NaN     NaN  143.0    0.0   11.35    1.0   NaN     NaN
# 1     14.23    1.0   NaN     NaN  124.0    0.0    6.18    1.0   NaN     NaN
# 2      2.48    1.0   NaN     NaN  127.0    0.0    3.44    1.0   NaN     NaN
# 3     29.43    1.0   NaN     NaN  124.0    0.0   15.90    1.0   NaN     NaN
# 4     32.88    1.0   NaN     NaN  124.0    0.0   14.43    1.0   NaN     NaN
# ..      ...    ...   ...     ...    ...    ...     ...    ...   ...     ...
# 195    0.25    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 196    0.26    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 197    0.25    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 198    0.26    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 199    0.26    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
#
# [200 rows x 31 columns]

# %%
print(
mip_merge[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',
    'bs_f','gap_f','time_f','opt_f','tk_f','tmax_f',
    'bs_g','gap_g','time_g','opt_g','tk_g','tmax_g',
    'bs_h','gap_h','time_h','opt_h','tk_h','tmax_h',
    ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr}
# \toprule
# vertice & bs & gap & time & opt & tk & tmax & bs_b & gap_b & time_b & opt_b & tk_b & tmax_b & bs_c & gap_c & time_c & opt_c & tk_c & tmax_c & bs_d & gap_d & time_d & opt_d & tk_d & tmax_d & bs_e & gap_e & time_e & opt_e & tk_e & tmax_e & bs_f & gap_f & time_f & opt_f & tk_f & tmax_f & bs_g & gap_g & time_g & opt_g & tk_g & tmax_g & bs_h & gap_h & time_h & opt_h & tk_h & tmax_h \\
# \midrule
# 0 & 143.0 & 0.0 & 22.6 & 1.0 & NaN & NaN & 143.0 & 0.0 & 20.8 & 1.0 & NaN & NaN & 143.0 & 0.0 & 19.1 & 1.0 & NaN & NaN & 143.0 & 0.0 & 18.2 & 1.0 & NaN & NaN & 143.0 & 0.0 & 11.3 & 1.0 & NaN & NaN & 143.0 & 0.0 & 8.4 & 1.0 & NaN & NaN & 143.0 & 0.0 & 6.1 & 1.0 & NaN & NaN & 137.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 1 & 124.0 & 0.0 & 16.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 6.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 4.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 5.7 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 2 & 127.0 & 0.0 & 4.2 & 1.0 & NaN & NaN & 127.0 & 0.0 & 3.9 & 1.0 & NaN & NaN & 127.0 & 0.0 & 2.6 & 1.0 & NaN & NaN & 127.0 & 0.0 & 2.5 & 1.0 & NaN & NaN & 127.0 & 0.0 & 3.4 & 1.0 & NaN & NaN & 127.0 & 0.0 & 2.3 & 1.0 & NaN & NaN & 127.0 & 0.0 & 2.3 & 1.0 & NaN & NaN & 122.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 3 & 124.0 & 0.0 & 29.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 28.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 30.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 29.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.1 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 4 & 124.0 & 0.0 & 44.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 43.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 34.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 32.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.8 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 5 & 16.0 & 0.0 & 1.4 & 1.0 & NaN & NaN & 16.0 & 0.0 & 1.0 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 6 & 124.0 & 0.0 & 21.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 21.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 20.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 12.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 9.9 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 7 & 124.0 & 0.0 & 29.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 26.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 12.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 12.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 16.5 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 8 & 125.0 & 0.0 & 4.1 & 1.0 & NaN & NaN & 125.0 & 0.0 & 3.7 & 1.0 & NaN & NaN & 125.0 & 0.0 & 4.1 & 1.0 & NaN & NaN & 125.0 & 0.0 & 3.9 & 1.0 & NaN & NaN & 125.0 & 0.0 & 3.6 & 1.0 & NaN & NaN & 125.0 & 0.0 & 2.2 & 1.0 & NaN & NaN & 125.0 & 0.0 & 2.6 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 9 & 124.0 & 0.0 & 38.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 35.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 22.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 22.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 12.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 17.0 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 10 & 149.0 & 0.0 & 14.1 & 1.0 & NaN & NaN & 149.0 & 0.0 & 14.0 & 1.0 & NaN & NaN & 149.0 & 0.0 & 16.2 & 1.0 & NaN & NaN & 149.0 & 0.0 & 15.6 & 1.0 & NaN & NaN & 149.0 & 0.0 & 10.0 & 1.0 & NaN & NaN & 149.0 & 0.0 & 10.9 & 1.0 & NaN & NaN & 149.0 & 0.0 & 14.8 & 1.0 & NaN & NaN & 146.0 & 0.0 & 0.2 & 1.0 & NaN & NaN \\
# 11 & 124.0 & 0.0 & 19.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 17.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 16.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.0 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 12 & 124.0 & 0.0 & 64.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 62.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 53.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 51.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 16.0 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 13 & 124.0 & 0.0 & 57.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 58.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 51.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 50.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 20.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.4 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 14 & 124.0 & 0.0 & 49.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 43.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 41.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 39.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.6 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 15 & 124.0 & 0.0 & 35.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 31.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 27.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 26.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 9.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.6 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 16 & 124.0 & 0.0 & 41.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 37.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 53.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 52.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.0 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.2 & 1.0 & NaN & NaN \\
# 17 & 124.0 & 0.0 & 40.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 40.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 27.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 28.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 12.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 12.9 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.2 & 1.0 & NaN & NaN \\
# 18 & 124.0 & 0.0 & 69.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 68.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 52.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 53.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 24.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.6 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 19 & 124.0 & 0.0 & 46.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 47.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 30.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 30.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.7 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 20 & 125.0 & 0.0 & 41.3 & 1.0 & NaN & NaN & 125.0 & 0.0 & 41.5 & 1.0 & NaN & NaN & 125.0 & 0.0 & 51.1 & 1.0 & NaN & NaN & 125.0 & 0.0 & 52.4 & 1.0 & NaN & NaN & 125.0 & 0.0 & 18.3 & 1.0 & NaN & NaN & 125.0 & 0.0 & 11.1 & 1.0 & NaN & NaN & 125.0 & 0.0 & 12.1 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 21 & 124.0 & 0.0 & 44.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 43.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 33.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 34.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.9 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 22 & 124.0 & 0.0 & 35.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 35.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 31.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 31.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.9 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 23 & 124.0 & 0.0 & 44.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 45.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 27.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 27.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.4 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 24 & 124.0 & 0.0 & 46.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 46.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 29.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 30.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 17.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.4 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 25 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 26 & 124.0 & 0.0 & 49.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 50.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 38.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 39.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 17.0 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 27 & 124.0 & 0.0 & 61.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 61.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 40.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 41.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 16.1 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 28 & 124.0 & 0.0 & 56.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 59.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 42.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 43.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.2 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 29 & 125.0 & 0.0 & 47.4 & 1.0 & NaN & NaN & 125.0 & 0.0 & 47.8 & 1.0 & NaN & NaN & 125.0 & 0.0 & 49.6 & 1.0 & NaN & NaN & 125.0 & 0.0 & 51.0 & 1.0 & NaN & NaN & 125.0 & 0.0 & 20.0 & 1.0 & NaN & NaN & 125.0 & 0.0 & 15.1 & 1.0 & NaN & NaN & 125.0 & 0.0 & 16.9 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 30 & 124.0 & 0.0 & 54.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 54.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 51.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 52.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.2 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 31 & 124.0 & 0.0 & 32.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 33.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.5 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 32 & 124.0 & 0.0 & 66.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 67.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 71.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 71.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 30.0 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 33 & 124.0 & 0.0 & 55.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 56.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 58.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 57.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 17.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.1 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 34 & 124.0 & 0.0 & 53.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 59.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 46.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 45.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.3 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 35 & 16.0 & 0.0 & 0.9 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.9 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.5 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.5 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 36 & 124.0 & 0.0 & 58.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 59.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 36.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 36.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.7 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 37 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.9 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 38 & 124.0 & 0.0 & 58.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 64.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 70.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 70.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 30.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 25.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.6 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 39 & 124.0 & 0.0 & 54.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 59.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 37.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 37.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 20.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 21.7 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 40 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 41 & 124.0 & 0.0 & 43.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 48.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 44.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 44.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 17.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.4 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.2 & 1.0 & NaN & NaN \\
# 42 & 124.0 & 0.0 & 91.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 100.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 57.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 57.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 16.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 24.4 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 43 & 124.0 & 0.0 & 47.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 52.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 49.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 49.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.7 & 1.0 & NaN & NaN & 120.0 & 0.0 & 0.1 & 1.0 & NaN & NaN \\
# 44 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 45 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 46 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 47 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 48 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 49 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 50 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 51 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 52 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 53 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 54 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.9 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 55 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 56 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.9 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 57 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 58 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 1.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 59 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 60 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 61 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.9 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 62 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 63 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 64 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 1.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 65 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 66 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 67 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.9 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 68 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 69 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 70 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 71 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 72 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.9 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 73 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 74 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 75 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 76 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 77 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 78 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 79 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 80 & 16.0 & 0.0 & 0.9 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.9 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.5 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.5 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 81 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 82 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 83 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 84 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 85 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 86 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 87 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 88 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 89 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 90 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 91 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 92 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 93 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 94 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 95 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 96 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 97 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 98 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 99 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 100 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 101 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 102 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 103 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 104 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 1.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 105 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 106 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 107 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 1.1 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 108 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 109 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 110 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 111 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 112 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 113 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 114 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 115 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 116 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 117 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 118 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 119 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 120 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 121 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 122 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 123 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 124 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 125 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 126 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 127 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 128 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 129 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 130 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 131 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 132 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 133 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 134 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 135 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 136 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 137 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 138 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 139 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 140 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 141 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 142 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 143 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 144 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 145 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 146 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 147 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 148 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 149 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 150 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 151 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 152 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 153 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 154 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 155 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 156 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 157 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 158 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 159 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 160 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 161 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 162 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 163 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 164 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 165 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 166 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 167 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 168 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 169 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 170 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 171 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 172 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 173 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 174 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 175 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 176 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 177 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.9 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 178 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 179 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 180 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 181 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 182 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 183 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 184 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 185 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 186 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 187 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.9 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 188 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 189 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 190 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 191 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 192 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 193 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 194 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.8 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 195 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 196 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 197 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 198 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 199 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.6 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# \bottomrule
# \end{tabular}

# %%
mip_concat = pd.DataFrame()
mip_concat = pd.concat([mip_concat, mip_internet_c0.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c0noclq.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c1.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c1noclq.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c2.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_misetc2.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_misetc3.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_miset.loc[200:200]], ignore_index=True)
mip_concat
# Out:
#                  vertice      bb      bs  gap     time   nodes    opt     tk
# 0       mip_fmaxc0_200_1  5092.0  5092.0  0.0  1694.27  1302.0  200.0  149.0  \
# 1  mip_fmaxc0noclq_200_1  5092.0  5092.0  0.0  1818.67  1460.0  200.0  149.0
# 2       mip_fmaxc1_200_1  5092.0  5092.0  0.0  1434.36  1344.0  200.0  149.0
# 3  mip_fmaxc1noclq_200_1  5092.0  5092.0  0.0  1469.66  1502.0  200.0  149.0
# 4       mip_fmaxc2_200_1  5092.0  5092.0  0.0   583.64  2260.0  200.0  149.0
# 5  mip_fmaxmisetc2_200_1  5092.0  5092.0  0.0   541.94   449.0  200.0  149.0
# 6  mip_fmaxmisetc3_200_1  5092.0  5092.0  0.0   607.62   480.0  200.0  149.0
# 7    mip_fmaxmiset_200_1  4931.0  4931.0  0.0     4.59   629.0  200.0  146.0
#
#      tmax
# 0   91.64
# 1  100.47
# 2   71.06
# 3   70.97
# 4   29.99
# 5   25.15
# 6   30.00
# 7    0.17

# %%
print(
mip_concat[[
    'vertice','bs','gap','time','opt','tk','tmax',
    ]].to_latex(index=False,float_format="%.1f")
)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# vertice & bs & gap & time & opt & tk & tmax \\
# \midrule
# mip_fmaxc0_200_1 & 5092.0 & 0.0 & 1694.3 & 200.0 & 149.0 & 91.6 \\
# mip_fmaxc0noclq_200_1 & 5092.0 & 0.0 & 1818.7 & 200.0 & 149.0 & 100.5 \\
# mip_fmaxc1_200_1 & 5092.0 & 0.0 & 1434.4 & 200.0 & 149.0 & 71.1 \\
# mip_fmaxc1noclq_200_1 & 5092.0 & 0.0 & 1469.7 & 200.0 & 149.0 & 71.0 \\
# mip_fmaxc2_200_1 & 5092.0 & 0.0 & 583.6 & 200.0 & 149.0 & 30.0 \\
# mip_fmaxmisetc2_200_1 & 5092.0 & 0.0 & 541.9 & 200.0 & 149.0 & 25.1 \\
# mip_fmaxmisetc3_200_1 & 5092.0 & 0.0 & 607.6 & 200.0 & 149.0 & 30.0 \\
# mip_fmaxmiset_200_1 & 4931.0 & 0.0 & 4.6 & 200.0 & 146.0 & 0.2 \\
# \bottomrule
# \end{tabular}
