# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="internet_graph"
method_="lp"
dim_=200
id_=1
ver_="fmax"

# %%
form_="fmaxc0"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','time','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'time':table['time'].sum(),
    'opt':table['opt'].sum(),
    'tk':table['bb'].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
lp_internet_c0 = table
lp_internet_c0

#print(lp_internet_c0[['vertice','bb','time','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#              vertice      bb   time    opt    tk
# 0                  0    93.3   0.41    1.0   NaN
# 1                  1    85.3   0.41    1.0   NaN
# 2                  2    93.0   0.42    1.0   NaN
# 3                  3    75.0   0.47    1.0   NaN
# 4                  4    67.0   0.41    1.0   NaN
# ..               ...     ...    ...    ...   ...
# 196              196     1.0   0.00    1.0   NaN
# 197              197     1.0   0.00    1.0   NaN
# 198              198     1.0   0.00    1.0   NaN
# 199              199     1.0   0.00    1.0   NaN
# 200  lp_fmaxc0_200_1  2655.1  16.70  200.0  93.8
#
# [201 rows x 5 columns]

# %%
form_="fmaxc0noclq"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','time','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'time':table['time'].sum(),
    'opt':table['opt'].sum(),
    'tk':table['bb'].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
lp_internet_c0noclq = table
lp_internet_c0noclq

#print(lp_internet_c0noclq[['vertice','bb','time','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                   vertice      bb   time    opt    tk
# 0                       0    93.3   0.40    1.0   NaN
# 1                       1    85.3   0.39    1.0   NaN
# 2                       2    93.0   0.38    1.0   NaN
# 3                       3    75.0   0.38    1.0   NaN
# 4                       4    67.0   0.39    1.0   NaN
# ..                    ...     ...    ...    ...   ...
# 196                   196     1.0   0.06    1.0   NaN
# 197                   197     1.0   0.05    1.0   NaN
# 198                   198     1.0   0.05    1.0   NaN
# 199                   199     1.0   0.06    1.0   NaN
# 200  lp_fmaxc0noclq_200_1  2655.1  24.72  200.0  93.8
#
# [201 rows x 5 columns]

# %%
form_="fmaxc1"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','time','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'time':table['time'].sum(),
    'opt':table['opt'].sum(),
    'tk':table['bb'].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
lp_internet_c1 = table
lp_internet_c1

#print(lp_internet_c1[['vertice','bb','time','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#              vertice      bb  time    opt    tk
# 0                  0    93.3  0.17    1.0   NaN
# 1                  1    85.3  0.17    1.0   NaN
# 2                  2    93.0  0.17    1.0   NaN
# 3                  3    75.0  0.18    1.0   NaN
# 4                  4    67.0  0.17    1.0   NaN
# ..               ...     ...   ...    ...   ...
# 196              196     1.0  0.00    1.0   NaN
# 197              197     1.0  0.00    1.0   NaN
# 198              198     1.0  0.00    1.0   NaN
# 199              199     1.0  0.00    1.0   NaN
# 200  lp_fmaxc1_200_1  2655.1  7.86  200.0  93.8
#
# [201 rows x 5 columns]

# %%
form_="fmaxc1noclq"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','time','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'time':table['time'].sum(),
    'opt':table['opt'].sum(),
    'tk':table['bb'].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
lp_internet_c1noclq = table
lp_internet_c1noclq

#print(lp_internet_c1noclq[['vertice','bb','time','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                   vertice      bb   time    opt    tk
# 0                       0    93.3   0.17    1.0   NaN
# 1                       1    85.3   0.17    1.0   NaN
# 2                       2    93.0   0.17    1.0   NaN
# 3                       3    75.0   0.18    1.0   NaN
# 4                       4    67.0   0.18    1.0   NaN
# ..                    ...     ...    ...    ...   ...
# 196                   196     1.0   0.03    1.0   NaN
# 197                   197     1.0   0.03    1.0   NaN
# 198                   198     1.0   0.03    1.0   NaN
# 199                   199     1.0   0.03    1.0   NaN
# 200  lp_fmaxc1noclq_200_1  2655.1  12.27  200.0  93.8
#
# [201 rows x 5 columns]

# %%
form_="fmaxc2"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','time','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'time':table['time'].sum(),
    'opt':table['opt'].sum(),
    'tk':table['bb'].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
lp_internet_c2 = table
lp_internet_c2

#print(lp_internet_c2[['vertice','bb','time','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#              vertice      bb  time    opt    tk
# 0                  0    73.0  0.10    1.0   NaN
# 1                  1    74.3  0.17    1.0   NaN
# 2                  2    75.3  0.12    1.0   NaN
# 3                  3    67.8  0.21    1.0   NaN
# 4                  4    58.8  0.23    1.0   NaN
# ..               ...     ...   ...    ...   ...
# 196              196     1.0  0.00    1.0   NaN
# 197              197     1.0  0.00    1.0   NaN
# 198              198     1.0  0.00    1.0   NaN
# 199              199     1.0  0.00    1.0   NaN
# 200  lp_fmaxc2_200_1  2357.9  7.71  200.0  75.3
#
# [201 rows x 5 columns]

# %%
form_="fmaxmisetc2"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','time','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'time':table['time'].sum(),
    'opt':table['opt'].sum(),
    'tk':table['bb'].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
lp_internet_misetc2 = table
lp_internet_misetc2

#print(lp_internet_misetc2[['vertice','bb','time','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                   vertice      bb  time    opt     tk
# 0                       0   114.3  0.16    1.0    NaN
# 1                       1   102.9  0.22    1.0    NaN
# 2                       2   113.5  0.26    1.0    NaN
# 3                       3    89.5  0.23    1.0    NaN
# 4                       4    69.4  0.20    1.0    NaN
# ..                    ...     ...   ...    ...    ...
# 196                   196     1.0  0.00    1.0    NaN
# 197                   197     1.0  0.00    1.0    NaN
# 198                   198     1.0  0.00    1.0    NaN
# 199                   199     1.0  0.00    1.0    NaN
# 200  lp_fmaxmisetc2_200_1  2918.3  9.49  200.0  114.3
#
# [201 rows x 5 columns]

# %%
form_="fmaxmisetc3"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','time','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'time':table['time'].sum(),
    'opt':table['opt'].sum(),
    'tk':table['bb'].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
lp_internet_misetc3 = table
lp_internet_misetc3

#print(lp_internet_misetc3[['vertice','bb','time','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                   vertice      bb  time    opt     tk
# 0                       0   114.3  0.18    1.0    NaN
# 1                       1   102.8  0.25    1.0    NaN
# 2                       2   113.5  0.21    1.0    NaN
# 3                       3    89.5  0.38    1.0    NaN
# 4                       4    69.4  0.38    1.0    NaN
# ..                    ...     ...   ...    ...    ...
# 196                   196     1.0  0.00    1.0    NaN
# 197                   197     1.0  0.00    1.0    NaN
# 198                   198     1.0  0.00    1.0    NaN
# 199                   199     1.0  0.00    1.0    NaN
# 200  lp_fmaxmisetc3_200_1  2913.0  8.56  200.0  114.3
#
# [201 rows x 5 columns]

# %%
form_="fmaxmiset"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','time','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'time':table['time'].sum(),
    'opt':table['opt'].sum(),
    'tk':table['bb'].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
lp_internet_miset = table
lp_internet_miset

#print(lp_internet_miset[['vertice','bb','time','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                 vertice      bb  time    opt    tk
# 0                     0    93.3   0.0    1.0   NaN
# 1                     1    79.3   0.0    1.0   NaN
# 2                     2    94.9   0.0    1.0   NaN
# 3                     3    57.9   0.0    1.0   NaN
# 4                     4    39.4   0.0    1.0   NaN
# ..                  ...     ...   ...    ...   ...
# 196                 196     1.0   0.0    1.0   NaN
# 197                 197     1.0   0.0    1.0   NaN
# 198                 198     1.0   0.0    1.0   NaN
# 199                 199     1.0   0.0    1.0   NaN
# 200  lp_fmaxmiset_200_1  1693.9   0.0  200.0  94.9
#
# [201 rows x 5 columns]

# %%
lp_merge = pd.DataFrame()

lp_merge = pd.merge(
    lp_internet_c0, lp_internet_c0noclq,
    on=['vertice'], 
    suffixes=("", "_b"),
    )

lp_merge = pd.merge(
    lp_merge, lp_internet_c1,
    on=['vertice'], 
    suffixes=("", "_c"),
    )

lp_merge = pd.merge(
    lp_merge, lp_internet_c1noclq,
    on=['vertice'], 
    suffixes=("", "_d"),
    )

lp_merge = pd.merge(
    lp_merge, lp_internet_c2,
    on=['vertice'], 
    suffixes=("", "_e"),
    )

lp_merge = pd.merge(
    lp_merge, lp_internet_misetc2,
    on=['vertice'], 
    suffixes=("", "_f"),
    )

lp_merge = pd.merge(
    lp_merge, lp_internet_misetc3,
    on=['vertice'], 
    suffixes=("", "_g"),
    )

lp_merge = pd.merge(
    lp_merge, lp_internet_miset,
    on=['vertice'], 
    suffixes=("", "_h"),
    )

lp_merge
# Out:
#     vertice    bb  time  opt  tk  bb_b  time_b  opt_b  tk_b  bb_c  ...  opt_f
# 0         0  93.3  0.41  1.0 NaN  93.3    0.40    1.0   NaN  93.3  ...    1.0  \
# 1         1  85.3  0.41  1.0 NaN  85.3    0.39    1.0   NaN  85.3  ...    1.0
# 2         2  93.0  0.42  1.0 NaN  93.0    0.38    1.0   NaN  93.0  ...    1.0
# 3         3  75.0  0.47  1.0 NaN  75.0    0.38    1.0   NaN  75.0  ...    1.0
# 4         4  67.0  0.41  1.0 NaN  67.0    0.39    1.0   NaN  67.0  ...    1.0
# ..      ...   ...   ...  ...  ..   ...     ...    ...   ...   ...  ...    ...
# 195     195   1.0  0.00  1.0 NaN   1.0    0.05    1.0   NaN   1.0  ...    1.0
# 196     196   1.0  0.00  1.0 NaN   1.0    0.06    1.0   NaN   1.0  ...    1.0
# 197     197   1.0  0.00  1.0 NaN   1.0    0.05    1.0   NaN   1.0  ...    1.0
# 198     198   1.0  0.00  1.0 NaN   1.0    0.05    1.0   NaN   1.0  ...    1.0
# 199     199   1.0  0.00  1.0 NaN   1.0    0.06    1.0   NaN   1.0  ...    1.0
#
#      tk_f   bb_g  time_g  opt_g  tk_g  bb_h  time_h  opt_h  tk_h
# 0     NaN  114.3    0.18    1.0   NaN  93.3     0.0    1.0   NaN
# 1     NaN  102.8    0.25    1.0   NaN  79.3     0.0    1.0   NaN
# 2     NaN  113.5    0.21    1.0   NaN  94.9     0.0    1.0   NaN
# 3     NaN   89.5    0.38    1.0   NaN  57.9     0.0    1.0   NaN
# 4     NaN   69.4    0.38    1.0   NaN  39.4     0.0    1.0   NaN
# ..    ...    ...     ...    ...   ...   ...     ...    ...   ...
# 195   NaN    1.0    0.00    1.0   NaN   1.0     0.0    1.0   NaN
# 196   NaN    1.0    0.00    1.0   NaN   1.0     0.0    1.0   NaN
# 197   NaN    1.0    0.00    1.0   NaN   1.0     0.0    1.0   NaN
# 198   NaN    1.0    0.00    1.0   NaN   1.0     0.0    1.0   NaN
# 199   NaN    1.0    0.00    1.0   NaN   1.0     0.0    1.0   NaN
#
# [200 rows x 33 columns]

# %%
lp_merge[[
    'vertice',
    'bb','tk',
    'bb_b','tk_b',
    'bb_c','tk_c',
    'bb_d','tk_d',
    'bb_e','tk_e',
    'bb_f','tk_f',
    'bb_g','tk_g',
    'bb_h','tk_h',
    ]]
# Out:
#     vertice    bb  tk  bb_b  tk_b  bb_c  tk_c  bb_d  tk_d  bb_e  tk_e   bb_f
# 0         0  93.3 NaN  93.3   NaN  93.3   NaN  93.3   NaN  73.0   NaN  114.3  \
# 1         1  85.3 NaN  85.3   NaN  85.3   NaN  85.3   NaN  74.3   NaN  102.9
# 2         2  93.0 NaN  93.0   NaN  93.0   NaN  93.0   NaN  75.3   NaN  113.5
# 3         3  75.0 NaN  75.0   NaN  75.0   NaN  75.0   NaN  67.8   NaN   89.5
# 4         4  67.0 NaN  67.0   NaN  67.0   NaN  67.0   NaN  58.8   NaN   69.4
# ..      ...   ...  ..   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 195     195   1.0 NaN   1.0   NaN   1.0   NaN   1.0   NaN   1.0   NaN    1.0
# 196     196   1.0 NaN   1.0   NaN   1.0   NaN   1.0   NaN   1.0   NaN    1.0
# 197     197   1.0 NaN   1.0   NaN   1.0   NaN   1.0   NaN   1.0   NaN    1.0
# 198     198   1.0 NaN   1.0   NaN   1.0   NaN   1.0   NaN   1.0   NaN    1.0
# 199     199   1.0 NaN   1.0   NaN   1.0   NaN   1.0   NaN   1.0   NaN    1.0
#
#      tk_f   bb_g  tk_g  bb_h  tk_h
# 0     NaN  114.3   NaN  93.3   NaN
# 1     NaN  102.8   NaN  79.3   NaN
# 2     NaN  113.5   NaN  94.9   NaN
# 3     NaN   89.5   NaN  57.9   NaN
# 4     NaN   69.4   NaN  39.4   NaN
# ..    ...    ...   ...   ...   ...
# 195   NaN    1.0   NaN   1.0   NaN
# 196   NaN    1.0   NaN   1.0   NaN
# 197   NaN    1.0   NaN   1.0   NaN
# 198   NaN    1.0   NaN   1.0   NaN
# 199   NaN    1.0   NaN   1.0   NaN
#
# [200 rows x 17 columns]

# %%
#print(result[['vertice','bb','bb_fmax','bb_miset','bb_neighb']].to_latex(index=False,float_format="%.1f"))

with open('../result/fmax_lp_internet_200_1.tex', 'w') as tf:
     tf.write(
          lp_merge[[
               'vertice',
               'bb','tk',
               'bb_b','tk_b',
               'bb_c','tk_c',
               'bb_d','tk_d',
               'bb_e','tk_e',
               'bb_f','tk_f',
               'bb_g','tk_g',
               'bb_h','tk_h',
    ]].to_latex(index=False,float_format="%.1f")
)

# %%
lp_concat = pd.DataFrame()
lp_concat = pd.concat([lp_concat,lp_internet_c0.loc[200:200]], ignore_index= True)
lp_concat = pd.concat([lp_concat,lp_internet_c0noclq.loc[200:200]], ignore_index= True)
lp_concat = pd.concat([lp_concat,lp_internet_c1.loc[200:200]], ignore_index= True)
lp_concat = pd.concat([lp_concat,lp_internet_c1noclq.loc[200:200]], ignore_index= True)
lp_concat = pd.concat([lp_concat,lp_internet_c2.loc[200:200]], ignore_index= True)
lp_concat = pd.concat([lp_concat,lp_internet_misetc2.loc[200:200]], ignore_index= True)
lp_concat = pd.concat([lp_concat,lp_internet_misetc3.loc[200:200]], ignore_index= True)
lp_concat = pd.concat([lp_concat,lp_internet_miset.loc[200:200]], ignore_index= True)
lp_concat
# Out:
#                 vertice      bb   time    opt     tk
# 0       lp_fmaxc0_200_1  2655.1  16.70  200.0   93.8
# 1  lp_fmaxc0noclq_200_1  2655.1  24.72  200.0   93.8
# 2       lp_fmaxc1_200_1  2655.1   7.86  200.0   93.8
# 3  lp_fmaxc1noclq_200_1  2655.1  12.27  200.0   93.8
# 4       lp_fmaxc2_200_1  2357.9   7.71  200.0   75.3
# 5  lp_fmaxmisetc2_200_1  2918.3   9.49  200.0  114.3
# 6  lp_fmaxmisetc3_200_1  2913.0   8.56  200.0  114.3
# 7    lp_fmaxmiset_200_1  1693.9   0.00  200.0   94.9

# %%
print(
lp_concat[['vertice','bb','time','tk']].to_latex(index=False,float_format="%.1f")
)
# Out:
# \begin{tabular}{lrrr}
# \toprule
# vertice & bb & time & tk \\
# \midrule
# lp_fmaxc0_200_1 & 2655.1 & 16.7 & 93.8 \\
# lp_fmaxc0noclq_200_1 & 2655.1 & 24.7 & 93.8 \\
# lp_fmaxc1_200_1 & 2655.1 & 7.9 & 93.8 \\
# lp_fmaxc1noclq_200_1 & 2655.1 & 12.3 & 93.8 \\
# lp_fmaxc2_200_1 & 2357.9 & 7.7 & 75.3 \\
# lp_fmaxmisetc2_200_1 & 2918.3 & 9.5 & 114.3 \\
# lp_fmaxmisetc3_200_1 & 2913.0 & 8.6 & 114.3 \\
# lp_fmaxmiset_200_1 & 1693.9 & 0.0 & 94.9 \\
# \bottomrule
# \end{tabular}
