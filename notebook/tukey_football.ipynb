# %%
# %matplotlib inline

# %%
import urllib.request
import io
import zipfile

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import gurobipy as gp
from gurobipy import GRB

import igraph as ig

# %%
url = "http://www-personal.umich.edu/~mejn/netdata/football.zip"

sock = urllib.request.urlopen(url)  # open URL
s = io.BytesIO(sock.read())  # read into BytesIO "file"
sock.close()

zf = zipfile.ZipFile(s)  # zipfile object
txt = zf.read("football.txt").decode()  # read info file
gml = zf.read("football.gml").decode()  # read gml data
# throw away bogus first line with # from mejn files
gml = gml.split("\n")[1:]
G = nx.parse_gml(gml)  # parse gml data

#print(txt)
# print degree for each team - number of games
for n, d in G.degree():
    print(f"{n:20} {d:2}")

#options = {"node_color": "black", "node_size": 50, "linewidths": 0, "width": 0.1}

#pos = nx.spring_layout(G, seed=1969)  # Seed for reproducible layout
#nx.draw(G, pos, **options)
#plt.show()
# Out:
# BrighamYoung         12
# FloridaState         12
# Iowa                 12
# KansasState          12
# NewMexico            11
# TexasTech            12
# PennState            12
# SouthernCalifornia   12
# ArizonaState         11
# SanDiegoState        11
# Baylor               10
# NorthTexas           10
# NorthernIllinois     10
# Northwestern         11
# WesternMichigan      10
# Wisconsin            12
# Wyoming              11
# Auburn               11
# Akron                11
# VirginiaTech         11
# Alabama              11
# UCLA                 11
# Arizona              11
# Utah                 11
# ArkansasState        10
# NorthCarolinaState   11
# BallState            10
# Florida              11
# BoiseState            9
# BostonCollege        11
# WestVirginia         11
# BowlingGreenState    11
# Michigan             11
# Virginia             10
# Buffalo              11
# Syracuse             11
# CentralFlorida        8
# GeorgiaTech          11
# CentralMichigan      11
# Purdue               11
# Colorado             11
# ColoradoState        10
# Connecticut           7
# EasternMichigan      11
# EastCarolina         11
# Duke                 11
# FresnoState          11
# OhioState            11
# Houston              11
# Rice                 11
# Idaho                 9
# Washington           11
# Kansas               10
# SouthernMethodist    12
# Kent                 10
# Pittsburgh           11
# Kentucky             10
# Louisville           10
# LouisianaTech        10
# LouisianaMonroe       8
# Minnesota            11
# MiamiOhio            11
# Vanderbilt           11
# MiddleTennesseeState  9
# Illinois             11
# MississippiState     11
# Memphis              11
# Nevada               12
# Oregon               11
# NewMexicoState       11
# SouthCarolina        11
# Ohio                 10
# IowaState            11
# SanJoseState         11
# Nebraska             11
# SouthernMississippi  10
# Tennessee            11
# Stanford             11
# WashingtonState      11
# Temple               11
# Navy                 11
# TexasA&M             11
# NotreDame            11
# TexasElPaso          11
# Oklahoma             11
# Toledo                9
# Tulane               11
# Mississippi          11
# Tulsa                12
# NorthCarolina        11
# UtahState             9
# Army                 11
# Cincinnati           11
# AirForce             10
# Rutgers              10
# Georgia              10
# LouisianaState       10
# LouisianaLafayette    8
# Texas                11
# Marshall             10
# MichiganState        11
# MiamiFlorida         10
# Missouri             10
# Clemson              10
# NevadaLasVegas       12
# WakeForest           10
# Indiana              11
# OklahomaState        10
# OregonState          10
# Maryland             11
# TexasChristian       11
# California           11
# AlabamaBirmingham    10
# Arkansas             10
# Hawaii               11

# %%
nx.is_connected(G)
# Out:
# True

# %%
print(list(G.nodes))
# Out:
# ['BrighamYoung', 'FloridaState', 'Iowa', 'KansasState', 'NewMexico', 'TexasTech', 'PennState', 'SouthernCalifornia', 'ArizonaState', 'SanDiegoState', 'Baylor', 'NorthTexas', 'NorthernIllinois', 'Northwestern', 'WesternMichigan', 'Wisconsin', 'Wyoming', 'Auburn', 'Akron', 'VirginiaTech', 'Alabama', 'UCLA', 'Arizona', 'Utah', 'ArkansasState', 'NorthCarolinaState', 'BallState', 'Florida', 'BoiseState', 'BostonCollege', 'WestVirginia', 'BowlingGreenState', 'Michigan', 'Virginia', 'Buffalo', 'Syracuse', 'CentralFlorida', 'GeorgiaTech', 'CentralMichigan', 'Purdue', 'Colorado', 'ColoradoState', 'Connecticut', 'EasternMichigan', 'EastCarolina', 'Duke', 'FresnoState', 'OhioState', 'Houston', 'Rice', 'Idaho', 'Washington', 'Kansas', 'SouthernMethodist', 'Kent', 'Pittsburgh', 'Kentucky', 'Louisville', 'LouisianaTech', 'LouisianaMonroe', 'Minnesota', 'MiamiOhio', 'Vanderbilt', 'MiddleTennesseeState', 'Illinois', 'MississippiState', 'Memphis', 'Nevada', 'Oregon', 'NewMexicoState', 'SouthCarolina', 'Ohio', 'IowaState', 'SanJoseState', 'Nebraska', 'SouthernMississippi', 'Tennessee', 'Stanford', 'WashingtonState', 'Temple', 'Navy', 'TexasA&M', 'NotreDame', 'TexasElPaso', 'Oklahoma', 'Toledo', 'Tulane', 'Mississippi', 'Tulsa', 'NorthCarolina', 'UtahState', 'Army', 'Cincinnati', 'AirForce', 'Rutgers', 'Georgia', 'LouisianaState', 'LouisianaLafayette', 'Texas', 'Marshall', 'MichiganState', 'MiamiFlorida', 'Missouri', 'Clemson', 'NevadaLasVegas', 'WakeForest', 'Indiana', 'OklahomaState', 'OregonState', 'Maryland', 'TexasChristian', 'California', 'AlabamaBirmingham', 'Arkansas', 'Hawaii']

# %%
len(list(G.nodes))
# Out:
# 115

# %%
list(G.adj['Iowa'])  # or list(G.neighbors(1))
# Out:
# ['KansasState',
#  'PennState',
#  'Northwestern',
#  'WesternMichigan',
#  'Wisconsin',
#  'OhioState',
#  'Minnesota',
#  'Illinois',
#  'IowaState',
#  'Nebraska',
#  'MichiganState',
#  'Indiana']

# %%
G.degree['Iowa']  # the number of edges incident to 1
# Out:
# 12

# %%
nx.maximal_independent_set(G)
# Out:
# ['SanJoseState',
#  'MichiganState',
#  'Pittsburgh',
#  'BallState',
#  'Duke',
#  'Texas',
#  'Arkansas',
#  'ArizonaState',
#  'OregonState',
#  'Louisville',
#  'ArkansasState',
#  'Minnesota',
#  'MiddleTennesseeState',
#  'Akron',
#  'BrighamYoung',
#  'Navy',
#  'IowaState']

# %%
N = nx.neighbors(G,'Iowa')
for i in N:
    print(i)
# Out:
# KansasState
# PennState
# Northwestern
# WesternMichigan
# Wisconsin
# OhioState
# Minnesota
# Illinois
# IowaState
# Nebraska
# MichiganState
# Indiana

# %%
path = nx.single_source_dijkstra_path(G, 'Iowa')
path['KansasState']
# Out:
# ['Iowa', 'KansasState']

# %%
nx.draw(G, with_labels=True)
plt.show()

# %%
N = nx.number_of_nodes(G)
M = nx.number_of_edges(G)

arc = []
#dm=np.array(G.edges)
#dm = np.zeros((G.nodes,G.nodes), dtype=int)
#dm = [tuple(item) for item in G.edges]
#print(dm)

arc = [e for e in G.edges]
#dm = np.zeros((arc), dtype=int)

dm = np.array(np.array(arc))

p = nx.shortest_path(G)

#type(p)


#for i,j in p.items():
#    print(i)
#    print(j)

#    print(p[i,j])
#for i in G:
#    for j in G:
#        print(p[i,j])
#print(p)
#for i in G.edges:
#        print(len(p[i])-1)
#        dm[i][j] = len(p[i][j])-1

#for i in G.edges:
#    print(dm[i])
#    for j in G:
#        print(dm[i][j])
        #print(len(p[i][j])-1)
        #dm[i][j] = len(p[i][j])-1
#    for j in G:
#        dm[i][j] = len(p[i][j])
# Out:
# BrighamYoung
# {'BrighamYoung': ['BrighamYoung'], 'FloridaState': ['BrighamYoung', 'FloridaState'], 'NewMexico': ['BrighamYoung', 'NewMexico'], 'SanDiegoState': ['BrighamYoung', 'SanDiegoState'], 'Wyoming': ['BrighamYoung', 'Wyoming'], 'Utah': ['BrighamYoung', 'Utah'], 'Virginia': ['BrighamYoung', 'Virginia'], 'Syracuse': ['BrighamYoung', 'Syracuse'], 'ColoradoState': ['BrighamYoung', 'ColoradoState'], 'MississippiState': ['BrighamYoung', 'MississippiState'], 'UtahState': ['BrighamYoung', 'UtahState'], 'AirForce': ['BrighamYoung', 'AirForce'], 'NevadaLasVegas': ['BrighamYoung', 'NevadaLasVegas'], 'NorthCarolinaState': ['BrighamYoung', 'FloridaState', 'NorthCarolinaState'], 'Florida': ['BrighamYoung', 'FloridaState', 'Florida'], 'GeorgiaTech': ['BrighamYoung', 'FloridaState', 'GeorgiaTech'], 'Duke': ['BrighamYoung', 'FloridaState', 'Duke'], 'Louisville': ['BrighamYoung', 'FloridaState', 'Louisville'], 'NorthCarolina': ['BrighamYoung', 'FloridaState', 'NorthCarolina'], 'MiamiFlorida': ['BrighamYoung', 'FloridaState', 'MiamiFlorida'], 'Clemson': ['BrighamYoung', 'FloridaState', 'Clemson'], 'WakeForest': ['BrighamYoung', 'FloridaState', 'WakeForest'], 'Maryland': ['BrighamYoung', 'FloridaState', 'Maryland'], 'TexasTech': ['BrighamYoung', 'NewMexico', 'TexasTech'], 'BoiseState': ['BrighamYoung', 'NewMexico', 'BoiseState'], 'NewMexicoState': ['BrighamYoung', 'NewMexico', 'NewMexicoState'], 'OregonState': ['BrighamYoung', 'NewMexico', 'OregonState'], 'ArizonaState': ['BrighamYoung', 'SanDiegoState', 'ArizonaState'], 'Arizona': ['BrighamYoung', 'SanDiegoState', 'Arizona'], 'Illinois': ['BrighamYoung', 'SanDiegoState', 'Illinois'], 'Auburn': ['BrighamYoung', 'Wyoming', 'Auburn'], 'CentralMichigan': ['BrighamYoung', 'Wyoming', 'CentralMichigan'], 'Nevada': ['BrighamYoung', 'Wyoming', 'Nevada'], 'TexasA&M': ['BrighamYoung', 'Wyoming', 'TexasA&M'], 'WashingtonState': ['BrighamYoung', 'Utah', 'WashingtonState'], 'California': ['BrighamYoung', 'Utah', 'California'], 'VirginiaTech': ['BrighamYoung', 'Virginia', 'VirginiaTech'], 'BostonCollege': ['BrighamYoung', 'Syracuse', 'BostonCollege'], 'WestVirginia': ['BrighamYoung', 'Syracuse', 'WestVirginia'], 'Buffalo': ['BrighamYoung', 'Syracuse', 'Buffalo'], 'EastCarolina': ['BrighamYoung', 'Syracuse', 'EastCarolina'], 'Pittsburgh': ['BrighamYoung', 'Syracuse', 'Pittsburgh'], 'Temple': ['BrighamYoung', 'Syracuse', 'Temple'], 'Cincinnati': ['BrighamYoung', 'Syracuse', 'Cincinnati'], 'Rutgers': ['BrighamYoung', 'Syracuse', 'Rutgers'], 'Colorado': ['BrighamYoung', 'ColoradoState', 'Colorado'], 'Alabama': ['BrighamYoung', 'MississippiState', 'Alabama'], 'Kentucky': ['BrighamYoung', 'MississippiState', 'Kentucky'], 'MiddleTennesseeState': ['BrighamYoung', 'MississippiState', 'MiddleTennesseeState'], 'Memphis': ['BrighamYoung', 'MississippiState', 'Memphis'], 'SouthCarolina': ['BrighamYoung', 'MississippiState', 'SouthCarolina'], 'Mississippi': ['BrighamYoung', 'MississippiState', 'Mississippi'], 'LouisianaState': ['BrighamYoung', 'MississippiState', 'LouisianaState'], 'Arkansas': ['BrighamYoung', 'MississippiState', 'Arkansas'], 'NorthTexas': ['BrighamYoung', 'UtahState', 'NorthTexas'], 'ArkansasState': ['BrighamYoung', 'UtahState', 'ArkansasState'], 'Idaho': ['BrighamYoung', 'UtahState', 'Idaho'], 'Navy': ['BrighamYoung', 'AirForce', 'Navy'], 'NotreDame': ['BrighamYoung', 'AirForce', 'NotreDame'], 'Army': ['BrighamYoung', 'AirForce', 'Army'], 'IowaState': ['BrighamYoung', 'NevadaLasVegas', 'IowaState'], 'Hawaii': ['BrighamYoung', 'NevadaLasVegas', 'Hawaii'], 'SouthernMethodist': ['BrighamYoung', 'FloridaState', 'NorthCarolinaState', 'SouthernMethodist'], 'Indiana': ['BrighamYoung', 'FloridaState', 'NorthCarolinaState', 'Indiana'], 'BallState': ['BrighamYoung', 'FloridaState', 'Florida', 'BallState'], 'Vanderbilt': ['BrighamYoung', 'FloridaState', 'Florida', 'Vanderbilt'], 'Tennessee': ['BrighamYoung', 'FloridaState', 'Florida', 'Tennessee'], 'Georgia': ['BrighamYoung', 'FloridaState', 'Florida', 'Georgia'], 'Central ...
# FloridaState
# {'FloridaState': ['FloridaState'], 'BrighamYoung': ['FloridaState', 'BrighamYoung'], 'NorthCarolinaState': ['FloridaState', 'NorthCarolinaState'], 'Florida': ['FloridaState', 'Florida'], 'Virginia': ['FloridaState', 'Virginia'], 'GeorgiaTech': ['FloridaState', 'GeorgiaTech'], 'Duke': ['FloridaState', 'Duke'], 'Louisville': ['FloridaState', 'Louisville'], 'NorthCarolina': ['FloridaState', 'NorthCarolina'], 'MiamiFlorida': ['FloridaState', 'MiamiFlorida'], 'Clemson': ['FloridaState', 'Clemson'], 'WakeForest': ['FloridaState', 'WakeForest'], 'Maryland': ['FloridaState', 'Maryland'], 'NewMexico': ['FloridaState', 'BrighamYoung', 'NewMexico'], 'SanDiegoState': ['FloridaState', 'BrighamYoung', 'SanDiegoState'], 'Wyoming': ['FloridaState', 'BrighamYoung', 'Wyoming'], 'Utah': ['FloridaState', 'BrighamYoung', 'Utah'], 'Syracuse': ['FloridaState', 'BrighamYoung', 'Syracuse'], 'ColoradoState': ['FloridaState', 'BrighamYoung', 'ColoradoState'], 'MississippiState': ['FloridaState', 'BrighamYoung', 'MississippiState'], 'UtahState': ['FloridaState', 'BrighamYoung', 'UtahState'], 'AirForce': ['FloridaState', 'BrighamYoung', 'AirForce'], 'NevadaLasVegas': ['FloridaState', 'BrighamYoung', 'NevadaLasVegas'], 'ArkansasState': ['FloridaState', 'NorthCarolinaState', 'ArkansasState'], 'SouthernMethodist': ['FloridaState', 'NorthCarolinaState', 'SouthernMethodist'], 'Indiana': ['FloridaState', 'NorthCarolinaState', 'Indiana'], 'Auburn': ['FloridaState', 'Florida', 'Auburn'], 'BallState': ['FloridaState', 'Florida', 'BallState'], 'Kentucky': ['FloridaState', 'Florida', 'Kentucky'], 'Vanderbilt': ['FloridaState', 'Florida', 'Vanderbilt'], 'MiddleTennesseeState': ['FloridaState', 'Florida', 'MiddleTennesseeState'], 'SouthCarolina': ['FloridaState', 'Florida', 'SouthCarolina'], 'Tennessee': ['FloridaState', 'Florida', 'Tennessee'], 'Georgia': ['FloridaState', 'Florida', 'Georgia'], 'LouisianaState': ['FloridaState', 'Florida', 'LouisianaState'], 'VirginiaTech': ['FloridaState', 'Virginia', 'VirginiaTech'], 'CentralFlorida': ['FloridaState', 'GeorgiaTech', 'CentralFlorida'], 'Navy': ['FloridaState', 'GeorgiaTech', 'Navy'], 'Northwestern': ['FloridaState', 'Duke', 'Northwestern'], 'EastCarolina': ['FloridaState', 'Duke', 'EastCarolina'], 'Connecticut': ['FloridaState', 'Louisville', 'Connecticut'], 'Houston': ['FloridaState', 'Louisville', 'Houston'], 'SouthernMississippi': ['FloridaState', 'Louisville', 'SouthernMississippi'], 'Tulane': ['FloridaState', 'Louisville', 'Tulane'], 'Army': ['FloridaState', 'Louisville', 'Army'], 'Cincinnati': ['FloridaState', 'Louisville', 'Cincinnati'], 'AlabamaBirmingham': ['FloridaState', 'Louisville', 'AlabamaBirmingham'], 'Pittsburgh': ['FloridaState', 'NorthCarolina', 'Pittsburgh'], 'Tulsa': ['FloridaState', 'NorthCarolina', 'Tulsa'], 'Marshall': ['FloridaState', 'NorthCarolina', 'Marshall'], 'BostonCollege': ['FloridaState', 'MiamiFlorida', 'BostonCollege'], 'WestVirginia': ['FloridaState', 'MiamiFlorida', 'WestVirginia'], 'Washington': ['FloridaState', 'MiamiFlorida', 'Washington'], 'LouisianaTech': ['FloridaState', 'MiamiFlorida', 'LouisianaTech'], 'Temple': ['FloridaState', 'MiamiFlorida', 'Temple'], 'Rutgers': ['FloridaState', 'MiamiFlorida', 'Rutgers'], 'Missouri': ['FloridaState', 'Clemson', 'Missouri'], 'TexasTech': ['FloridaState', 'BrighamYoung', 'NewMexico', 'TexasTech'], 'BoiseState': ['FloridaState', 'BrighamYoung', 'NewMexico', 'BoiseState'], 'NewMexicoState': ['FloridaState', 'BrighamYoung', 'NewMexico', 'NewMexicoState'], 'OregonState': ['FloridaState', 'BrighamYoung', 'NewMexico', 'OregonState'], 'ArizonaState': ['FloridaState', 'BrighamYoung', 'SanDiegoState', 'ArizonaState'], 'Arizona': ['FloridaState', 'BrighamYoung', 'SanDiegoState', 'Arizona'], 'Illinois': ['FloridaState', 'BrighamYoung', 'SanDiegoState', 'Illinois'], 'CentralMichigan': ['FloridaState', 'BrighamYoung', 'Wyoming', 'CentralMichigan'], 'Nevada': ['FloridaState', 'BrighamYoung', 'Wyoming', 'Nevada'], 'TexasA&M': ['FloridaState', 'Brigh ...
# Iowa
# {'Iowa': ['Iowa'], 'KansasState': ['Iowa', 'KansasState'], 'PennState': ['Iowa', 'PennState'], 'Northwestern': ['Iowa', 'Northwestern'], 'WesternMichigan': ['Iowa', 'WesternMichigan'], 'Wisconsin': ['Iowa', 'Wisconsin'], 'OhioState': ['Iowa', 'OhioState'], 'Minnesota': ['Iowa', 'Minnesota'], 'Illinois': ['Iowa', 'Illinois'], 'IowaState': ['Iowa', 'IowaState'], 'Nebraska': ['Iowa', 'Nebraska'], 'MichiganState': ['Iowa', 'MichiganState'], 'Indiana': ['Iowa', 'Indiana'], 'TexasTech': ['Iowa', 'KansasState', 'TexasTech'], 'NorthTexas': ['Iowa', 'KansasState', 'NorthTexas'], 'BallState': ['Iowa', 'KansasState', 'BallState'], 'Colorado': ['Iowa', 'KansasState', 'Colorado'], 'Kansas': ['Iowa', 'KansasState', 'Kansas'], 'LouisianaTech': ['Iowa', 'KansasState', 'LouisianaTech'], 'TexasA&M': ['Iowa', 'KansasState', 'TexasA&M'], 'Oklahoma': ['Iowa', 'KansasState', 'Oklahoma'], 'Missouri': ['Iowa', 'KansasState', 'Missouri'], 'SouthernCalifornia': ['Iowa', 'PennState', 'SouthernCalifornia'], 'Michigan': ['Iowa', 'PennState', 'Michigan'], 'Purdue': ['Iowa', 'PennState', 'Purdue'], 'Pittsburgh': ['Iowa', 'PennState', 'Pittsburgh'], 'Toledo': ['Iowa', 'PennState', 'Toledo'], 'NorthernIllinois': ['Iowa', 'Northwestern', 'NorthernIllinois'], 'Duke': ['Iowa', 'Northwestern', 'Duke'], 'TexasChristian': ['Iowa', 'Northwestern', 'TexasChristian'], 'CentralMichigan': ['Iowa', 'WesternMichigan', 'CentralMichigan'], 'EasternMichigan': ['Iowa', 'WesternMichigan', 'EasternMichigan'], 'Kent': ['Iowa', 'WesternMichigan', 'Kent'], 'Ohio': ['Iowa', 'WesternMichigan', 'Ohio'], 'Marshall': ['Iowa', 'WesternMichigan', 'Marshall'], 'Oregon': ['Iowa', 'Wisconsin', 'Oregon'], 'Cincinnati': ['Iowa', 'Wisconsin', 'Cincinnati'], 'Hawaii': ['Iowa', 'Wisconsin', 'Hawaii'], 'Arizona': ['Iowa', 'OhioState', 'Arizona'], 'FresnoState': ['Iowa', 'OhioState', 'FresnoState'], 'MiamiOhio': ['Iowa', 'OhioState', 'MiamiOhio'], 'Baylor': ['Iowa', 'Minnesota', 'Baylor'], 'LouisianaMonroe': ['Iowa', 'Minnesota', 'LouisianaMonroe'], 'SanDiegoState': ['Iowa', 'Illinois', 'SanDiegoState'], 'MiddleTennesseeState': ['Iowa', 'Illinois', 'MiddleTennesseeState'], 'California': ['Iowa', 'Illinois', 'California'], 'NevadaLasVegas': ['Iowa', 'IowaState', 'NevadaLasVegas'], 'OklahomaState': ['Iowa', 'IowaState', 'OklahomaState'], 'SanJoseState': ['Iowa', 'Nebraska', 'SanJoseState'], 'NotreDame': ['Iowa', 'Nebraska', 'NotreDame'], 'NorthCarolinaState': ['Iowa', 'Indiana', 'NorthCarolinaState'], 'Kentucky': ['Iowa', 'Indiana', 'Kentucky'], 'NewMexico': ['Iowa', 'KansasState', 'TexasTech', 'NewMexico'], 'UtahState': ['Iowa', 'KansasState', 'TexasTech', 'UtahState'], 'LouisianaLafayette': ['Iowa', 'KansasState', 'TexasTech', 'LouisianaLafayette'], 'Texas': ['Iowa', 'KansasState', 'TexasTech', 'Texas'], 'ArkansasState': ['Iowa', 'KansasState', 'NorthTexas', 'ArkansasState'], 'BoiseState': ['Iowa', 'KansasState', 'NorthTexas', 'BoiseState'], 'Idaho': ['Iowa', 'KansasState', 'NorthTexas', 'Idaho'], 'NewMexicoState': ['Iowa', 'KansasState', 'NorthTexas', 'NewMexicoState'], 'Florida': ['Iowa', 'KansasState', 'BallState', 'Florida'], 'Buffalo': ['Iowa', 'KansasState', 'BallState', 'Buffalo'], 'Connecticut': ['Iowa', 'KansasState', 'BallState', 'Connecticut'], 'ColoradoState': ['Iowa', 'KansasState', 'Colorado', 'ColoradoState'], 'Washington': ['Iowa', 'KansasState', 'Colorado', 'Washington'], 'SouthernMethodist': ['Iowa', 'KansasState', 'Kansas', 'SouthernMethodist'], 'AlabamaBirmingham': ['Iowa', 'KansasState', 'Kansas', 'AlabamaBirmingham'], 'Auburn': ['Iowa', 'KansasState', 'LouisianaTech', 'Auburn'], 'CentralFlorida': ['Iowa', 'KansasState', 'LouisianaTech', 'CentralFlorida'], 'Tulsa': ['Iowa', 'KansasState', 'LouisianaTech', 'Tulsa'], 'MiamiFlorida': ['Iowa', 'KansasState', 'LouisianaTech', 'MiamiFlorida'], 'Wyoming': ['Iowa', 'KansasState', 'TexasA&M', 'Wyoming'], 'TexasElPaso': ['Iowa', 'KansasState', 'TexasA&M', 'TexasElPaso'], 'Rice': ['Iowa', 'KansasState', 'Oklahoma', 'Rice'], 'Clemson': [' ...
# KansasState
# {'KansasState': ['KansasState'], 'Iowa': ['KansasState', 'Iowa'], 'TexasTech': ['KansasState', 'TexasTech'], 'NorthTexas': ['KansasState', 'NorthTexas'], 'BallState': ['KansasState', 'BallState'], 'Colorado': ['KansasState', 'Colorado'], 'Kansas': ['KansasState', 'Kansas'], 'LouisianaTech': ['KansasState', 'LouisianaTech'], 'IowaState': ['KansasState', 'IowaState'], 'Nebraska': ['KansasState', 'Nebraska'], 'TexasA&M': ['KansasState', 'TexasA&M'], 'Oklahoma': ['KansasState', 'Oklahoma'], 'Missouri': ['KansasState', 'Missouri'], 'PennState': ['KansasState', 'Iowa', 'PennState'], 'Northwestern': ['KansasState', 'Iowa', 'Northwestern'], 'WesternMichigan': ['KansasState', 'Iowa', 'WesternMichigan'], 'Wisconsin': ['KansasState', 'Iowa', 'Wisconsin'], 'OhioState': ['KansasState', 'Iowa', 'OhioState'], 'Minnesota': ['KansasState', 'Iowa', 'Minnesota'], 'Illinois': ['KansasState', 'Iowa', 'Illinois'], 'MichiganState': ['KansasState', 'Iowa', 'MichiganState'], 'Indiana': ['KansasState', 'Iowa', 'Indiana'], 'NewMexico': ['KansasState', 'TexasTech', 'NewMexico'], 'Baylor': ['KansasState', 'TexasTech', 'Baylor'], 'UtahState': ['KansasState', 'TexasTech', 'UtahState'], 'LouisianaLafayette': ['KansasState', 'TexasTech', 'LouisianaLafayette'], 'Texas': ['KansasState', 'TexasTech', 'Texas'], 'OklahomaState': ['KansasState', 'TexasTech', 'OklahomaState'], 'ArkansasState': ['KansasState', 'NorthTexas', 'ArkansasState'], 'BoiseState': ['KansasState', 'NorthTexas', 'BoiseState'], 'Idaho': ['KansasState', 'NorthTexas', 'Idaho'], 'NewMexicoState': ['KansasState', 'NorthTexas', 'NewMexicoState'], 'NevadaLasVegas': ['KansasState', 'NorthTexas', 'NevadaLasVegas'], 'NorthernIllinois': ['KansasState', 'BallState', 'NorthernIllinois'], 'Florida': ['KansasState', 'BallState', 'Florida'], 'Buffalo': ['KansasState', 'BallState', 'Buffalo'], 'CentralMichigan': ['KansasState', 'BallState', 'CentralMichigan'], 'Connecticut': ['KansasState', 'BallState', 'Connecticut'], 'EasternMichigan': ['KansasState', 'BallState', 'EasternMichigan'], 'MiamiOhio': ['KansasState', 'BallState', 'MiamiOhio'], 'Toledo': ['KansasState', 'BallState', 'Toledo'], 'SouthernCalifornia': ['KansasState', 'Colorado', 'SouthernCalifornia'], 'ColoradoState': ['KansasState', 'Colorado', 'ColoradoState'], 'Washington': ['KansasState', 'Colorado', 'Washington'], 'SouthernMethodist': ['KansasState', 'Kansas', 'SouthernMethodist'], 'AlabamaBirmingham': ['KansasState', 'Kansas', 'AlabamaBirmingham'], 'Auburn': ['KansasState', 'LouisianaTech', 'Auburn'], 'CentralFlorida': ['KansasState', 'LouisianaTech', 'CentralFlorida'], 'LouisianaMonroe': ['KansasState', 'LouisianaTech', 'LouisianaMonroe'], 'MiddleTennesseeState': ['KansasState', 'LouisianaTech', 'MiddleTennesseeState'], 'Tulsa': ['KansasState', 'LouisianaTech', 'Tulsa'], 'MiamiFlorida': ['KansasState', 'LouisianaTech', 'MiamiFlorida'], 'Hawaii': ['KansasState', 'LouisianaTech', 'Hawaii'], 'Ohio': ['KansasState', 'IowaState', 'Ohio'], 'SanJoseState': ['KansasState', 'Nebraska', 'SanJoseState'], 'NotreDame': ['KansasState', 'Nebraska', 'NotreDame'], 'Wyoming': ['KansasState', 'TexasA&M', 'Wyoming'], 'TexasElPaso': ['KansasState', 'TexasA&M', 'TexasElPaso'], 'Rice': ['KansasState', 'Oklahoma', 'Rice'], 'Clemson': ['KansasState', 'Missouri', 'Clemson'], 'Michigan': ['KansasState', 'Iowa', 'PennState', 'Michigan'], 'Purdue': ['KansasState', 'Iowa', 'PennState', 'Purdue'], 'Pittsburgh': ['KansasState', 'Iowa', 'PennState', 'Pittsburgh'], 'Duke': ['KansasState', 'Iowa', 'Northwestern', 'Duke'], 'TexasChristian': ['KansasState', 'Iowa', 'Northwestern', 'TexasChristian'], 'Kent': ['KansasState', 'Iowa', 'WesternMichigan', 'Kent'], 'Marshall': ['KansasState', 'Iowa', 'WesternMichigan', 'Marshall'], 'Oregon': ['KansasState', 'Iowa', 'Wisconsin', 'Oregon'], 'Cincinnati': ['KansasState', 'Iowa', 'Wisconsin', 'Cincinnati'], 'Arizona': ['KansasState', 'Iowa', 'OhioState', 'Arizona'], 'FresnoState': ['KansasState', 'Iowa', 'OhioState', 'FresnoState'], 'SanDieg ...
# NewMexico
# {'NewMexico': ['NewMexico'], 'BrighamYoung': ['NewMexico', 'BrighamYoung'], 'TexasTech': ['NewMexico', 'TexasTech'], 'SanDiegoState': ['NewMexico', 'SanDiegoState'], 'Wyoming': ['NewMexico', 'Wyoming'], 'Utah': ['NewMexico', 'Utah'], 'BoiseState': ['NewMexico', 'BoiseState'], 'ColoradoState': ['NewMexico', 'ColoradoState'], 'NewMexicoState': ['NewMexico', 'NewMexicoState'], 'AirForce': ['NewMexico', 'AirForce'], 'NevadaLasVegas': ['NewMexico', 'NevadaLasVegas'], 'OregonState': ['NewMexico', 'OregonState'], 'FloridaState': ['NewMexico', 'BrighamYoung', 'FloridaState'], 'Virginia': ['NewMexico', 'BrighamYoung', 'Virginia'], 'Syracuse': ['NewMexico', 'BrighamYoung', 'Syracuse'], 'MississippiState': ['NewMexico', 'BrighamYoung', 'MississippiState'], 'UtahState': ['NewMexico', 'BrighamYoung', 'UtahState'], 'KansasState': ['NewMexico', 'TexasTech', 'KansasState'], 'Baylor': ['NewMexico', 'TexasTech', 'Baylor'], 'NorthTexas': ['NewMexico', 'TexasTech', 'NorthTexas'], 'Kansas': ['NewMexico', 'TexasTech', 'Kansas'], 'Nebraska': ['NewMexico', 'TexasTech', 'Nebraska'], 'TexasA&M': ['NewMexico', 'TexasTech', 'TexasA&M'], 'Oklahoma': ['NewMexico', 'TexasTech', 'Oklahoma'], 'LouisianaLafayette': ['NewMexico', 'TexasTech', 'LouisianaLafayette'], 'Texas': ['NewMexico', 'TexasTech', 'Texas'], 'OklahomaState': ['NewMexico', 'TexasTech', 'OklahomaState'], 'ArizonaState': ['NewMexico', 'SanDiegoState', 'ArizonaState'], 'Arizona': ['NewMexico', 'SanDiegoState', 'Arizona'], 'Illinois': ['NewMexico', 'SanDiegoState', 'Illinois'], 'Auburn': ['NewMexico', 'Wyoming', 'Auburn'], 'CentralMichigan': ['NewMexico', 'Wyoming', 'CentralMichigan'], 'Nevada': ['NewMexico', 'Wyoming', 'Nevada'], 'WashingtonState': ['NewMexico', 'Utah', 'WashingtonState'], 'California': ['NewMexico', 'Utah', 'California'], 'ArkansasState': ['NewMexico', 'BoiseState', 'ArkansasState'], 'Idaho': ['NewMexico', 'BoiseState', 'Idaho'], 'Arkansas': ['NewMexico', 'BoiseState', 'Arkansas'], 'Colorado': ['NewMexico', 'ColoradoState', 'Colorado'], 'SouthCarolina': ['NewMexico', 'NewMexicoState', 'SouthCarolina'], 'TexasElPaso': ['NewMexico', 'NewMexicoState', 'TexasElPaso'], 'Tulsa': ['NewMexico', 'NewMexicoState', 'Tulsa'], 'Army': ['NewMexico', 'NewMexicoState', 'Army'], 'Georgia': ['NewMexico', 'NewMexicoState', 'Georgia'], 'Navy': ['NewMexico', 'AirForce', 'Navy'], 'NotreDame': ['NewMexico', 'AirForce', 'NotreDame'], 'IowaState': ['NewMexico', 'NevadaLasVegas', 'IowaState'], 'Mississippi': ['NewMexico', 'NevadaLasVegas', 'Mississippi'], 'Hawaii': ['NewMexico', 'NevadaLasVegas', 'Hawaii'], 'SouthernCalifornia': ['NewMexico', 'OregonState', 'SouthernCalifornia'], 'UCLA': ['NewMexico', 'OregonState', 'UCLA'], 'Washington': ['NewMexico', 'OregonState', 'Washington'], 'Oregon': ['NewMexico', 'OregonState', 'Oregon'], 'Stanford': ['NewMexico', 'OregonState', 'Stanford'], 'NorthCarolinaState': ['NewMexico', 'BrighamYoung', 'FloridaState', 'NorthCarolinaState'], 'Florida': ['NewMexico', 'BrighamYoung', 'FloridaState', 'Florida'], 'GeorgiaTech': ['NewMexico', 'BrighamYoung', 'FloridaState', 'GeorgiaTech'], 'Duke': ['NewMexico', 'BrighamYoung', 'FloridaState', 'Duke'], 'Louisville': ['NewMexico', 'BrighamYoung', 'FloridaState', 'Louisville'], 'NorthCarolina': ['NewMexico', 'BrighamYoung', 'FloridaState', 'NorthCarolina'], 'MiamiFlorida': ['NewMexico', 'BrighamYoung', 'FloridaState', 'MiamiFlorida'], 'Clemson': ['NewMexico', 'BrighamYoung', 'FloridaState', 'Clemson'], 'WakeForest': ['NewMexico', 'BrighamYoung', 'FloridaState', 'WakeForest'], 'Maryland': ['NewMexico', 'BrighamYoung', 'FloridaState', 'Maryland'], 'VirginiaTech': ['NewMexico', 'BrighamYoung', 'Virginia', 'VirginiaTech'], 'BostonCollege': ['NewMexico', 'BrighamYoung', 'Syracuse', 'BostonCollege'], 'WestVirginia': ['NewMexico', 'BrighamYoung', 'Syracuse', 'WestVirginia'], 'Buffalo': ['NewMexico', 'BrighamYoung', 'Syracuse', 'Buffalo'], 'EastCarolina': ['NewMexico', 'BrighamYoung', 'Syracuse', 'EastCarolina'], 'Pittsburgh': ['NewMexico ...
# TexasTech
# {'TexasTech': ['TexasTech'], 'KansasState': ['TexasTech', 'KansasState'], 'NewMexico': ['TexasTech', 'NewMexico'], 'Baylor': ['TexasTech', 'Baylor'], 'NorthTexas': ['TexasTech', 'NorthTexas'], 'Kansas': ['TexasTech', 'Kansas'], 'Nebraska': ['TexasTech', 'Nebraska'], 'TexasA&M': ['TexasTech', 'TexasA&M'], 'Oklahoma': ['TexasTech', 'Oklahoma'], 'UtahState': ['TexasTech', 'UtahState'], 'LouisianaLafayette': ['TexasTech', 'LouisianaLafayette'], 'Texas': ['TexasTech', 'Texas'], 'OklahomaState': ['TexasTech', 'OklahomaState'], 'Iowa': ['TexasTech', 'KansasState', 'Iowa'], 'BallState': ['TexasTech', 'KansasState', 'BallState'], 'Colorado': ['TexasTech', 'KansasState', 'Colorado'], 'LouisianaTech': ['TexasTech', 'KansasState', 'LouisianaTech'], 'IowaState': ['TexasTech', 'KansasState', 'IowaState'], 'Missouri': ['TexasTech', 'KansasState', 'Missouri'], 'BrighamYoung': ['TexasTech', 'NewMexico', 'BrighamYoung'], 'SanDiegoState': ['TexasTech', 'NewMexico', 'SanDiegoState'], 'Wyoming': ['TexasTech', 'NewMexico', 'Wyoming'], 'Utah': ['TexasTech', 'NewMexico', 'Utah'], 'BoiseState': ['TexasTech', 'NewMexico', 'BoiseState'], 'ColoradoState': ['TexasTech', 'NewMexico', 'ColoradoState'], 'NewMexicoState': ['TexasTech', 'NewMexico', 'NewMexicoState'], 'AirForce': ['TexasTech', 'NewMexico', 'AirForce'], 'NevadaLasVegas': ['TexasTech', 'NewMexico', 'NevadaLasVegas'], 'OregonState': ['TexasTech', 'NewMexico', 'OregonState'], 'Minnesota': ['TexasTech', 'Baylor', 'Minnesota'], 'ArkansasState': ['TexasTech', 'NorthTexas', 'ArkansasState'], 'Idaho': ['TexasTech', 'NorthTexas', 'Idaho'], 'SouthernMethodist': ['TexasTech', 'Kansas', 'SouthernMethodist'], 'AlabamaBirmingham': ['TexasTech', 'Kansas', 'AlabamaBirmingham'], 'SanJoseState': ['TexasTech', 'Nebraska', 'SanJoseState'], 'NotreDame': ['TexasTech', 'Nebraska', 'NotreDame'], 'TexasElPaso': ['TexasTech', 'TexasA&M', 'TexasElPaso'], 'Rice': ['TexasTech', 'Oklahoma', 'Rice'], 'ArizonaState': ['TexasTech', 'UtahState', 'ArizonaState'], 'LouisianaMonroe': ['TexasTech', 'LouisianaLafayette', 'LouisianaMonroe'], 'MiddleTennesseeState': ['TexasTech', 'LouisianaLafayette', 'MiddleTennesseeState'], 'Tulane': ['TexasTech', 'LouisianaLafayette', 'Tulane'], 'Houston': ['TexasTech', 'Texas', 'Houston'], 'Stanford': ['TexasTech', 'Texas', 'Stanford'], 'SouthernMississippi': ['TexasTech', 'OklahomaState', 'SouthernMississippi'], 'Tulsa': ['TexasTech', 'OklahomaState', 'Tulsa'], 'PennState': ['TexasTech', 'KansasState', 'Iowa', 'PennState'], 'Northwestern': ['TexasTech', 'KansasState', 'Iowa', 'Northwestern'], 'WesternMichigan': ['TexasTech', 'KansasState', 'Iowa', 'WesternMichigan'], 'Wisconsin': ['TexasTech', 'KansasState', 'Iowa', 'Wisconsin'], 'OhioState': ['TexasTech', 'KansasState', 'Iowa', 'OhioState'], 'Illinois': ['TexasTech', 'KansasState', 'Iowa', 'Illinois'], 'MichiganState': ['TexasTech', 'KansasState', 'Iowa', 'MichiganState'], 'Indiana': ['TexasTech', 'KansasState', 'Iowa', 'Indiana'], 'NorthernIllinois': ['TexasTech', 'KansasState', 'BallState', 'NorthernIllinois'], 'Florida': ['TexasTech', 'KansasState', 'BallState', 'Florida'], 'Buffalo': ['TexasTech', 'KansasState', 'BallState', 'Buffalo'], 'CentralMichigan': ['TexasTech', 'KansasState', 'BallState', 'CentralMichigan'], 'Connecticut': ['TexasTech', 'KansasState', 'BallState', 'Connecticut'], 'EasternMichigan': ['TexasTech', 'KansasState', 'BallState', 'EasternMichigan'], 'MiamiOhio': ['TexasTech', 'KansasState', 'BallState', 'MiamiOhio'], 'Toledo': ['TexasTech', 'KansasState', 'BallState', 'Toledo'], 'SouthernCalifornia': ['TexasTech', 'KansasState', 'Colorado', 'SouthernCalifornia'], 'Washington': ['TexasTech', 'KansasState', 'Colorado', 'Washington'], 'Auburn': ['TexasTech', 'KansasState', 'LouisianaTech', 'Auburn'], 'CentralFlorida': ['TexasTech', 'KansasState', 'LouisianaTech', 'CentralFlorida'], 'MiamiFlorida': ['TexasTech', 'KansasState', 'LouisianaTech', 'MiamiFlorida'], 'Hawaii': ['TexasTech', 'KansasState', 'LouisianaTech', 'Hawaii'], ' ...
# PennState
# {'PennState': ['PennState'], 'Iowa': ['PennState', 'Iowa'], 'SouthernCalifornia': ['PennState', 'SouthernCalifornia'], 'Michigan': ['PennState', 'Michigan'], 'Purdue': ['PennState', 'Purdue'], 'OhioState': ['PennState', 'OhioState'], 'Pittsburgh': ['PennState', 'Pittsburgh'], 'LouisianaTech': ['PennState', 'LouisianaTech'], 'Minnesota': ['PennState', 'Minnesota'], 'Illinois': ['PennState', 'Illinois'], 'Toledo': ['PennState', 'Toledo'], 'MichiganState': ['PennState', 'MichiganState'], 'Indiana': ['PennState', 'Indiana'], 'KansasState': ['PennState', 'Iowa', 'KansasState'], 'Northwestern': ['PennState', 'Iowa', 'Northwestern'], 'WesternMichigan': ['PennState', 'Iowa', 'WesternMichigan'], 'Wisconsin': ['PennState', 'Iowa', 'Wisconsin'], 'IowaState': ['PennState', 'Iowa', 'IowaState'], 'Nebraska': ['PennState', 'Iowa', 'Nebraska'], 'ArizonaState': ['PennState', 'SouthernCalifornia', 'ArizonaState'], 'UCLA': ['PennState', 'SouthernCalifornia', 'UCLA'], 'Arizona': ['PennState', 'SouthernCalifornia', 'Arizona'], 'Colorado': ['PennState', 'SouthernCalifornia', 'Colorado'], 'Oregon': ['PennState', 'SouthernCalifornia', 'Oregon'], 'SanJoseState': ['PennState', 'SouthernCalifornia', 'SanJoseState'], 'Stanford': ['PennState', 'SouthernCalifornia', 'Stanford'], 'WashingtonState': ['PennState', 'SouthernCalifornia', 'WashingtonState'], 'NotreDame': ['PennState', 'SouthernCalifornia', 'NotreDame'], 'OregonState': ['PennState', 'SouthernCalifornia', 'OregonState'], 'California': ['PennState', 'SouthernCalifornia', 'California'], 'BowlingGreenState': ['PennState', 'Michigan', 'BowlingGreenState'], 'Rice': ['PennState', 'Michigan', 'Rice'], 'CentralMichigan': ['PennState', 'Purdue', 'CentralMichigan'], 'Kent': ['PennState', 'Purdue', 'Kent'], 'FresnoState': ['PennState', 'OhioState', 'FresnoState'], 'MiamiOhio': ['PennState', 'OhioState', 'MiamiOhio'], 'VirginiaTech': ['PennState', 'Pittsburgh', 'VirginiaTech'], 'BostonCollege': ['PennState', 'Pittsburgh', 'BostonCollege'], 'WestVirginia': ['PennState', 'Pittsburgh', 'WestVirginia'], 'Syracuse': ['PennState', 'Pittsburgh', 'Syracuse'], 'Temple': ['PennState', 'Pittsburgh', 'Temple'], 'NorthCarolina': ['PennState', 'Pittsburgh', 'NorthCarolina'], 'Rutgers': ['PennState', 'Pittsburgh', 'Rutgers'], 'MiamiFlorida': ['PennState', 'Pittsburgh', 'MiamiFlorida'], 'Auburn': ['PennState', 'LouisianaTech', 'Auburn'], 'CentralFlorida': ['PennState', 'LouisianaTech', 'CentralFlorida'], 'LouisianaMonroe': ['PennState', 'LouisianaTech', 'LouisianaMonroe'], 'MiddleTennesseeState': ['PennState', 'LouisianaTech', 'MiddleTennesseeState'], 'Tulsa': ['PennState', 'LouisianaTech', 'Tulsa'], 'LouisianaLafayette': ['PennState', 'LouisianaTech', 'LouisianaLafayette'], 'Hawaii': ['PennState', 'LouisianaTech', 'Hawaii'], 'Baylor': ['PennState', 'Minnesota', 'Baylor'], 'Ohio': ['PennState', 'Minnesota', 'Ohio'], 'SanDiegoState': ['PennState', 'Illinois', 'SanDiegoState'], 'NorthernIllinois': ['PennState', 'Toledo', 'NorthernIllinois'], 'BallState': ['PennState', 'Toledo', 'BallState'], 'EasternMichigan': ['PennState', 'Toledo', 'EasternMichigan'], 'Navy': ['PennState', 'Toledo', 'Navy'], 'Marshall': ['PennState', 'Toledo', 'Marshall'], 'Missouri': ['PennState', 'MichiganState', 'Missouri'], 'NorthCarolinaState': ['PennState', 'Indiana', 'NorthCarolinaState'], 'Kentucky': ['PennState', 'Indiana', 'Kentucky'], 'Cincinnati': ['PennState', 'Indiana', 'Cincinnati'], 'TexasTech': ['PennState', 'Iowa', 'KansasState', 'TexasTech'], 'NorthTexas': ['PennState', 'Iowa', 'KansasState', 'NorthTexas'], 'Kansas': ['PennState', 'Iowa', 'KansasState', 'Kansas'], 'TexasA&M': ['PennState', 'Iowa', 'KansasState', 'TexasA&M'], 'Oklahoma': ['PennState', 'Iowa', 'KansasState', 'Oklahoma'], 'Duke': ['PennState', 'Iowa', 'Northwestern', 'Duke'], 'TexasChristian': ['PennState', 'Iowa', 'Northwestern', 'TexasChristian'], 'NevadaLasVegas': ['PennState', 'Iowa', 'IowaState', 'NevadaLasVegas'], 'OklahomaState': ['PennState', 'Iowa', 'IowaState', 'Okl ...
# SouthernCalifornia
# {'SouthernCalifornia': ['SouthernCalifornia'], 'PennState': ['SouthernCalifornia', 'PennState'], 'ArizonaState': ['SouthernCalifornia', 'ArizonaState'], 'UCLA': ['SouthernCalifornia', 'UCLA'], 'Arizona': ['SouthernCalifornia', 'Arizona'], 'Colorado': ['SouthernCalifornia', 'Colorado'], 'Oregon': ['SouthernCalifornia', 'Oregon'], 'SanJoseState': ['SouthernCalifornia', 'SanJoseState'], 'Stanford': ['SouthernCalifornia', 'Stanford'], 'WashingtonState': ['SouthernCalifornia', 'WashingtonState'], 'NotreDame': ['SouthernCalifornia', 'NotreDame'], 'OregonState': ['SouthernCalifornia', 'OregonState'], 'California': ['SouthernCalifornia', 'California'], 'Iowa': ['SouthernCalifornia', 'PennState', 'Iowa'], 'Michigan': ['SouthernCalifornia', 'PennState', 'Michigan'], 'Purdue': ['SouthernCalifornia', 'PennState', 'Purdue'], 'OhioState': ['SouthernCalifornia', 'PennState', 'OhioState'], 'Pittsburgh': ['SouthernCalifornia', 'PennState', 'Pittsburgh'], 'LouisianaTech': ['SouthernCalifornia', 'PennState', 'LouisianaTech'], 'Minnesota': ['SouthernCalifornia', 'PennState', 'Minnesota'], 'Illinois': ['SouthernCalifornia', 'PennState', 'Illinois'], 'Toledo': ['SouthernCalifornia', 'PennState', 'Toledo'], 'MichiganState': ['SouthernCalifornia', 'PennState', 'MichiganState'], 'Indiana': ['SouthernCalifornia', 'PennState', 'Indiana'], 'SanDiegoState': ['SouthernCalifornia', 'ArizonaState', 'SanDiegoState'], 'ColoradoState': ['SouthernCalifornia', 'ArizonaState', 'ColoradoState'], 'Washington': ['SouthernCalifornia', 'ArizonaState', 'Washington'], 'UtahState': ['SouthernCalifornia', 'ArizonaState', 'UtahState'], 'Alabama': ['SouthernCalifornia', 'UCLA', 'Alabama'], 'FresnoState': ['SouthernCalifornia', 'UCLA', 'FresnoState'], 'Utah': ['SouthernCalifornia', 'Arizona', 'Utah'], 'KansasState': ['SouthernCalifornia', 'Colorado', 'KansasState'], 'Kansas': ['SouthernCalifornia', 'Colorado', 'Kansas'], 'IowaState': ['SouthernCalifornia', 'Colorado', 'IowaState'], 'Nebraska': ['SouthernCalifornia', 'Colorado', 'Nebraska'], 'TexasA&M': ['SouthernCalifornia', 'Colorado', 'TexasA&M'], 'Texas': ['SouthernCalifornia', 'Colorado', 'Texas'], 'Missouri': ['SouthernCalifornia', 'Colorado', 'Missouri'], 'OklahomaState': ['SouthernCalifornia', 'Colorado', 'OklahomaState'], 'Wisconsin': ['SouthernCalifornia', 'Oregon', 'Wisconsin'], 'Idaho': ['SouthernCalifornia', 'Oregon', 'Idaho'], 'Nevada': ['SouthernCalifornia', 'Oregon', 'Nevada'], 'Rice': ['SouthernCalifornia', 'SanJoseState', 'Rice'], 'SouthernMethodist': ['SouthernCalifornia', 'SanJoseState', 'SouthernMethodist'], 'TexasElPaso': ['SouthernCalifornia', 'SanJoseState', 'TexasElPaso'], 'Tulsa': ['SouthernCalifornia', 'SanJoseState', 'Tulsa'], 'TexasChristian': ['SouthernCalifornia', 'SanJoseState', 'TexasChristian'], 'Hawaii': ['SouthernCalifornia', 'SanJoseState', 'Hawaii'], 'BoiseState': ['SouthernCalifornia', 'WashingtonState', 'BoiseState'], 'BostonCollege': ['SouthernCalifornia', 'NotreDame', 'BostonCollege'], 'WestVirginia': ['SouthernCalifornia', 'NotreDame', 'WestVirginia'], 'Navy': ['SouthernCalifornia', 'NotreDame', 'Navy'], 'AirForce': ['SouthernCalifornia', 'NotreDame', 'AirForce'], 'Rutgers': ['SouthernCalifornia', 'NotreDame', 'Rutgers'], 'NewMexico': ['SouthernCalifornia', 'OregonState', 'NewMexico'], 'Northwestern': ['SouthernCalifornia', 'PennState', 'Iowa', 'Northwestern'], 'WesternMichigan': ['SouthernCalifornia', 'PennState', 'Iowa', 'WesternMichigan'], 'BowlingGreenState': ['SouthernCalifornia', 'PennState', 'Michigan', 'BowlingGreenState'], 'CentralMichigan': ['SouthernCalifornia', 'PennState', 'Purdue', 'CentralMichigan'], 'Kent': ['SouthernCalifornia', 'PennState', 'Purdue', 'Kent'], 'MiamiOhio': ['SouthernCalifornia', 'PennState', 'OhioState', 'MiamiOhio'], 'VirginiaTech': ['SouthernCalifornia', 'PennState', 'Pittsburgh', 'VirginiaTech'], 'Syracuse': ['SouthernCalifornia', 'PennState', 'Pittsburgh', 'Syracuse'], 'Temple': ['SouthernCalifornia', 'PennState', 'Pittsburgh', 'Temple'], 'NorthCa ...
# ArizonaState
# {'ArizonaState': ['ArizonaState'], 'SouthernCalifornia': ['ArizonaState', 'SouthernCalifornia'], 'SanDiegoState': ['ArizonaState', 'SanDiegoState'], 'UCLA': ['ArizonaState', 'UCLA'], 'Arizona': ['ArizonaState', 'Arizona'], 'ColoradoState': ['ArizonaState', 'ColoradoState'], 'Washington': ['ArizonaState', 'Washington'], 'Oregon': ['ArizonaState', 'Oregon'], 'Stanford': ['ArizonaState', 'Stanford'], 'WashingtonState': ['ArizonaState', 'WashingtonState'], 'UtahState': ['ArizonaState', 'UtahState'], 'California': ['ArizonaState', 'California'], 'PennState': ['ArizonaState', 'SouthernCalifornia', 'PennState'], 'Colorado': ['ArizonaState', 'SouthernCalifornia', 'Colorado'], 'SanJoseState': ['ArizonaState', 'SouthernCalifornia', 'SanJoseState'], 'NotreDame': ['ArizonaState', 'SouthernCalifornia', 'NotreDame'], 'OregonState': ['ArizonaState', 'SouthernCalifornia', 'OregonState'], 'BrighamYoung': ['ArizonaState', 'SanDiegoState', 'BrighamYoung'], 'NewMexico': ['ArizonaState', 'SanDiegoState', 'NewMexico'], 'Wyoming': ['ArizonaState', 'SanDiegoState', 'Wyoming'], 'Utah': ['ArizonaState', 'SanDiegoState', 'Utah'], 'Illinois': ['ArizonaState', 'SanDiegoState', 'Illinois'], 'AirForce': ['ArizonaState', 'SanDiegoState', 'AirForce'], 'NevadaLasVegas': ['ArizonaState', 'SanDiegoState', 'NevadaLasVegas'], 'Alabama': ['ArizonaState', 'UCLA', 'Alabama'], 'Michigan': ['ArizonaState', 'UCLA', 'Michigan'], 'FresnoState': ['ArizonaState', 'UCLA', 'FresnoState'], 'OhioState': ['ArizonaState', 'Arizona', 'OhioState'], 'Nevada': ['ArizonaState', 'ColoradoState', 'Nevada'], 'Idaho': ['ArizonaState', 'Washington', 'Idaho'], 'MiamiFlorida': ['ArizonaState', 'Washington', 'MiamiFlorida'], 'Wisconsin': ['ArizonaState', 'Oregon', 'Wisconsin'], 'Texas': ['ArizonaState', 'Stanford', 'Texas'], 'BoiseState': ['ArizonaState', 'WashingtonState', 'BoiseState'], 'TexasTech': ['ArizonaState', 'UtahState', 'TexasTech'], 'NorthTexas': ['ArizonaState', 'UtahState', 'NorthTexas'], 'ArkansasState': ['ArizonaState', 'UtahState', 'ArkansasState'], 'NewMexicoState': ['ArizonaState', 'UtahState', 'NewMexicoState'], 'Iowa': ['ArizonaState', 'SouthernCalifornia', 'PennState', 'Iowa'], 'Purdue': ['ArizonaState', 'SouthernCalifornia', 'PennState', 'Purdue'], 'Pittsburgh': ['ArizonaState', 'SouthernCalifornia', 'PennState', 'Pittsburgh'], 'LouisianaTech': ['ArizonaState', 'SouthernCalifornia', 'PennState', 'LouisianaTech'], 'Minnesota': ['ArizonaState', 'SouthernCalifornia', 'PennState', 'Minnesota'], 'Toledo': ['ArizonaState', 'SouthernCalifornia', 'PennState', 'Toledo'], 'MichiganState': ['ArizonaState', 'SouthernCalifornia', 'PennState', 'MichiganState'], 'Indiana': ['ArizonaState', 'SouthernCalifornia', 'PennState', 'Indiana'], 'KansasState': ['ArizonaState', 'SouthernCalifornia', 'Colorado', 'KansasState'], 'Kansas': ['ArizonaState', 'SouthernCalifornia', 'Colorado', 'Kansas'], 'IowaState': ['ArizonaState', 'SouthernCalifornia', 'Colorado', 'IowaState'], 'Nebraska': ['ArizonaState', 'SouthernCalifornia', 'Colorado', 'Nebraska'], 'TexasA&M': ['ArizonaState', 'SouthernCalifornia', 'Colorado', 'TexasA&M'], 'Missouri': ['ArizonaState', 'SouthernCalifornia', 'Colorado', 'Missouri'], 'OklahomaState': ['ArizonaState', 'SouthernCalifornia', 'Colorado', 'OklahomaState'], 'Rice': ['ArizonaState', 'SouthernCalifornia', 'SanJoseState', 'Rice'], 'SouthernMethodist': ['ArizonaState', 'SouthernCalifornia', 'SanJoseState', 'SouthernMethodist'], 'TexasElPaso': ['ArizonaState', 'SouthernCalifornia', 'SanJoseState', 'TexasElPaso'], 'Tulsa': ['ArizonaState', 'SouthernCalifornia', 'SanJoseState', 'Tulsa'], 'TexasChristian': ['ArizonaState', 'SouthernCalifornia', 'SanJoseState', 'TexasChristian'], 'Hawaii': ['ArizonaState', 'SouthernCalifornia', 'SanJoseState', 'Hawaii'], 'BostonCollege': ['ArizonaState', 'SouthernCalifornia', 'NotreDame', 'BostonCollege'], 'WestVirginia': ['ArizonaState', 'SouthernCalifornia', 'NotreDame', 'WestVirginia'], 'Navy': ['ArizonaState', 'SouthernCalifornia', 'NotreDame ...
# SanDiegoState
# {'SanDiegoState': ['SanDiegoState'], 'BrighamYoung': ['SanDiegoState', 'BrighamYoung'], 'NewMexico': ['SanDiegoState', 'NewMexico'], 'ArizonaState': ['SanDiegoState', 'ArizonaState'], 'Wyoming': ['SanDiegoState', 'Wyoming'], 'Arizona': ['SanDiegoState', 'Arizona'], 'Utah': ['SanDiegoState', 'Utah'], 'ColoradoState': ['SanDiegoState', 'ColoradoState'], 'Illinois': ['SanDiegoState', 'Illinois'], 'AirForce': ['SanDiegoState', 'AirForce'], 'NevadaLasVegas': ['SanDiegoState', 'NevadaLasVegas'], 'OregonState': ['SanDiegoState', 'OregonState'], 'FloridaState': ['SanDiegoState', 'BrighamYoung', 'FloridaState'], 'Virginia': ['SanDiegoState', 'BrighamYoung', 'Virginia'], 'Syracuse': ['SanDiegoState', 'BrighamYoung', 'Syracuse'], 'MississippiState': ['SanDiegoState', 'BrighamYoung', 'MississippiState'], 'UtahState': ['SanDiegoState', 'BrighamYoung', 'UtahState'], 'TexasTech': ['SanDiegoState', 'NewMexico', 'TexasTech'], 'BoiseState': ['SanDiegoState', 'NewMexico', 'BoiseState'], 'NewMexicoState': ['SanDiegoState', 'NewMexico', 'NewMexicoState'], 'SouthernCalifornia': ['SanDiegoState', 'ArizonaState', 'SouthernCalifornia'], 'UCLA': ['SanDiegoState', 'ArizonaState', 'UCLA'], 'Washington': ['SanDiegoState', 'ArizonaState', 'Washington'], 'Oregon': ['SanDiegoState', 'ArizonaState', 'Oregon'], 'Stanford': ['SanDiegoState', 'ArizonaState', 'Stanford'], 'WashingtonState': ['SanDiegoState', 'ArizonaState', 'WashingtonState'], 'California': ['SanDiegoState', 'ArizonaState', 'California'], 'Auburn': ['SanDiegoState', 'Wyoming', 'Auburn'], 'CentralMichigan': ['SanDiegoState', 'Wyoming', 'CentralMichigan'], 'Nevada': ['SanDiegoState', 'Wyoming', 'Nevada'], 'TexasA&M': ['SanDiegoState', 'Wyoming', 'TexasA&M'], 'OhioState': ['SanDiegoState', 'Arizona', 'OhioState'], 'Colorado': ['SanDiegoState', 'ColoradoState', 'Colorado'], 'Iowa': ['SanDiegoState', 'Illinois', 'Iowa'], 'PennState': ['SanDiegoState', 'Illinois', 'PennState'], 'Northwestern': ['SanDiegoState', 'Illinois', 'Northwestern'], 'Michigan': ['SanDiegoState', 'Illinois', 'Michigan'], 'Minnesota': ['SanDiegoState', 'Illinois', 'Minnesota'], 'MiddleTennesseeState': ['SanDiegoState', 'Illinois', 'MiddleTennesseeState'], 'MichiganState': ['SanDiegoState', 'Illinois', 'MichiganState'], 'Indiana': ['SanDiegoState', 'Illinois', 'Indiana'], 'Navy': ['SanDiegoState', 'AirForce', 'Navy'], 'NotreDame': ['SanDiegoState', 'AirForce', 'NotreDame'], 'Army': ['SanDiegoState', 'AirForce', 'Army'], 'NorthTexas': ['SanDiegoState', 'NevadaLasVegas', 'NorthTexas'], 'IowaState': ['SanDiegoState', 'NevadaLasVegas', 'IowaState'], 'Mississippi': ['SanDiegoState', 'NevadaLasVegas', 'Mississippi'], 'Hawaii': ['SanDiegoState', 'NevadaLasVegas', 'Hawaii'], 'NorthCarolinaState': ['SanDiegoState', 'BrighamYoung', 'FloridaState', 'NorthCarolinaState'], 'Florida': ['SanDiegoState', 'BrighamYoung', 'FloridaState', 'Florida'], 'GeorgiaTech': ['SanDiegoState', 'BrighamYoung', 'FloridaState', 'GeorgiaTech'], 'Duke': ['SanDiegoState', 'BrighamYoung', 'FloridaState', 'Duke'], 'Louisville': ['SanDiegoState', 'BrighamYoung', 'FloridaState', 'Louisville'], 'NorthCarolina': ['SanDiegoState', 'BrighamYoung', 'FloridaState', 'NorthCarolina'], 'MiamiFlorida': ['SanDiegoState', 'BrighamYoung', 'FloridaState', 'MiamiFlorida'], 'Clemson': ['SanDiegoState', 'BrighamYoung', 'FloridaState', 'Clemson'], 'WakeForest': ['SanDiegoState', 'BrighamYoung', 'FloridaState', 'WakeForest'], 'Maryland': ['SanDiegoState', 'BrighamYoung', 'FloridaState', 'Maryland'], 'VirginiaTech': ['SanDiegoState', 'BrighamYoung', 'Virginia', 'VirginiaTech'], 'BostonCollege': ['SanDiegoState', 'BrighamYoung', 'Syracuse', 'BostonCollege'], 'WestVirginia': ['SanDiegoState', 'BrighamYoung', 'Syracuse', 'WestVirginia'], 'Buffalo': ['SanDiegoState', 'BrighamYoung', 'Syracuse', 'Buffalo'], 'EastCarolina': ['SanDiegoState', 'BrighamYoung', 'Syracuse', 'EastCarolina'], 'Pittsburgh': ['SanDiegoState', 'BrighamYoung', 'Syracuse', 'Pittsburgh'], 'Temple': ['SanDiegoState', 'BrighamY ...
# Baylor
# {'Baylor': ['Baylor'], 'TexasTech': ['Baylor', 'TexasTech'], 'NorthTexas': ['Baylor', 'NorthTexas'], 'Minnesota': ['Baylor', 'Minnesota'], 'IowaState': ['Baylor', 'IowaState'], 'Nebraska': ['Baylor', 'Nebraska'], 'TexasA&M': ['Baylor', 'TexasA&M'], 'Oklahoma': ['Baylor', 'Oklahoma'], 'Texas': ['Baylor', 'Texas'], 'Missouri': ['Baylor', 'Missouri'], 'OklahomaState': ['Baylor', 'OklahomaState'], 'KansasState': ['Baylor', 'TexasTech', 'KansasState'], 'NewMexico': ['Baylor', 'TexasTech', 'NewMexico'], 'Kansas': ['Baylor', 'TexasTech', 'Kansas'], 'UtahState': ['Baylor', 'TexasTech', 'UtahState'], 'LouisianaLafayette': ['Baylor', 'TexasTech', 'LouisianaLafayette'], 'ArkansasState': ['Baylor', 'NorthTexas', 'ArkansasState'], 'BoiseState': ['Baylor', 'NorthTexas', 'BoiseState'], 'Idaho': ['Baylor', 'NorthTexas', 'Idaho'], 'NewMexicoState': ['Baylor', 'NorthTexas', 'NewMexicoState'], 'NevadaLasVegas': ['Baylor', 'NorthTexas', 'NevadaLasVegas'], 'Iowa': ['Baylor', 'Minnesota', 'Iowa'], 'PennState': ['Baylor', 'Minnesota', 'PennState'], 'Northwestern': ['Baylor', 'Minnesota', 'Northwestern'], 'Wisconsin': ['Baylor', 'Minnesota', 'Wisconsin'], 'Purdue': ['Baylor', 'Minnesota', 'Purdue'], 'OhioState': ['Baylor', 'Minnesota', 'OhioState'], 'LouisianaMonroe': ['Baylor', 'Minnesota', 'LouisianaMonroe'], 'Illinois': ['Baylor', 'Minnesota', 'Illinois'], 'Ohio': ['Baylor', 'Minnesota', 'Ohio'], 'Indiana': ['Baylor', 'Minnesota', 'Indiana'], 'Colorado': ['Baylor', 'IowaState', 'Colorado'], 'SanJoseState': ['Baylor', 'Nebraska', 'SanJoseState'], 'NotreDame': ['Baylor', 'Nebraska', 'NotreDame'], 'Wyoming': ['Baylor', 'TexasA&M', 'Wyoming'], 'TexasElPaso': ['Baylor', 'TexasA&M', 'TexasElPaso'], 'Rice': ['Baylor', 'Oklahoma', 'Rice'], 'Houston': ['Baylor', 'Texas', 'Houston'], 'Stanford': ['Baylor', 'Texas', 'Stanford'], 'MichiganState': ['Baylor', 'Missouri', 'MichiganState'], 'Clemson': ['Baylor', 'Missouri', 'Clemson'], 'SouthernMississippi': ['Baylor', 'OklahomaState', 'SouthernMississippi'], 'Tulsa': ['Baylor', 'OklahomaState', 'Tulsa'], 'BallState': ['Baylor', 'TexasTech', 'KansasState', 'BallState'], 'LouisianaTech': ['Baylor', 'TexasTech', 'KansasState', 'LouisianaTech'], 'BrighamYoung': ['Baylor', 'TexasTech', 'NewMexico', 'BrighamYoung'], 'SanDiegoState': ['Baylor', 'TexasTech', 'NewMexico', 'SanDiegoState'], 'Utah': ['Baylor', 'TexasTech', 'NewMexico', 'Utah'], 'ColoradoState': ['Baylor', 'TexasTech', 'NewMexico', 'ColoradoState'], 'AirForce': ['Baylor', 'TexasTech', 'NewMexico', 'AirForce'], 'OregonState': ['Baylor', 'TexasTech', 'NewMexico', 'OregonState'], 'SouthernMethodist': ['Baylor', 'TexasTech', 'Kansas', 'SouthernMethodist'], 'AlabamaBirmingham': ['Baylor', 'TexasTech', 'Kansas', 'AlabamaBirmingham'], 'ArizonaState': ['Baylor', 'TexasTech', 'UtahState', 'ArizonaState'], 'MiddleTennesseeState': ['Baylor', 'TexasTech', 'LouisianaLafayette', 'MiddleTennesseeState'], 'Tulane': ['Baylor', 'TexasTech', 'LouisianaLafayette', 'Tulane'], 'NorthCarolinaState': ['Baylor', 'NorthTexas', 'ArkansasState', 'NorthCarolinaState'], 'Memphis': ['Baylor', 'NorthTexas', 'ArkansasState', 'Memphis'], 'Mississippi': ['Baylor', 'NorthTexas', 'ArkansasState', 'Mississippi'], 'TexasChristian': ['Baylor', 'NorthTexas', 'ArkansasState', 'TexasChristian'], 'CentralMichigan': ['Baylor', 'NorthTexas', 'BoiseState', 'CentralMichigan'], 'WashingtonState': ['Baylor', 'NorthTexas', 'BoiseState', 'WashingtonState'], 'Arkansas': ['Baylor', 'NorthTexas', 'BoiseState', 'Arkansas'], 'WestVirginia': ['Baylor', 'NorthTexas', 'Idaho', 'WestVirginia'], 'Washington': ['Baylor', 'NorthTexas', 'Idaho', 'Washington'], 'Oregon': ['Baylor', 'NorthTexas', 'Idaho', 'Oregon'], 'SouthCarolina': ['Baylor', 'NorthTexas', 'NewMexicoState', 'SouthCarolina'], 'Army': ['Baylor', 'NorthTexas', 'NewMexicoState', 'Army'], 'Georgia': ['Baylor', 'NorthTexas', 'NewMexicoState', 'Georgia'], 'Nevada': ['Baylor', 'NorthTexas', 'NevadaLasVegas', 'Nevada'], 'Hawaii': ['Baylor', 'NorthTexas', 'NevadaLa ...
# NorthTexas
# ...
# AlabamaBirmingham
# {'AlabamaBirmingham': ['AlabamaBirmingham'], 'EastCarolina': ['AlabamaBirmingham', 'EastCarolina'], 'Kansas': ['AlabamaBirmingham', 'Kansas'], 'Louisville': ['AlabamaBirmingham', 'Louisville'], 'MiddleTennesseeState': ['AlabamaBirmingham', 'MiddleTennesseeState'], 'Memphis': ['AlabamaBirmingham', 'Memphis'], 'SouthernMississippi': ['AlabamaBirmingham', 'SouthernMississippi'], 'Army': ['AlabamaBirmingham', 'Army'], 'Cincinnati': ['AlabamaBirmingham', 'Cincinnati'], 'LouisianaState': ['AlabamaBirmingham', 'LouisianaState'], 'LouisianaLafayette': ['AlabamaBirmingham', 'LouisianaLafayette'], 'VirginiaTech': ['AlabamaBirmingham', 'EastCarolina', 'VirginiaTech'], 'WestVirginia': ['AlabamaBirmingham', 'EastCarolina', 'WestVirginia'], 'Syracuse': ['AlabamaBirmingham', 'EastCarolina', 'Syracuse'], 'Duke': ['AlabamaBirmingham', 'EastCarolina', 'Duke'], 'Houston': ['AlabamaBirmingham', 'EastCarolina', 'Houston'], 'Tulane': ['AlabamaBirmingham', 'EastCarolina', 'Tulane'], 'KansasState': ['AlabamaBirmingham', 'Kansas', 'KansasState'], 'TexasTech': ['AlabamaBirmingham', 'Kansas', 'TexasTech'], 'Colorado': ['AlabamaBirmingham', 'Kansas', 'Colorado'], 'SouthernMethodist': ['AlabamaBirmingham', 'Kansas', 'SouthernMethodist'], 'IowaState': ['AlabamaBirmingham', 'Kansas', 'IowaState'], 'Nebraska': ['AlabamaBirmingham', 'Kansas', 'Nebraska'], 'Oklahoma': ['AlabamaBirmingham', 'Kansas', 'Oklahoma'], 'Texas': ['AlabamaBirmingham', 'Kansas', 'Texas'], 'Missouri': ['AlabamaBirmingham', 'Kansas', 'Missouri'], 'FloridaState': ['AlabamaBirmingham', 'Louisville', 'FloridaState'], 'Connecticut': ['AlabamaBirmingham', 'Louisville', 'Connecticut'], 'Kentucky': ['AlabamaBirmingham', 'Louisville', 'Kentucky'], 'Florida': ['AlabamaBirmingham', 'MiddleTennesseeState', 'Florida'], 'LouisianaTech': ['AlabamaBirmingham', 'MiddleTennesseeState', 'LouisianaTech'], 'LouisianaMonroe': ['AlabamaBirmingham', 'MiddleTennesseeState', 'LouisianaMonroe'], 'Illinois': ['AlabamaBirmingham', 'MiddleTennesseeState', 'Illinois'], 'MississippiState': ['AlabamaBirmingham', 'MiddleTennesseeState', 'MississippiState'], 'Maryland': ['AlabamaBirmingham', 'MiddleTennesseeState', 'Maryland'], 'ArkansasState': ['AlabamaBirmingham', 'Memphis', 'ArkansasState'], 'Tennessee': ['AlabamaBirmingham', 'Memphis', 'Tennessee'], 'Alabama': ['AlabamaBirmingham', 'SouthernMississippi', 'Alabama'], 'OklahomaState': ['AlabamaBirmingham', 'SouthernMississippi', 'OklahomaState'], 'BostonCollege': ['AlabamaBirmingham', 'Army', 'BostonCollege'], 'NewMexicoState': ['AlabamaBirmingham', 'Army', 'NewMexicoState'], 'Navy': ['AlabamaBirmingham', 'Army', 'Navy'], 'AirForce': ['AlabamaBirmingham', 'Army', 'AirForce'], 'Wisconsin': ['AlabamaBirmingham', 'Cincinnati', 'Wisconsin'], 'MiamiOhio': ['AlabamaBirmingham', 'Cincinnati', 'MiamiOhio'], 'Indiana': ['AlabamaBirmingham', 'Cincinnati', 'Indiana'], 'Auburn': ['AlabamaBirmingham', 'LouisianaState', 'Auburn'], 'Mississippi': ['AlabamaBirmingham', 'LouisianaState', 'Mississippi'], 'Arkansas': ['AlabamaBirmingham', 'LouisianaState', 'Arkansas'], 'NorthTexas': ['AlabamaBirmingham', 'LouisianaLafayette', 'NorthTexas'], 'Akron': ['AlabamaBirmingham', 'EastCarolina', 'VirginiaTech', 'Akron'], 'Virginia': ['AlabamaBirmingham', 'EastCarolina', 'VirginiaTech', 'Virginia'], 'CentralFlorida': ['AlabamaBirmingham', 'EastCarolina', 'VirginiaTech', 'CentralFlorida'], 'Pittsburgh': ['AlabamaBirmingham', 'EastCarolina', 'VirginiaTech', 'Pittsburgh'], 'Temple': ['AlabamaBirmingham', 'EastCarolina', 'VirginiaTech', 'Temple'], 'Rutgers': ['AlabamaBirmingham', 'EastCarolina', 'VirginiaTech', 'Rutgers'], 'MiamiFlorida': ['AlabamaBirmingham', 'EastCarolina', 'VirginiaTech', 'MiamiFlorida'], 'Idaho': ['AlabamaBirmingham', 'EastCarolina', 'WestVirginia', 'Idaho'], 'NotreDame': ['AlabamaBirmingham', 'EastCarolina', 'WestVirginia', 'NotreDame'], 'BrighamYoung': ['AlabamaBirmingham', 'EastCarolina', 'Syracuse', 'BrighamYoung'], 'Buffalo': ['AlabamaBirmingham', 'EastCarolina', 'Syracuse', ' ...
# Arkansas
# {'Arkansas': ['Arkansas'], 'Auburn': ['Arkansas', 'Auburn'], 'Alabama': ['Arkansas', 'Alabama'], 'BoiseState': ['Arkansas', 'BoiseState'], 'LouisianaMonroe': ['Arkansas', 'LouisianaMonroe'], 'MississippiState': ['Arkansas', 'MississippiState'], 'SouthCarolina': ['Arkansas', 'SouthCarolina'], 'Tennessee': ['Arkansas', 'Tennessee'], 'Mississippi': ['Arkansas', 'Mississippi'], 'Georgia': ['Arkansas', 'Georgia'], 'LouisianaState': ['Arkansas', 'LouisianaState'], 'NorthernIllinois': ['Arkansas', 'Auburn', 'NorthernIllinois'], 'Wyoming': ['Arkansas', 'Auburn', 'Wyoming'], 'Florida': ['Arkansas', 'Auburn', 'Florida'], 'LouisianaTech': ['Arkansas', 'Auburn', 'LouisianaTech'], 'Vanderbilt': ['Arkansas', 'Auburn', 'Vanderbilt'], 'UCLA': ['Arkansas', 'Alabama', 'UCLA'], 'CentralFlorida': ['Arkansas', 'Alabama', 'CentralFlorida'], 'SouthernMississippi': ['Arkansas', 'Alabama', 'SouthernMississippi'], 'NewMexico': ['Arkansas', 'BoiseState', 'NewMexico'], 'NorthTexas': ['Arkansas', 'BoiseState', 'NorthTexas'], 'ArkansasState': ['Arkansas', 'BoiseState', 'ArkansasState'], 'CentralMichigan': ['Arkansas', 'BoiseState', 'CentralMichigan'], 'Idaho': ['Arkansas', 'BoiseState', 'Idaho'], 'NewMexicoState': ['Arkansas', 'BoiseState', 'NewMexicoState'], 'WashingtonState': ['Arkansas', 'BoiseState', 'WashingtonState'], 'UtahState': ['Arkansas', 'BoiseState', 'UtahState'], 'Minnesota': ['Arkansas', 'LouisianaMonroe', 'Minnesota'], 'MiddleTennesseeState': ['Arkansas', 'LouisianaMonroe', 'MiddleTennesseeState'], 'Memphis': ['Arkansas', 'LouisianaMonroe', 'Memphis'], 'LouisianaLafayette': ['Arkansas', 'LouisianaMonroe', 'LouisianaLafayette'], 'BrighamYoung': ['Arkansas', 'MississippiState', 'BrighamYoung'], 'Kentucky': ['Arkansas', 'MississippiState', 'Kentucky'], 'EasternMichigan': ['Arkansas', 'SouthCarolina', 'EasternMichigan'], 'Clemson': ['Arkansas', 'SouthCarolina', 'Clemson'], 'Tulane': ['Arkansas', 'Mississippi', 'Tulane'], 'NevadaLasVegas': ['Arkansas', 'Mississippi', 'NevadaLasVegas'], 'GeorgiaTech': ['Arkansas', 'Georgia', 'GeorgiaTech'], 'Houston': ['Arkansas', 'LouisianaState', 'Houston'], 'AlabamaBirmingham': ['Arkansas', 'LouisianaState', 'AlabamaBirmingham'], 'Northwestern': ['Arkansas', 'Auburn', 'NorthernIllinois', 'Northwestern'], 'WesternMichigan': ['Arkansas', 'Auburn', 'NorthernIllinois', 'WesternMichigan'], 'Akron': ['Arkansas', 'Auburn', 'NorthernIllinois', 'Akron'], 'BallState': ['Arkansas', 'Auburn', 'NorthernIllinois', 'BallState'], 'Buffalo': ['Arkansas', 'Auburn', 'NorthernIllinois', 'Buffalo'], 'Toledo': ['Arkansas', 'Auburn', 'NorthernIllinois', 'Toledo'], 'SanDiegoState': ['Arkansas', 'Auburn', 'Wyoming', 'SanDiegoState'], 'Utah': ['Arkansas', 'Auburn', 'Wyoming', 'Utah'], 'ColoradoState': ['Arkansas', 'Auburn', 'Wyoming', 'ColoradoState'], 'Nevada': ['Arkansas', 'Auburn', 'Wyoming', 'Nevada'], 'TexasA&M': ['Arkansas', 'Auburn', 'Wyoming', 'TexasA&M'], 'AirForce': ['Arkansas', 'Auburn', 'Wyoming', 'AirForce'], 'FloridaState': ['Arkansas', 'Auburn', 'Florida', 'FloridaState'], 'KansasState': ['Arkansas', 'Auburn', 'LouisianaTech', 'KansasState'], 'PennState': ['Arkansas', 'Auburn', 'LouisianaTech', 'PennState'], 'Tulsa': ['Arkansas', 'Auburn', 'LouisianaTech', 'Tulsa'], 'MiamiFlorida': ['Arkansas', 'Auburn', 'LouisianaTech', 'MiamiFlorida'], 'Hawaii': ['Arkansas', 'Auburn', 'LouisianaTech', 'Hawaii'], 'Duke': ['Arkansas', 'Auburn', 'Vanderbilt', 'Duke'], 'MiamiOhio': ['Arkansas', 'Auburn', 'Vanderbilt', 'MiamiOhio'], 'WakeForest': ['Arkansas', 'Auburn', 'Vanderbilt', 'WakeForest'], 'SouthernCalifornia': ['Arkansas', 'Alabama', 'UCLA', 'SouthernCalifornia'], 'ArizonaState': ['Arkansas', 'Alabama', 'UCLA', 'ArizonaState'], 'Arizona': ['Arkansas', 'Alabama', 'UCLA', 'Arizona'], 'Michigan': ['Arkansas', 'Alabama', 'UCLA', 'Michigan'], 'FresnoState': ['Arkansas', 'Alabama', 'UCLA', 'FresnoState'], 'Washington': ['Arkansas', 'Alabama', 'UCLA', 'Washington'], 'Oregon': ['Arkansas', 'Alabama', 'UCLA', 'Oregon'], 'Stanford': ['Arkans ...
# Hawaii
# {'Hawaii': ['Hawaii'], 'Wisconsin': ['Hawaii', 'Wisconsin'], 'FresnoState': ['Hawaii', 'FresnoState'], 'Rice': ['Hawaii', 'Rice'], 'SouthernMethodist': ['Hawaii', 'SouthernMethodist'], 'LouisianaTech': ['Hawaii', 'LouisianaTech'], 'Nevada': ['Hawaii', 'Nevada'], 'SanJoseState': ['Hawaii', 'SanJoseState'], 'TexasElPaso': ['Hawaii', 'TexasElPaso'], 'Tulsa': ['Hawaii', 'Tulsa'], 'NevadaLasVegas': ['Hawaii', 'NevadaLasVegas'], 'TexasChristian': ['Hawaii', 'TexasChristian'], 'Iowa': ['Hawaii', 'Wisconsin', 'Iowa'], 'Northwestern': ['Hawaii', 'Wisconsin', 'Northwestern'], 'WesternMichigan': ['Hawaii', 'Wisconsin', 'WesternMichigan'], 'Michigan': ['Hawaii', 'Wisconsin', 'Michigan'], 'Purdue': ['Hawaii', 'Wisconsin', 'Purdue'], 'OhioState': ['Hawaii', 'Wisconsin', 'OhioState'], 'Minnesota': ['Hawaii', 'Wisconsin', 'Minnesota'], 'Oregon': ['Hawaii', 'Wisconsin', 'Oregon'], 'Cincinnati': ['Hawaii', 'Wisconsin', 'Cincinnati'], 'MichiganState': ['Hawaii', 'Wisconsin', 'MichiganState'], 'Indiana': ['Hawaii', 'Wisconsin', 'Indiana'], 'UCLA': ['Hawaii', 'FresnoState', 'UCLA'], 'California': ['Hawaii', 'FresnoState', 'California'], 'Houston': ['Hawaii', 'Rice', 'Houston'], 'Oklahoma': ['Hawaii', 'Rice', 'Oklahoma'], 'NorthCarolinaState': ['Hawaii', 'SouthernMethodist', 'NorthCarolinaState'], 'Kansas': ['Hawaii', 'SouthernMethodist', 'Kansas'], 'Tulane': ['Hawaii', 'SouthernMethodist', 'Tulane'], 'KansasState': ['Hawaii', 'LouisianaTech', 'KansasState'], 'PennState': ['Hawaii', 'LouisianaTech', 'PennState'], 'Auburn': ['Hawaii', 'LouisianaTech', 'Auburn'], 'CentralFlorida': ['Hawaii', 'LouisianaTech', 'CentralFlorida'], 'LouisianaMonroe': ['Hawaii', 'LouisianaTech', 'LouisianaMonroe'], 'MiddleTennesseeState': ['Hawaii', 'LouisianaTech', 'MiddleTennesseeState'], 'LouisianaLafayette': ['Hawaii', 'LouisianaTech', 'LouisianaLafayette'], 'MiamiFlorida': ['Hawaii', 'LouisianaTech', 'MiamiFlorida'], 'Wyoming': ['Hawaii', 'Nevada', 'Wyoming'], 'ColoradoState': ['Hawaii', 'Nevada', 'ColoradoState'], 'SouthernCalifornia': ['Hawaii', 'SanJoseState', 'SouthernCalifornia'], 'Nebraska': ['Hawaii', 'SanJoseState', 'Nebraska'], 'Stanford': ['Hawaii', 'SanJoseState', 'Stanford'], 'NewMexicoState': ['Hawaii', 'TexasElPaso', 'NewMexicoState'], 'TexasA&M': ['Hawaii', 'TexasElPaso', 'TexasA&M'], 'NorthCarolina': ['Hawaii', 'Tulsa', 'NorthCarolina'], 'OklahomaState': ['Hawaii', 'Tulsa', 'OklahomaState'], 'BrighamYoung': ['Hawaii', 'NevadaLasVegas', 'BrighamYoung'], 'NewMexico': ['Hawaii', 'NevadaLasVegas', 'NewMexico'], 'SanDiegoState': ['Hawaii', 'NevadaLasVegas', 'SanDiegoState'], 'NorthTexas': ['Hawaii', 'NevadaLasVegas', 'NorthTexas'], 'Utah': ['Hawaii', 'NevadaLasVegas', 'Utah'], 'IowaState': ['Hawaii', 'NevadaLasVegas', 'IowaState'], 'Mississippi': ['Hawaii', 'NevadaLasVegas', 'Mississippi'], 'AirForce': ['Hawaii', 'NevadaLasVegas', 'AirForce'], 'ArkansasState': ['Hawaii', 'TexasChristian', 'ArkansasState'], 'Navy': ['Hawaii', 'TexasChristian', 'Navy'], 'Illinois': ['Hawaii', 'Wisconsin', 'Iowa', 'Illinois'], 'NorthernIllinois': ['Hawaii', 'Wisconsin', 'Northwestern', 'NorthernIllinois'], 'Duke': ['Hawaii', 'Wisconsin', 'Northwestern', 'Duke'], 'BallState': ['Hawaii', 'Wisconsin', 'WesternMichigan', 'BallState'], 'CentralMichigan': ['Hawaii', 'Wisconsin', 'WesternMichigan', 'CentralMichigan'], 'EasternMichigan': ['Hawaii', 'Wisconsin', 'WesternMichigan', 'EasternMichigan'], 'Kent': ['Hawaii', 'Wisconsin', 'WesternMichigan', 'Kent'], 'Ohio': ['Hawaii', 'Wisconsin', 'WesternMichigan', 'Ohio'], 'Toledo': ['Hawaii', 'Wisconsin', 'WesternMichigan', 'Toledo'], 'Marshall': ['Hawaii', 'Wisconsin', 'WesternMichigan', 'Marshall'], 'BowlingGreenState': ['Hawaii', 'Wisconsin', 'Michigan', 'BowlingGreenState'], 'NotreDame': ['Hawaii', 'Wisconsin', 'Purdue', 'NotreDame'], 'Arizona': ['Hawaii', 'Wisconsin', 'OhioState', 'Arizona'], 'MiamiOhio': ['Hawaii', 'Wisconsin', 'OhioState', 'MiamiOhio'], 'Baylor': ['Hawaii', 'Wisconsin', 'Minnesota', 'Baylor'], 'ArizonaState': ['Hawa ...

# %%
N = nx.number_of_nodes(G)
M = nx.number_of_edges(G)

lb = np.zeros((N), dtype=int)
ub = np.zeros((N), dtype=int)
time = np.zeros((N), dtype=int)
gap = np.zeros((N), dtype=int)
nodes = np.zeros((N), dtype=int)

for i in G:

    model = gp.Model("tukey") #cria o modelo

    x = model.addVars(N, vtype=GRB.BINARY, name='x') #Adicionando Variáveis 
    
    obj = 0
    for j in G:
        obj += 1 * x[j]
         
    model.setObjective(obj, GRB.MINIMIZE)
    
    # configurando parametros
    # model.Params.TimeLimit = 60
    model.Params.MIPGap = 1.e-6
    model.Params.Threads = 1
    # model.Params.Presolve = 0
    # model.Params.Cuts = 0
 
    # Turn off display and heuristics
    gp.setParam('OutputFlag', 0)
    gp.setParam('Heuristics', 0)

    constr0 = 0
    constr0 += 1*x[i]
    model.addConstr(constr0 == 1)

    for u in range(0,N):
        for w in range(u+1,N):
            if dm[u,w] <= N:
                for s in range(0,N):
                    if (s != u) and (s != w):
                        if (dm[u,s] + dm[s,w] == dm[u,w]):
                            constr1 = x[u] + x[w]
                            model.addConstr(constr1 >= x[s])

    #relax = model.relax()    
    #relax.optimize()

    model.optimize()
    
    lb[i] = model.objBound
    ub[i] = model.objVal
    gap[i] = model.MIPGap
    time[i] = model.Runtime
    nodes[i] = model.NodeCount

# %%
t = 0
for i in ub:
    print("tukey[%d] =" %t, end=" ")
    print("%g" %i)
    t = t+1
# Out:
# tukey[0] = 21
# tukey[1] = 21
# tukey[2] = 19
# tukey[3] = 3
# tukey[4] = 2
# tukey[5] = 3
# tukey[6] = 3
# tukey[7] = 1
# tukey[8] = 19
# tukey[9] = 19
# tukey[10] = 2
# tukey[11] = 1
# tukey[12] = 1
# tukey[13] = 19
# tukey[14] = 1
# tukey[15] = 1
# tukey[16] = 1
# tukey[17] = 1
# tukey[18] = 1
# tukey[19] = 19
# tukey[20] = 1
# tukey[21] = 1
# tukey[22] = 1
# tukey[23] = 19
# tukey[24] = 19
# tukey[25] = 19
# tukey[26] = 1
# tukey[27] = 19
# tukey[28] = 19
# tukey[29] = 2
# tukey[30] = 19
# tukey[31] = 19
# tukey[32] = 19
# tukey[33] = 19

# %%
N = nx.number_of_nodes(G)
M = nx.number_of_edges(G)

lb = np.zeros((N), dtype=int)
ub = np.zeros((N), dtype=int)
time = np.zeros((N), dtype=int)
gap = np.zeros((N), dtype=int)
nodes = np.zeros((N), dtype=int)

for i in G:

    model = gp.Model("tukey") #cria o modelo

    # configurando parametros
    # model.Params.TimeLimit = 60
    model.Params.MIPGap = 1.e-6
    model.Params.Threads = 1
    # model.Params.Presolve = 0
    # model.Params.Cuts = 0

    x = model.addVars(N, vtype=GRB.BINARY, name='x') #Adicionando Variáveis 
    
    obj = 0
    for j in G:
        obj += 1 * x[j]
         
    model.setObjective(obj, GRB.MAXIMIZE)
     
    # Turn off display and heuristics
    gp.setParam('OutputFlag', 0)
    gp.setParam('Heuristics', 0)

    constr0 = 0
    constr0 += 1 * x[i]
    model.addConstr(constr0 == 0)

    for u in range(0,N):
        for w in range(u+1,N):
            if dm[u,w] <= N:
                for s in range(0,N):
                    if (s != u) and (s != w):
                        if (dm[u,s] + dm[s,w] == dm[u,w]):
                            constr1 = x[u] + x[w]
                            model.addConstr(constr1 <= 1 + x[s])

    #relax = model.relax()
    #relax.optimize()

    model.optimize()

    lb[i] = N - model.objBound
    ub[i] = N - model.objVal
    gap[i] = model.MIPGap
    time[i] = model.Runtime
    nodes[i] = model.NodeCount

# %%
t = 0
for i in ub:
    print("tukey[%d] =" %t, end=" ")
    print("%g" %i)
    t = t+1
# Out:
# tukey[0] = 21
# tukey[1] = 21
# tukey[2] = 19
# tukey[3] = 3
# tukey[4] = 2
# tukey[5] = 3
# tukey[6] = 3
# tukey[7] = 1
# tukey[8] = 19
# tukey[9] = 19
# tukey[10] = 2
# tukey[11] = 1
# tukey[12] = 1
# tukey[13] = 19
# tukey[14] = 1
# tukey[15] = 1
# tukey[16] = 1
# tukey[17] = 1
# tukey[18] = 1
# tukey[19] = 19
# tukey[20] = 1
# tukey[21] = 1
# tukey[22] = 1
# tukey[23] = 19
# tukey[24] = 19
# tukey[25] = 19
# tukey[26] = 1
# tukey[27] = 19
# tukey[28] = 19
# tukey[29] = 2
# tukey[30] = 19
# tukey[31] = 19
# tukey[32] = 19
# tukey[33] = 19

# %%
N = nx.number_of_nodes(G)
M = nx.number_of_edges(G)

lb = np.zeros((N), dtype=int)
ub = np.zeros((N), dtype=int)
time = np.zeros((N), dtype=int)
gap = np.zeros((N), dtype=int)
nodes = np.zeros((N), dtype=int)

for i in G:

    model = gp.Model("tukey") #cria o modelo

    # configurando parametros
    # model.Params.TimeLimit = 60
    model.Params.MIPGap = 1.e-6
    model.Params.Threads = 1
    # model.Params.Presolve = 0
    # model.Params.Cuts = 0

    x = model.addVars(N, vtype=GRB.BINARY, name='x') #Adicionando Variáveis 
    
    obj = 0
    for j in G:
        obj += 1 * x[j]
         
    model.setObjective(obj, GRB.MAXIMIZE)
     
    # Turn off display and heuristics
    gp.setParam('OutputFlag', 0)
    gp.setParam('Heuristics', 0)

    constr0 = 0
    constr0 += 1 * x[i]
    model.addConstr(constr0 == 0)

    for u in range(0,N):
        for w in range(u+1,N):
            if dm[u,w] <= N:
                for s in range(0,N):
                    if (s != u) and (s != w):
                        if (dm[u,s] + dm[s,w] == dm[u,w]):
                            constr1 = x[u] + x[w]
                            model.addConstr(constr1 <= 1 + x[s])

                            Is = nx.maximal_independent_set(G, [s])
                            for k in Is:
                                constr2 = 1 * x[k]
                            constr2 += 1 + (len(Is)- 1)*x[s]                            

    #relax = model.relax()
    #relax.optimize()

    model.optimize()

    lb[i] = N - model.objBound
    ub[i] = N - model.objVal
    gap[i] = model.MIPGap
    time[i] = model.Runtime
    nodes[i] = model.NodeCount

# %%
t = 0
for i in ub:
    print("tukey[%d] =" %t, end=" ")
    print("%g" %i)
    t = t+1
# Out:
# tukey[0] = 21
# tukey[1] = 21
# tukey[2] = 19
# tukey[3] = 3
# tukey[4] = 2
# tukey[5] = 3
# tukey[6] = 3
# tukey[7] = 1
# tukey[8] = 19
# tukey[9] = 19
# tukey[10] = 2
# tukey[11] = 1
# tukey[12] = 1
# tukey[13] = 19
# tukey[14] = 1
# tukey[15] = 1
# tukey[16] = 1
# tukey[17] = 1
# tukey[18] = 1
# tukey[19] = 19
# tukey[20] = 1
# tukey[21] = 1
# tukey[22] = 1
# tukey[23] = 19
# tukey[24] = 19
# tukey[25] = 19
# tukey[26] = 1
# tukey[27] = 19
# tukey[28] = 19
# tukey[29] = 2
# tukey[30] = 19
# tukey[31] = 19
# tukey[32] = 19
# tukey[33] = 19
