# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="karate"
method_="mip"
ver_="fmin"

# %%
form_="fminc0"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_c0 = table
#mip_karate_c0

#print(mip_karate_c0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminc0noclq"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_c0noclq = table
#mip_karate_c0noclq

#print(mip_karate_c0noclq[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminc1"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_c1 = table
#mip_karate_c1

#print(mip_karate_c1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminc1noclq"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_c1noclq = table
#mip_karate_c1noclq

#print(mip_karate_c1noclq[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminc2"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_c2 = table
#mip_karate_c2

#print(mip_karate_c2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminmisetc2"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_misetc2 = table
#mip_karate_misetc2

#print(mip_karate_misetc2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminmisetc3"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_misetc3 = table
#mip_karate_misetc3

#print(mip_karate_misetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminmiset"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_miset = table
#mip_karate_miset

#print(mip_karate_miset[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
merge_karate = pd.DataFrame()

merge_karate = pd.merge(
    mip_karate_c0, mip_karate_c0noclq,
    on=['vertice'], 
    suffixes=("", "_b"),
    )

merge_karate = pd.merge(
    merge_karate, mip_karate_c1,
    on=['vertice'], 
    suffixes=("", "_c"),
    )

merge_karate = pd.merge(
    merge_karate, mip_karate_c1noclq,
    on=['vertice'], 
    suffixes=("", "_d"),
    )

merge_karate = pd.merge(
    merge_karate, mip_karate_c2,
    on=['vertice'], 
    suffixes=("", "_e"),
    )

merge_karate = pd.merge(
    merge_karate, mip_karate_misetc2,
    on=['vertice'], 
    suffixes=("", "_f"),
    )

merge_karate = pd.merge(
    merge_karate, mip_karate_misetc3,
    on=['vertice'], 
    suffixes=("", "_g"),
    )

merge_karate = pd.merge(
    merge_karate, mip_karate_miset,
    on=['vertice'], 
    suffixes=("", "_h"),
    )

# %%
merge_karate[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',
    'bs_f','gap_f','time_f','opt_f','tk_f','tmax_f',    
    'bs_g','gap_g','time_g','opt_g','tk_g','tmax_g',    
    'bs_h','gap_h','time_h','opt_h','tk_h','tmax_h',
    ]]
# Out:
#    vertice     bs  gap  time   opt    tk  tmax   bs_b  gap_b  time_b  ...  \
# 0        0   21.0  0.0  0.03   1.0   NaN   NaN   21.0    0.0    0.03  ...
# 1        1   21.0  0.0  0.32   1.0   NaN   NaN   21.0    0.0    0.32  ...
# 2        2   19.0  0.0  0.01   1.0   NaN   NaN   19.0    0.0    0.01  ...
# 3        3    3.0  0.0  0.01   1.0   NaN   NaN    3.0    0.0    0.01  ...
# 4        4    2.0  0.0  0.01   1.0   NaN   NaN    2.0    0.0    0.01  ...
# 5        5    3.0  0.0  0.01   1.0   NaN   NaN    3.0    0.0    0.01  ...
# 6        6    3.0  0.0  0.01   1.0   NaN   NaN    3.0    0.0    0.01  ...
# 7        7    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.01  ...
# 8        8   19.0  0.0  0.09   1.0   NaN   NaN   19.0    0.0    0.09  ...
# 9        9   19.0  0.0  0.29   1.0   NaN   NaN   19.0    0.0    0.30  ...
# 10      10    2.0  0.0  0.01   1.0   NaN   NaN    2.0    0.0    0.01  ...
# 11      11    1.0  0.0  0.00   1.0   NaN   NaN    1.0    0.0    0.01  ...
# ...

# %%
print(
merge_karate[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',   
    'bs_f','gap_f','time_f','opt_f','tk_f','tmax_f',   
    'bs_g','gap_g','time_g','opt_g','tk_g','tmax_g',   
    'bs_h','gap_h','time_h','opt_h','tk_h','tmax_h',
    ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr}
# \toprule
# vertice &    bs &  gap &  time &  opt &   tk &  tmax &  bs\_b &  gap\_b &  time\_b &  opt\_b &  tk\_b &  tmax\_b &  bs\_c &  gap\_c &  time\_c &  opt\_c &  tk\_c &  tmax\_c &  bs\_d &  gap\_d &  time\_d &  opt\_d &  tk\_d &  tmax\_d &  bs\_e &  gap\_e &  time\_e &  opt\_e &  tk\_e &  tmax\_e &  bs\_f &  gap\_f &  time\_f &  opt\_f &  tk\_f &  tmax\_f &  bs\_g &  gap\_g &  time\_g &  opt\_g &  tk\_g &  tmax\_g &  bs\_h &  gap\_h &  time\_h &  opt\_h &  tk\_h &  tmax\_h \\
# \midrule
# ...

# %%
with open('../result/tex/mip_fmin_karate.tex', 'w') as tf:
     tf.write(
          merge_karate[[
          'vertice',
          'bs','time',#'opt',#'tk','tmax',
          'bs_b','time_b',#'opt_b',#'tk_b','tmax_b',
          'bs_c','time_c',#'opt_c',#'tk_c','tmax_c',
          'bs_d','time_d',#'opt_d',#'tk_d','tmax_d',
          'bs_e','time_e',#'opt_e',#'tk_e','tmax_e',
          'bs_f','time_f',#'opt_f',#'tk_f','tmax_f',
          'bs_g','time_g',#'opt_g',#'tk_g','tmax_g',
          'bs_h','time_h',#'opt_h',#'tk_h','tmax_h',
          ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# /tmp/ipykernel_7425/3009748323.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   merge_karate[[
