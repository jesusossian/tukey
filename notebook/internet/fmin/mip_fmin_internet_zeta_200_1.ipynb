# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="internet_graph"
method_="mip"
dim_=200
id_=1
ver_="fmin"

# %%
form_="fminmiset"

file=f"../result/{inst_}/zeta/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_miset = table
#mip_internet_miset

#print(mip_internet_miset[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminmisetc2"

file=f"../result/{inst_}/zeta/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_misetc2 = table
#mip_internet_misetc2

#print(mip_internet_misetc2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminmisetc3"

file=f"../result/{inst_}/zeta/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_misetc3 = table
#mip_internet_misetc3

#print(mip_internet_misetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmincutmisetc3"

file=f"../result/{inst_}/zeta/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_cutmisetc3 = table
#mip_internet_cutmisetc3

#print(mip_internet_misetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmincutbmisetc3"

file=f"../result/{inst_}/zeta/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_cutbmisetc3 = table
#mip_internet_cutbmisetc3

#print(mip_internet_cutbmisetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fminlazymisetc3"

file=f"../result/{inst_}/zeta/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_lazymisetc3 = table
mip_internet_lazymisetc3

#print(mip_internet_cutbmisetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                        vertice      bb      bs  gap   time   nodes    opt  \
# 0                            0   143.0   143.0  0.0   2.54   116.0    1.0
# 1                            1   124.0   124.0  0.0   0.61     9.0    1.0
# 2                            2   127.0   127.0  0.0   0.72    14.0    1.0
# 3                            3   124.0   124.0  0.0   1.04    43.0    1.0
# 4                            4   124.0   124.0  0.0   0.53    23.0    1.0
# ..                         ...     ...     ...  ...    ...     ...    ...
# 196                        196     1.0     1.0  0.0   0.00     0.0    1.0
# 197                        197     1.0     1.0  0.0   0.00     0.0    1.0
# 198                        198     1.0     1.0  0.0   0.00     0.0    1.0
# 199                        199     1.0     1.0  0.0   0.00     0.0    1.0
# 200  mip_fminlazymisetc3_200_1  5092.0  5092.0  0.0  36.14  1147.0  200.0
#
#         tk  tmax
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# ...

# %%
mip_merge = pd.DataFrame()

mip_merge = pd.merge(
    mip_internet_miset, mip_internet_misetc2,
    on=['vertice'], 
    suffixes=("", "_b"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_misetc3,
    on=['vertice'], 
    suffixes=("", "_b"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_cutmisetc3,
    on=['vertice'], 
    suffixes=("", "_c"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_cutbmisetc3,
    on=['vertice'], 
    suffixes=("", "_d"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_cutbmisetc3,
    on=['vertice'], 
    suffixes=("", "_e"),
    )

mip_merge[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',
    ]]
# Out:
#     vertice     bs  gap  time  opt  tk  tmax   bs_b   bs_b  gap_b  ...  \
# 0         0  137.0  0.0  0.11  1.0 NaN   NaN  143.0  143.0    0.0  ...
# 1         1  120.0  0.0  0.03  1.0 NaN   NaN  124.0  124.0    0.0  ...
# 2         2  122.0  0.0  0.02  1.0 NaN   NaN  127.0  127.0    0.0  ...
# 3         3  120.0  0.0  0.11  1.0 NaN   NaN  124.0  124.0    0.0  ...
# 4         4  120.0  0.0  0.14  1.0 NaN   NaN  124.0  124.0    0.0  ...
# ..      ...    ...  ...   ...  ...  ..   ...    ...    ...    ...  ...
# 195     195    1.0  0.0  0.00  1.0 NaN   NaN    1.0    1.0    0.0  ...
# 196     196    1.0  0.0  0.00  1.0 NaN   NaN    1.0    1.0    0.0  ...
# 197     197    1.0  0.0  0.00  1.0 NaN   NaN    1.0    1.0    0.0  ...
# 198     198    1.0  0.0  0.00  1.0 NaN   NaN    1.0    1.0    0.0  ...
# 199     199    1.0  0.0  0.00  1.0 NaN   NaN    1.0    1.0    0.0  ...
#
#      time_d  opt_d  tk_d  tmax_d   bs_e  gap_e  time_e  opt_e  tk_e  tmax_e
# ...

# %%
print(
mip_merge[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr}
# \toprule
# vertice &    bs &  gap &  time &  opt &  tk &  tmax &  bs\_b &  bs\_b &  gap\_b &  gap\_b &  time\_b &  time\_b &  opt\_b &  opt\_b &  tk\_b &  tk\_b &  tmax\_b &  tmax\_b &  bs\_c &  gap\_c &  time\_c &  opt\_c &  tk\_c &  tmax\_c &  bs\_d &  gap\_d &  time\_d &  opt\_d &  tk\_d &  tmax\_d \\
# \midrule
#       0 & 137.0 &  0.0 &   0.1 &  1.0 & NaN &   NaN & 143.0 & 143.0 &    0.0 &    0.0 &     6.5 &     5.7 &    1.0 &    1.0 &   NaN &   NaN &     NaN &     NaN & 143.0 &    0.0 &     4.5 &    1.0 &   NaN &     NaN & 143.0 &    0.0 &     3.9 &    1.0 &   NaN &     NaN \\
#       1 & 120.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN & 124.0 & 124.0 &    0.0 &    0.0 &     3.5 &     2.8 &    1.0 &    1.0 &   NaN &   NaN &     NaN &     NaN & 124.0 &    0.0 &     1.3 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &     0.9 &    1.0 &   NaN &     NaN \\
# ...

# %%
mip_concat = pd.DataFrame()
mip_concat = pd.concat([mip_concat, mip_internet_miset.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_misetc2.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_misetc3.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_cutmisetc3.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_cutbmisetc3.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_lazymisetc3.loc[200:200]], ignore_index=True)
mip_concat
# Out:
#                      vertice      bb      bs  gap    time   nodes    opt  \
# 0        mip_fminmiset_200_1  4931.0  4931.0  0.0    4.19   658.0  200.0
# 1      mip_fminmisetc2_200_1  5092.0  5092.0  0.0  399.86   434.0  200.0
# 2      mip_fminmisetc3_200_1  5092.0  5092.0  0.0  353.14   472.0  200.0
# 3   mip_fmincutmisetc3_200_1  5092.0  5092.0  0.0   73.57   868.0  200.0
# 4  mip_fmincutbmisetc3_200_1  5092.0  5092.0  0.0   64.19   867.0  200.0
# 5  mip_fminlazymisetc3_200_1  5092.0  5092.0  0.0   36.14  1147.0  200.0
#
#       tk   tmax
# 0  146.0   0.17
# 1  149.0  18.82
# 2  149.0  19.61
# 3  149.0   4.52
# 4  149.0   3.92
# 5  149.0   2.54

# %%
#print(
#mip_concat[[
#    'vertice','bs','gap','time','opt','tk','tmax',
#    ]].to_latex(index=False,float_format="%.1f")
#)

# %%
inst_="internet_graph"
method_="rf"
dim_=200
id_=1
ver_="fmin"

# %%
form_="fminrfc2"

file=f"../result/{inst_}/zeta/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bs','time']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bs':table["bs"].sum(),
    'time':table['time'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
rf_internet_c2_3_2 = table
rf_internet_c2_3_2

#print(mip_internet_c0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                vertice      bs    time     tk   tmax
# 0                    0   199.0    6.41    NaN    NaN
# 1                    1   199.0    6.65    NaN    NaN
# 2                    2   199.0    6.41    NaN    NaN
# 3                    3   199.0    7.94    NaN    NaN
# 4                    4   199.0    8.73    NaN    NaN
# ..                 ...     ...     ...    ...    ...
# 196                196     1.0    0.00    NaN    NaN
# 197                197     1.0    0.00    NaN    NaN
# 198                198     1.0    0.00    NaN    NaN
# 199                199     1.0    0.00    NaN    NaN
# 200  rf_fminrfc2_200_1  7067.0  230.84  199.0  10.72
#
# [201 rows x 5 columns]
