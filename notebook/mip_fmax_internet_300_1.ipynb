# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="internet_graph"
method_="mip"
dim_=300
id_=1
ver_="fmax"

# %%
form_="fmaxc0"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c0 = table
#mip_internet_c0

#print(mip_internet_c0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmaxc0noclq"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c0noclq = table
#mip_internet_c0noclq

#print(mip_internet_c0noclq[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmaxc1"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c1 = table
#mip_internet_c1

#print(mip_internet_c1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmaxc1noclq"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c1noclq = table
#mip_internet_c1noclq

#print(mip_internet_c1noclq[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmaxc2"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c2 = table
#mip_internet_c2

#print(mip_internet_c2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmaxmisetc2"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_misetc2 = table
#mip_internet_misetc2

#print(mip_internet_misetc2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmaxmisetc3"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_misetc3 = table
#mip_internet_misetc3

#print(mip_internet_misetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
form_="fmaxmiset"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_miset = table
#mip_internet_miset

#print(mip_internet_miset[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
mip_merge = pd.DataFrame()

mip_merge = pd.merge(
    mip_internet_c0, mip_internet_c0noclq,
    on=['vertice'], 
    suffixes=("", "_b"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_c1,
    on=['vertice'], 
    suffixes=("", "_c"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_c1noclq,
    on=['vertice'], 
    suffixes=("", "_d"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_c2,
    on=['vertice'], 
    suffixes=("", "_e"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_misetc2,
    on=['vertice'], 
    suffixes=("", "_f"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_misetc3,
    on=['vertice'], 
    suffixes=("", "_g"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_miset,
    on=['vertice'], 
    suffixes=("", "_h"),
    )


mip_merge[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',
    'bs_f','gap_f','time_f','opt_f','tk_f','tmax_f',
    'bs_g','gap_g','time_g','opt_g','tk_g','tmax_g',
    'bs_h','gap_h','time_h','opt_h','tk_h','tmax_h',
    ]]
# Out:
#     vertice     bs  gap    time  opt  tk  tmax   bs_b  gap_b  time_b  ...  \
# 0         0  224.0  0.0  245.65  1.0 NaN   NaN  224.0    0.0  239.48  ...
# 1         1  224.0  0.0  107.21  1.0 NaN   NaN  224.0    0.0  108.46  ...
# 2         2  224.0  0.0  188.99  1.0 NaN   NaN  224.0    0.0  181.44  ...
# 3         3  229.0  0.0   25.79  1.0 NaN   NaN  229.0    0.0   23.77  ...
# 4         4  224.0  0.0  167.39  1.0 NaN   NaN  224.0    0.0  154.29  ...
# ..      ...    ...  ...     ...  ...  ..   ...    ...    ...     ...  ...
# 295     295    1.0  0.0    0.00  1.0 NaN   NaN    1.0    0.0    1.88  ...
# 296     296    1.0  0.0    0.00  1.0 NaN   NaN    1.0    0.0    1.89  ...
# 297     297    1.0  0.0    0.00  1.0 NaN   NaN    1.0    0.0    1.88  ...
# 298     298    1.0  0.0    0.00  1.0 NaN   NaN    1.0    0.0    1.90  ...
# 299     299    1.0  0.0    0.00  1.0 NaN   NaN    1.0    0.0    1.88  ...
#
#      time_g  opt_g  tk_g  tmax_g   bs_h  gap_h  time_h  opt_h  tk_h  tmax_h
# ...

# %%
print(
mip_merge[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',
    'bs_f','gap_f','time_f','opt_f','tk_f','tmax_f',
    'bs_g','gap_g','time_g','opt_g','tk_g','tmax_g',
    'bs_h','gap_h','time_h','opt_h','tk_h','tmax_h',
    ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr}
# \toprule
# vertice &    bs &  gap &  time &  opt &  tk &  tmax &  bs\_b &  gap\_b &  time\_b &  opt\_b &  tk\_b &  tmax\_b &  bs\_c &  gap\_c &  time\_c &  opt\_c &  tk\_c &  tmax\_c &  bs\_d &  gap\_d &  time\_d &  opt\_d &  tk\_d &  tmax\_d &  bs\_e &  gap\_e &  time\_e &  opt\_e &  tk\_e &  tmax\_e &  bs\_f &  gap\_f &  time\_f &  opt\_f &  tk\_f &  tmax\_f &  bs\_g &  gap\_g &  time\_g &  opt\_g &  tk\_g &  tmax\_g &  bs\_h &  gap\_h &  time\_h &  opt\_h &  tk\_h &  tmax\_h \\
# \midrule
# ...

# %%
mip_concat = pd.DataFrame()
mip_concat = pd.concat([mip_concat, mip_internet_c0.loc[300:300]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c0noclq.loc[300:300]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c1.loc[300:300]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c1noclq.loc[300:300]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c2.loc[300:300]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_misetc2.loc[300:300]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_misetc3.loc[300:300]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_miset.loc[300:300]], ignore_index=True)
mip_concat
# Out:
#                  vertice       bb       bs   gap      time    nodes    opt  \
# 0       mip_fmaxc0_300_1  12155.0  12155.0  0.00  11342.63   8306.0  300.0
# 1  mip_fmaxc0noclq_300_1  12155.0  12155.0  0.00  11509.79   8548.0  300.0
# 2       mip_fmaxc1_300_1  12084.0  12155.0  0.93  10898.98   8182.0  299.0
# 3  mip_fmaxc1noclq_300_1  12084.0  12155.0  0.93  11071.63   8477.0  299.0
# 4       mip_fmaxc2_300_1  12155.0  12155.0  0.00   3576.05  14369.0  300.0
# 5  mip_fmaxmisetc2_300_1  12155.0  12155.0  0.00   3077.11   1079.0  300.0
# 6  mip_fmaxmisetc3_300_1  12155.0  12155.0  0.00   2749.65   1102.0  300.0
# 7    mip_fmaxmiset_300_1  11776.0  11776.0  0.00     15.41   1923.0  300.0
#
#       tk    tmax
# 0  229.0  345.81
# 1  229.0  343.39
# 2  229.0  600.01
# 3  229.0  600.22
# 4  229.0  108.87
# 5  229.0  141.12
# 6  229.0   95.46
# 7  220.0    0.45

# %%
print(
mip_concat[[
    'vertice','bs','gap','time','opt','tk','tmax',
    ]].to_latex(index=False,float_format="%.1f")
)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
#               vertice &      bs &  gap &    time &   opt &    tk &  tmax \\
# \midrule
#      mip\_fmaxc0\_300\_1 & 12155.0 &  0.0 & 11342.6 & 300.0 & 229.0 & 345.8 \\
# mip\_fmaxc0noclq\_300\_1 & 12155.0 &  0.0 & 11509.8 & 300.0 & 229.0 & 343.4 \\
#      mip\_fmaxc1\_300\_1 & 12155.0 &  0.9 & 10899.0 & 299.0 & 229.0 & 600.0 \\
# mip\_fmaxc1noclq\_300\_1 & 12155.0 &  0.9 & 11071.6 & 299.0 & 229.0 & 600.2 \\
#      mip\_fmaxc2\_300\_1 & 12155.0 &  0.0 &  3576.0 & 300.0 & 229.0 & 108.9 \\
# mip\_fmaxmisetc2\_300\_1 & 12155.0 &  0.0 &  3077.1 & 300.0 & 229.0 & 141.1 \\
# mip\_fmaxmisetc3\_300\_1 & 12155.0 &  0.0 &  2749.7 & 300.0 & 229.0 &  95.5 \\
#   mip\_fmaxmiset\_300\_1 & 11776.0 &  0.0 &    15.4 & 300.0 & 220.0 &   0.5 \\
# \bottomrule
# \end{tabular}
# ...
