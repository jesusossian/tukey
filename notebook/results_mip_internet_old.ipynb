# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="internet_graph"
method_="mip"

# %%
form_="fmin"
dim_=200
id_=1

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fmin_200_1 = table
mip_internet_fmin_200_1

#print(mip_internet_fmin_200_1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#             vertice      bb      bs  gap    time   nodes    opt     tk   tmax
# 0                 0   143.0   143.0  0.0    8.19    65.0    1.0    NaN    NaN
# 1                 1   124.0   124.0  0.0    8.46     1.0    1.0    NaN    NaN
# 2                 2   127.0   127.0  0.0    3.35     1.0    1.0    NaN    NaN
# 3                 3   124.0   124.0  0.0   21.64    21.0    1.0    NaN    NaN
# 4                 4   124.0   124.0  0.0   11.74    67.0    1.0    NaN    NaN
# ..              ...     ...     ...  ...     ...     ...    ...    ...    ...
# 196             196     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 197             197     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 198             198     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 199             199     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 200  mip_fmin_200_1  5092.0  5092.0  0.0  613.07  2350.0  200.0  149.0  27.17
#
# [201 rows x 9 columns]

# %%
form_="fmin"
dim_=200
id_=2

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fmin_200_2 = table
mip_internet_fmin_200_2

#print(mip_internet_fmin_200_2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#             vertice      bb      bs  gap    time   nodes    opt     tk   tmax
# 0                 0   138.0   138.0  0.0   15.73   115.0    1.0    NaN    NaN
# 1                 1   138.0   138.0  0.0   16.42   139.0    1.0    NaN    NaN
# 2                 2   138.0   138.0  0.0   14.82   111.0    1.0    NaN    NaN
# 3                 3   138.0   138.0  0.0   14.61    37.0    1.0    NaN    NaN
# 4                 4   138.0   138.0  0.0   19.19   102.0    1.0    NaN    NaN
# ..              ...     ...     ...  ...     ...     ...    ...    ...    ...
# 196             196     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 197             197     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 198             198     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 199             199     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 200  mip_fmin_200_2  5997.0  5997.0  0.0  723.84  5777.0  200.0  153.0  24.85
#
# [201 rows x 9 columns]

# %%
form_="fmin"
dim_=200
id_=3

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fmin_200_3 = table
mip_internet_fmin_200_3

#print(mip_internet_fmin_200_3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#             vertice      bb      bs  gap    time   nodes    opt     tk   tmax
# 0                 0   137.0   137.0  0.0   12.34   111.0    1.0    NaN    NaN
# 1                 1   139.0   139.0  0.0   10.55    27.0    1.0    NaN    NaN
# 2                 2   137.0   137.0  0.0   15.61   115.0    1.0    NaN    NaN
# 3                 3   139.0   139.0  0.0   12.41   147.0    1.0    NaN    NaN
# 4                 4   139.0   139.0  0.0   13.82   115.0    1.0    NaN    NaN
# ..              ...     ...     ...  ...     ...     ...    ...    ...    ...
# 196             196     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 197             197     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 198             198     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 199             199     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 200  mip_fmin_200_3  5523.0  5523.0  0.0  649.25  4589.0  200.0  139.0  27.04
#
# [201 rows x 9 columns]

# %%
form_="fmax"
dim_=200
id_=1

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fmax_200_1 = table
mip_internet_fmax_200_1

#print(mip_internet_fmax_200_1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#             vertice      bb      bs  gap    time   nodes    opt     tk   tmax
# 0                 0   143.0   143.0  0.0   11.26    61.0    1.0    NaN    NaN
# 1                 1   124.0   124.0  0.0    6.75     1.0    1.0    NaN    NaN
# 2                 2   127.0   127.0  0.0    3.60     1.0    1.0    NaN    NaN
# 3                 3   124.0   124.0  0.0   16.90    15.0    1.0    NaN    NaN
# 4                 4   124.0   124.0  0.0   15.62    67.0    1.0    NaN    NaN
# ..              ...     ...     ...  ...     ...     ...    ...    ...    ...
# 196             196     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 197             197     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 198             198     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 199             199     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 200  mip_fmax_200_1  5092.0  5092.0  0.0  747.21  2260.0  200.0  149.0  50.21
#
# [201 rows x 9 columns]

# %%
form_="fmax"
dim_=200
id_=2

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fmax_200_2 = table
mip_internet_fmax_200_2

#print(mip_internet_fmax_200_2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#             vertice      bb      bs  gap    time   nodes    opt     tk   tmax
# 0                 0   138.0   138.0  0.0   21.93    80.0    1.0    NaN    NaN
# 1                 1   138.0   138.0  0.0   15.97   143.0    1.0    NaN    NaN
# 2                 2   138.0   138.0  0.0   14.59   115.0    1.0    NaN    NaN
# 3                 3   138.0   138.0  0.0   12.77    42.0    1.0    NaN    NaN
# 4                 4   138.0   138.0  0.0   16.45   123.0    1.0    NaN    NaN
# ..              ...     ...     ...  ...     ...     ...    ...    ...    ...
# 196             196     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 197             197     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 198             198     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 199             199     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 200  mip_fmax_200_2  5997.0  5997.0  0.0  790.65  5534.0  200.0  153.0  35.31
#
# [201 rows x 9 columns]

# %%
form_="fmax"
dim_=200
id_=3

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fmax_200_3 = table
mip_internet_fmax_200_3

#print(mip_internet_fmax_200_3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#             vertice      bb      bs  gap    time   nodes    opt     tk   tmax
# 0                 0   137.0   137.0  0.0   13.34   130.0    1.0    NaN    NaN
# 1                 1   139.0   139.0  0.0   14.74    43.0    1.0    NaN    NaN
# 2                 2   137.0   137.0  0.0   21.75   116.0    1.0    NaN    NaN
# 3                 3   139.0   139.0  0.0   11.23   123.0    1.0    NaN    NaN
# 4                 4   139.0   139.0  0.0   14.95   110.0    1.0    NaN    NaN
# ..              ...     ...     ...  ...     ...     ...    ...    ...    ...
# 196             196     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 197             197     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 198             198     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 199             199     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 200  mip_fmax_200_3  5523.0  5523.0  0.0  656.37  4389.0  200.0  139.0  25.28
#
# [201 rows x 9 columns]

# %%
form_="maxmiset0"
dim_=200
id_=1

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_maxmiset0_200_1 = table
mip_internet_maxmiset0_200_1

#print(mip_internet_maxmiset0_200_1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_39191/603849114.py in <module>
#       6
#       7 df = pd.DataFrame()
# ----> 8 df = pd.read_csv(file,header=None,sep=';')
#       9
#      10 table = pd.DataFrame()
#
# ...

# %%
form_="maxmiset0"
dim_=200
id_=2

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_maxmiset0_200_2 = table
mip_internet_maxmiset0_200_2

#print(mip_internet_maxmiset0_200_2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_39191/2298599623.py in <module>
#       6
#       7 df = pd.DataFrame()
# ----> 8 df = pd.read_csv(file,header=None,sep=';')
#       9
#      10 table = pd.DataFrame()
#
# ...

# %%
form_="maxmiset0"
dim_=200
id_=3

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_maxmiset0_200_3 = table
mip_internet_maxmiset0_200_3

#print(mip_internet_maxmiset0_200_3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_39191/825307542.py in <module>
#       6
#       7 df = pd.DataFrame()
# ----> 8 df = pd.read_csv(file,header=None,sep=';')
#       9
#      10 table = pd.DataFrame()
#
# ...

# %%
form_="minmiset"
dim_=200
id_=1

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_minmiset_200_1 = table
mip_internet_minmiset_200_1

#print(mip_internet_minmiset_200_1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                 vertice      bb      bs  gap  time  nodes    opt     tk  tmax
# 0                     0    94.0    94.0  0.0  0.03    2.0    1.0    NaN   NaN
# 1                     1    96.0    96.0  0.0  0.03    8.0    1.0    NaN   NaN
# 2                     2    98.0    98.0  0.0  0.04   37.0    1.0    NaN   NaN
# 3                     3    93.0    93.0  0.0  0.04   32.0    1.0    NaN   NaN
# 4                     4    70.0    70.0  0.0  0.03   12.0    1.0    NaN   NaN
# ..                  ...     ...     ...  ...   ...    ...    ...    ...   ...
# 196                 196     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 197                 197     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 198                 198     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 199                 199     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 200  mip_minmiset_200_1  3425.0  3425.0  0.0  1.32  746.0  200.0  102.0  0.05
#
# [201 rows x 9 columns]

# %%
form_="minmiset"
dim_=200
id_=2

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_minmiset_200_2 = table
mip_internet_minmiset_200_2

#print(mip_internet_minmiset_200_2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                 vertice      bb      bs  gap  time  nodes    opt     tk  tmax
# 0                     0    65.0    65.0  0.0  0.03   15.0    1.0    NaN   NaN
# 1                     1    77.0    77.0  0.0  0.03   10.0    1.0    NaN   NaN
# 2                     2    85.0    85.0  0.0  0.04   20.0    1.0    NaN   NaN
# 3                     3    61.0    61.0  0.0  0.01    1.0    1.0    NaN   NaN
# 4                     4    80.0    80.0  0.0  0.04   26.0    1.0    NaN   NaN
# ..                  ...     ...     ...  ...   ...    ...    ...    ...   ...
# 196                 196     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 197                 197     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 198                 198     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 199                 199     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 200  mip_minmiset_200_2  3188.0  3188.0  0.0  1.48  804.0  200.0  104.0  0.05
#
# [201 rows x 9 columns]

# %%
form_="minmiset"
dim_=200
id_=3

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_minmiset_200_3 = table
mip_internet_minmiset_200_3

#print(mip_internet_minmiset_200_3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                 vertice      bb      bs  gap  time  nodes    opt     tk  tmax
# 0                     0    77.0    77.0  0.0  0.04   16.0    1.0    NaN   NaN
# 1                     1   103.0   103.0  0.0  0.01    1.0    1.0    NaN   NaN
# 2                     2    72.0    72.0  0.0  0.03   14.0    1.0    NaN   NaN
# 3                     3    76.0    76.0  0.0  0.04   43.0    1.0    NaN   NaN
# 4                     4    87.0    87.0  0.0  0.03   14.0    1.0    NaN   NaN
# ..                  ...     ...     ...  ...   ...    ...    ...    ...   ...
# 196                 196     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 197                 197     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 198                 198     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 199                 199     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 200  mip_minmiset_200_3  2928.0  2928.0  0.0  1.06  646.0  200.0  103.0  0.05
#
# [201 rows x 9 columns]

# %%
form_="minmiset0"
dim_=200
id_=1

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_minmiset0_200_1 = table
mip_internet_minmiset0_200_1

#print(mip_internet_minmiset0_200_2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                  vertice      bb      bs  gap     time  nodes    opt     tk  \
# 0                      0   143.0   143.0  0.0    18.08   11.0    1.0    NaN
# 1                      1   124.0   124.0  0.0    10.09    1.0    1.0    NaN
# 2                      2   127.0   127.0  0.0     3.69    1.0    1.0    NaN
# 3                      3   124.0   124.0  0.0    30.66   11.0    1.0    NaN
# 4                      4   124.0   124.0  0.0    31.45   15.0    1.0    NaN
# ..                   ...     ...     ...  ...      ...    ...    ...    ...
# 196                  196     1.0     1.0  0.0     0.00    0.0    1.0    NaN
# 197                  197     1.0     1.0  0.0     0.00    0.0    1.0    NaN
# 198                  198     1.0     1.0  0.0     0.00    0.0    1.0    NaN
# 199                  199     1.0     1.0  0.0     0.00    0.0    1.0    NaN
# 200  mip_minmiset0_200_1  5092.0  5092.0  0.0  1214.87  628.0  200.0  149.0
#
#      tmax
# 0     NaN
# 1     NaN
# 2     NaN
# ...

# %%
form_="minmiset0"
dim_=200
id_=2

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_minmiset0_200_2 = table
mip_internet_minmiset0_200_2

#print(mip_internet_minmiset0_200_2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                  vertice      bb      bs  gap     time   nodes    opt     tk  \
# 0                      0   138.0   138.0  0.0    29.89    17.0    1.0    NaN
# 1                      1   138.0   138.0  0.0    34.61    25.0    1.0    NaN
# 2                      2   138.0   138.0  0.0    35.14    17.0    1.0    NaN
# 3                      3   138.0   138.0  0.0    21.24    11.0    1.0    NaN
# 4                      4   138.0   138.0  0.0    22.59    17.0    1.0    NaN
# ..                   ...     ...     ...  ...      ...     ...    ...    ...
# 196                  196     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 197                  197     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 198                  198     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 199                  199     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 200  mip_minmiset0_200_2  5997.0  5997.0  0.0  1398.19  1164.0  200.0  153.0
#
#      tmax
# 0     NaN
# 1     NaN
# ...

# %%
form_="minmiset0"
dim_=200
id_=3

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_minmiset0_200_3 = table
mip_internet_minmiset0_200_3

#print(mip_internet_minmiset0_200_3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                  vertice      bb      bs  gap     time  nodes    opt     tk  \
# 0                      0   137.0   137.0  0.0    31.12   17.0    1.0    NaN
# 1                      1   139.0   139.0  0.0    16.96    9.0    1.0    NaN
# 2                      2   137.0   137.0  0.0    35.16   26.0    1.0    NaN
# 3                      3   139.0   139.0  0.0    22.54   29.0    1.0    NaN
# 4                      4   139.0   139.0  0.0    29.96   21.0    1.0    NaN
# ..                   ...     ...     ...  ...      ...    ...    ...    ...
# 196                  196     1.0     1.0  0.0     0.00    0.0    1.0    NaN
# 197                  197     1.0     1.0  0.0     0.00    0.0    1.0    NaN
# 198                  198     1.0     1.0  0.0     0.00    0.0    1.0    NaN
# 199                  199     1.0     1.0  0.0     0.00    0.0    1.0    NaN
# 200  mip_minmiset0_200_3  5523.0  5523.0  0.0  1188.02  824.0  200.0  139.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# ...

# %%
result_200_1 = pd.DataFrame()

result_200_1 = pd.merge(
    mip_internet_fmin_200_1, mip_internet_fmax_200_1,
    on=['vertice'], 
    suffixes=("", "_fmax"),
    )

result_200_1 = pd.merge(
    result_200_1, mip_internet_minmiset0_200_1,
    on=['vertice'], 
    suffixes=("", "_minmiset0"),
    )

result_200_1 = pd.merge(
    result_200_1, mip_internet_maxmiset0_200_1,
    on=['vertice'], 
    suffixes=("", "_maxmiset0"),
    )

result_200_1[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_fmax','gap_fmax','time_fmax','opt_fmax','tk_fmax','tmax_fmax',
    'bs_minmiset0','gap_minmiset0','time_minmiset0','opt_minmiset0','tk_minmiset0','tmax_minmiset0',
    'bs_maxmiset0','gap_maxmiset0','time_maxmiset0','opt_maxmiset0','tk_maxmiset0','tmax_maxmiset0'
    ]]
# Out:
#     vertice     bs  gap   time  opt  tk  tmax  bs_fmax  gap_fmax  time_fmax  \
# 0         0  143.0  0.0  10.24  1.0 NaN   NaN    143.0       0.0      14.85
# 1         1  124.0  0.0   9.52  1.0 NaN   NaN    124.0       0.0       8.25
# 2         2  127.0  0.0   3.67  1.0 NaN   NaN    127.0       0.0       4.44
# 3         3  124.0  0.0  23.80  1.0 NaN   NaN    124.0       0.0      21.57
# 4         4  124.0  0.0  14.24  1.0 NaN   NaN    124.0       0.0      19.54
# ..      ...    ...  ...    ...  ...  ..   ...      ...       ...        ...
# 195     195    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 196     196    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 197     197    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 198     198    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 199     199    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
#
# ...

# %%
result = pd.DataFrame()

result_200_2 = pd.merge(
    mip_internet_fmin_200_2, mip_internet_fmax_200_2,
    on=['vertice'], 
    suffixes=("", "_fmax"),
    )

result_200_2 = pd.merge(
    result_200_2, mip_internet_minmiset0_200_2,
    on=['vertice'], 
    suffixes=("", "_minmiset0"),
    )

result_200_2 = pd.merge(
    result_200_2, mip_internet_maxmiset0_200_2,
    on=['vertice'], 
    suffixes=("", "_maxmiset0"),
    )

result_200_2[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_fmax','gap_fmax','time_fmax','opt_fmax','tk_fmax','tmax_fmax',
    'bs_minmiset0','gap_minmiset0','time_minmiset0','opt_minmiset0','tk_minmiset0','tmax_minmiset0',
    'bs_maxmiset0','gap_maxmiset0','time_maxmiset0','opt_maxmiset0','tk_maxmiset0','tmax_maxmiset0'
    ]]
# Out:
#     vertice     bs  gap   time  opt  tk  tmax  bs_fmax  gap_fmax  time_fmax  \
# 0         0  138.0  0.0  20.68  1.0 NaN   NaN    138.0       0.0      24.77
# 1         1  138.0  0.0  21.17  1.0 NaN   NaN    138.0       0.0      19.85
# 2         2  138.0  0.0  18.79  1.0 NaN   NaN    138.0       0.0      18.39
# 3         3  138.0  0.0  18.59  1.0 NaN   NaN    138.0       0.0      16.19
# 4         4  138.0  0.0  24.55  1.0 NaN   NaN    138.0       0.0      20.37
# ..      ...    ...  ...    ...  ...  ..   ...      ...       ...        ...
# 195     195    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 196     196    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 197     197    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 198     198    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 199     199    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
#
# ...

# %%
result_200_3 = pd.DataFrame()

result_200_3 = pd.merge(
    mip_internet_fmin_200_3, mip_internet_fmax_200_3,
    on=['vertice'], 
    suffixes=("", "_fmax"),
    )

result_200_3 = pd.merge(
    result_200_3, mip_internet_minmiset0_200_3,
    on=['vertice'], 
    suffixes=("", "_minmiset0"),
    )

result_200_3 = pd.merge(
    result_200_3, mip_internet_maxmiset0_200_3,
    on=['vertice'], 
    suffixes=("", "_maxmiset0"),
    )

result_200_3[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_fmax','gap_fmax','time_fmax','opt_fmax','tk_fmax','tmax_fmax',
    'bs_minmiset0','gap_minmiset0','time_minmiset0','opt_minmiset0','tk_minmiset0','tmax_minmiset0',
    'bs_maxmiset0','gap_maxmiset0','time_maxmiset0','opt_maxmiset0','tk_maxmiset0','tmax_maxmiset0'
    ]]
# Out:
#     vertice     bs  gap   time  opt  tk  tmax  bs_fmax  gap_fmax  time_fmax  \
# 0         0  137.0  0.0  16.72  1.0 NaN   NaN    137.0       0.0      16.15
# 1         1  139.0  0.0  14.30  1.0 NaN   NaN    139.0       0.0      17.06
# 2         2  137.0  0.0  21.29  1.0 NaN   NaN    137.0       0.0      25.00
# 3         3  139.0  0.0  16.96  1.0 NaN   NaN    139.0       0.0      13.17
# 4         4  139.0  0.0  19.07  1.0 NaN   NaN    139.0       0.0      18.59
# ..      ...    ...  ...    ...  ...  ..   ...      ...       ...        ...
# 195     195    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 196     196    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 197     197    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 198     198    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 199     199    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
#
# ...

# %%
print(
result_200_1[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_fmax','gap_fmax','time_fmax','opt_fmax','tk_fmax','tmax_fmax',
    'bs_minmiset0','gap_minmiset0','time_minmiset0','opt_minmiset0','tk_minmiset0','tmax_minmiset0',
    'bs_maxmiset0','gap_maxmiset0','time_maxmiset0','opt_maxmiset0','tk_maxmiset0','tmax_maxmiset0'
    ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrrr}
# \toprule
# vertice &    bs &  gap &  time &  opt &  tk &  tmax &  bs\_fmax &  gap\_fmax &  time\_fmax &  opt\_fmax &  tk\_fmax &  tmax\_fmax &  bs\_minmiset0 &  gap\_minmiset0 &  time\_minmiset0 &  opt\_minmiset0 &  tk\_minmiset0 &  tmax\_minmiset0 &  bs\_maxmiset0 &  gap\_maxmiset0 &  time\_maxmiset0 &  opt\_maxmiset0 &  tk\_maxmiset0 &  tmax\_maxmiset0 \\
# \midrule
#       0 & 143.0 &  0.0 &  10.2 &  1.0 & NaN &   NaN &    143.0 &       0.0 &       14.8 &       1.0 &      NaN &        NaN &         143.0 &            0.0 &            18.1 &            1.0 &           NaN &             NaN &         143.0 &            0.0 &            19.0 &            1.0 &           NaN &             NaN \\
# ...

# %%
print(
result_200_2[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_fmax','gap_fmax','time_fmax','opt_fmax','tk_fmax','tmax_fmax',
    'bs_minmiset0','gap_minmiset0','time_minmiset0','opt_minmiset0','tk_minmiset0','tmax_minmiset0',
    'bs_maxmiset0','gap_maxmiset0','time_maxmiset0','opt_maxmiset0','tk_maxmiset0','tmax_maxmiset0'
    ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrrr}
# \toprule
# vertice &    bs &  gap &  time &  opt &  tk &  tmax &  bs\_fmax &  gap\_fmax &  time\_fmax &  opt\_fmax &  tk\_fmax &  tmax\_fmax &  bs\_minmiset0 &  gap\_minmiset0 &  time\_minmiset0 &  opt\_minmiset0 &  tk\_minmiset0 &  tmax\_minmiset0 &  bs\_maxmiset0 &  gap\_maxmiset0 &  time\_maxmiset0 &  opt\_maxmiset0 &  tk\_maxmiset0 &  tmax\_maxmiset0 \\
# \midrule
#       0 & 138.0 &  0.0 &  20.7 &  1.0 & NaN &   NaN &    138.0 &       0.0 &       24.8 &       1.0 &      NaN &        NaN &         138.0 &            0.0 &            29.9 &            1.0 &           NaN &             NaN &         138.0 &            0.0 &            44.1 &            1.0 &           NaN &             NaN \\
# ...

# %%
print(
result_200_3[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_fmax','gap_fmax','time_fmax','opt_fmax','tk_fmax','tmax_fmax',
    'bs_minmiset0','gap_minmiset0','time_minmiset0','opt_minmiset0','tk_minmiset0','tmax_minmiset0',
    'bs_maxmiset0','gap_maxmiset0','time_maxmiset0','opt_maxmiset0','tk_maxmiset0','tmax_maxmiset0'
    ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrrr}
# \toprule
# vertice &    bs &  gap &  time &  opt &  tk &  tmax &  bs\_fmax &  gap\_fmax &  time\_fmax &  opt\_fmax &  tk\_fmax &  tmax\_fmax &  bs\_minmiset0 &  gap\_minmiset0 &  time\_minmiset0 &  opt\_minmiset0 &  tk\_minmiset0 &  tmax\_minmiset0 &  bs\_maxmiset0 &  gap\_maxmiset0 &  time\_maxmiset0 &  opt\_maxmiset0 &  tk\_maxmiset0 &  tmax\_maxmiset0 \\
# \midrule
#       0 & 137.0 &  0.0 &  16.7 &  1.0 & NaN &   NaN &    137.0 &       0.0 &       16.1 &       1.0 &      NaN &        NaN &         137.0 &            0.0 &            31.1 &            1.0 &           NaN &             NaN &         137.0 &            0.0 &            46.9 &            1.0 &           NaN &             NaN \\
# ...

# %%
resume_200_1 = pd.DataFrame()
resume_200_1 = pd.concat([resume_200_1, mip_internet_fmin_200_1.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_fmax_200_1.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_minmiset_200_1.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_minmiset0_200_1.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_maxmiset0_200_1.loc[200:200]], ignore_index=True)
resume_200_1
# Out:
#                vertice      bb      bs  gap     time   nodes    opt     tk  \
# 0       mip_fmin_200_1  5092.0  5092.0  0.0   772.72  2350.0  200.0  149.0
# 1       mip_fmax_200_1  5092.0  5092.0  0.0   788.88  2260.0  200.0  149.0
# 2   mip_minmiset_200_1  3425.0  3425.0  0.0     1.32   746.0  200.0  102.0
# 3  mip_minmiset0_200_1  5092.0  5092.0  0.0  1214.87   628.0  200.0  149.0
# 4  mip_maxmiset0_200_1  5092.0  5092.0  0.0  2155.89   545.0  200.0  149.0
#
#      tmax
# 0   33.82
# 1   40.96
# 2    0.05
# 3   67.40
# 4  112.22

# %%
resume_200_2 = pd.DataFrame()
resume_200_2 = pd.concat([resume_200_2, mip_internet_fmin_200_2.loc[200:200]], ignore_index=True)
resume_200_2 = pd.concat([resume_200_2, mip_internet_fmax_200_2.loc[200:200]], ignore_index=True)
resume_200_2 = pd.concat([resume_200_2, mip_internet_minmiset_200_2.loc[200:200]], ignore_index=True)
resume_200_2 = pd.concat([resume_200_2, mip_internet_minmiset0_200_2.loc[200:200]], ignore_index=True)
resume_200_2 = pd.concat([resume_200_2, mip_internet_maxmiset0_200_2.loc[200:200]], ignore_index=True)
resume_200_2
# Out:
#                vertice      bb      bs  gap     time   nodes    opt     tk  \
# 0       mip_fmin_200_2  5997.0  5997.0  0.0   974.63  5777.0  200.0  153.0
# 1       mip_fmax_200_2  5997.0  5997.0  0.0   970.49  5534.0  200.0  153.0
# 2   mip_minmiset_200_2  3188.0  3188.0  0.0     1.48   804.0  200.0  104.0
# 3  mip_minmiset0_200_2  5997.0  5997.0  0.0  1398.19  1164.0  200.0  153.0
# 4  mip_maxmiset0_200_2  5997.0  5997.0  0.0  2562.99  1366.0  200.0  153.0
#
#      tmax
# 0   34.79
# 1   41.63
# 2    0.05
# 3   55.30
# 4  124.37

# %%
resume_200_3 = pd.DataFrame()
resume_200_3 = pd.concat([resume_200_3, mip_internet_fmin_200_3.loc[200:200]], ignore_index=True)
resume_200_3 = pd.concat([resume_200_3, mip_internet_fmax_200_3.loc[200:200]], ignore_index=True)
resume_200_3 = pd.concat([resume_200_3, mip_internet_minmiset_200_3.loc[200:200]], ignore_index=True)
resume_200_3 = pd.concat([resume_200_3, mip_internet_minmiset0_200_3.loc[200:200]], ignore_index=True)
resume_200_3 = pd.concat([resume_200_3, mip_internet_maxmiset0_200_3.loc[200:200]], ignore_index=True)
resume_200_3
# Out:
#                vertice      bb      bs  gap     time   nodes    opt     tk  \
# 0       mip_fmin_200_3  5523.0  5523.0  0.0   873.37  4589.0  200.0  139.0
# 1       mip_fmax_200_3  5523.0  5523.0  0.0   843.78  4389.0  200.0  139.0
# 2   mip_minmiset_200_3  2928.0  2928.0  0.0     1.06   646.0  200.0  103.0
# 3  mip_minmiset0_200_3  5523.0  5523.0  0.0  1188.02   824.0  200.0  139.0
# 4  mip_maxmiset0_200_3  5523.0  5523.0  0.0  2182.86  1020.0  200.0  139.0
#
#     tmax
# 0  35.00
# 1  34.26
# 2   0.05
# 3  46.77
# 4  97.67

# %%
print(
resume_200_1[[
    'vertice','bs','gap','time','opt','tk','tmax',
    ]].to_latex(index=False,float_format="%.1f")
)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
#             vertice &     bs &  gap &   time &   opt &    tk &  tmax \\
# \midrule
#      mip\_fmin\_200\_1 & 5092.0 &  0.0 &  772.7 & 200.0 & 149.0 &  33.8 \\
#      mip\_fmax\_200\_1 & 5092.0 &  0.0 &  788.9 & 200.0 & 149.0 &  41.0 \\
#  mip\_minmiset\_200\_1 & 3425.0 &  0.0 &    1.3 & 200.0 & 102.0 &   0.1 \\
# mip\_minmiset0\_200\_1 & 5092.0 &  0.0 & 1214.9 & 200.0 & 149.0 &  67.4 \\
# mip\_maxmiset0\_200\_1 & 5092.0 &  0.0 & 2155.9 & 200.0 & 149.0 & 112.2 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_112192/329633122.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   resume_200_1[[

# %%
print(
resume_200_2[[
    'vertice','bs','gap','time','opt','tk','tmax',
    ]].to_latex(index=False,float_format="%.1f")
)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
#             vertice &     bs &  gap &   time &   opt &    tk &  tmax \\
# \midrule
#      mip\_fmin\_200\_2 & 5997.0 &  0.0 &  974.6 & 200.0 & 153.0 &  34.8 \\
#      mip\_fmax\_200\_2 & 5997.0 &  0.0 &  970.5 & 200.0 & 153.0 &  41.6 \\
#  mip\_minmiset\_200\_2 & 3188.0 &  0.0 &    1.5 & 200.0 & 104.0 &   0.1 \\
# mip\_minmiset0\_200\_2 & 5997.0 &  0.0 & 1398.2 & 200.0 & 153.0 &  55.3 \\
# mip\_maxmiset0\_200\_2 & 5997.0 &  0.0 & 2563.0 & 200.0 & 153.0 & 124.4 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_112192/3842470942.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   resume_200_2[[

# %%
print(
resume_200_3[[
    'vertice','bs','gap','time','opt','tk','tmax',
    ]].to_latex(index=False,float_format="%.1f")
)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
#             vertice &     bs &  gap &   time &   opt &    tk &  tmax \\
# \midrule
#      mip\_fmin\_200\_3 & 5523.0 &  0.0 &  873.4 & 200.0 & 139.0 &  35.0 \\
#      mip\_fmax\_200\_3 & 5523.0 &  0.0 &  843.8 & 200.0 & 139.0 &  34.3 \\
#  mip\_minmiset\_200\_3 & 2928.0 &  0.0 &    1.1 & 200.0 & 103.0 &   0.1 \\
# mip\_minmiset0\_200\_3 & 5523.0 &  0.0 & 1188.0 & 200.0 & 139.0 &  46.8 \\
# mip\_maxmiset0\_200\_3 & 5523.0 &  0.0 & 2182.9 & 200.0 & 139.0 &  97.7 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_112192/3291987253.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   resume_200_3[[
