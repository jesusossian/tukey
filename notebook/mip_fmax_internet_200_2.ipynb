# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="internet_graph"
method_="mip"
dim_=200
id_=2
ver_="fmax"

# %%
form_="fmaxc0"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c0 = table
mip_internet_c0

#print(mip_internet_c0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#               vertice      bb      bs  gap     time   nodes    opt     tk  \
# 0                   0   138.0   138.0  0.0    40.12    59.0    1.0    NaN
# 1                   1   138.0   138.0  0.0    56.18    73.0    1.0    NaN
# 2                   2   138.0   138.0  0.0    34.04    91.0    1.0    NaN
# 3                   3   138.0   138.0  0.0    33.12    48.0    1.0    NaN
# 4                   4   138.0   138.0  0.0    28.57    80.0    1.0    NaN
# ..                ...     ...     ...  ...      ...     ...    ...    ...
# 196               196     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 197               197     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 198               198     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 199               199     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 200  mip_fmaxc0_200_2  5997.0  5997.0  0.0  2065.08  3534.0  200.0  153.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  94.48
#
# [201 rows x 9 columns]

# %%
form_="fmaxc0noclq"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c0noclq = table
mip_internet_c0noclq

#print(mip_internet_c0noclq[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap     time   nodes    opt  \
# 0                        0   138.0   138.0  0.0    37.11    59.0    1.0
# 1                        1   138.0   138.0  0.0    54.30    73.0    1.0
# 2                        2   138.0   138.0  0.0    32.46    91.0    1.0
# 3                        3   138.0   138.0  0.0    31.50    48.0    1.0
# 4                        4   138.0   138.0  0.0    26.59    80.0    1.0
# ..                     ...     ...     ...  ...      ...     ...    ...
# 196                    196     1.0     1.0  0.0     0.64     1.0    1.0
# 197                    197     1.0     1.0  0.0     0.64     1.0    1.0
# 198                    198     1.0     1.0  0.0     0.65     1.0    1.0
# 199                    199     1.0     1.0  0.0     0.64     1.0    1.0
# 200  mip_fmaxc0noclq_200_2  5997.0  5997.0  0.0  2031.08  3692.0  200.0
#
#         tk  tmax
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# 3      NaN   NaN
# 4      NaN   NaN
# ..     ...   ...
# 196    NaN   NaN
# 197    NaN   NaN
# 198    NaN   NaN
# 199    NaN   NaN
# 200  153.0  84.3
#
# [201 rows x 9 columns]

# %%
form_="fmaxc1"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c1 = table
mip_internet_c1

#print(mip_internet_c1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#               vertice      bb      bs  gap     time   nodes    opt     tk  \
# 0                   0   138.0   138.0  0.0    32.31    96.0    1.0    NaN
# 1                   1   138.0   138.0  0.0    28.94   137.0    1.0    NaN
# 2                   2   138.0   138.0  0.0    22.92   103.0    1.0    NaN
# 3                   3   138.0   138.0  0.0    27.26    66.0    1.0    NaN
# 4                   4   138.0   138.0  0.0    27.96    63.0    1.0    NaN
# ..                ...     ...     ...  ...      ...     ...    ...    ...
# 196               196     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 197               197     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 198               198     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 199               199     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 200  mip_fmaxc1_200_2  5997.0  5997.0  0.0  1736.12  3613.0  200.0  153.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  67.22
#
# [201 rows x 9 columns]

# %%
form_="fmaxc1noclq"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c1noclq = table
mip_internet_c1noclq

#print(mip_internet_c1noclq[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap     time   nodes    opt  \
# 0                        0   138.0   138.0  0.0    32.08    96.0    1.0
# 1                        1   138.0   138.0  0.0    28.58   137.0    1.0
# 2                        2   138.0   138.0  0.0    22.83   103.0    1.0
# 3                        3   138.0   138.0  0.0    27.08    66.0    1.0
# 4                        4   138.0   138.0  0.0    27.89    63.0    1.0
# ..                     ...     ...     ...  ...      ...     ...    ...
# 196                    196     1.0     1.0  0.0     0.26     1.0    1.0
# 197                    197     1.0     1.0  0.0     0.26     1.0    1.0
# 198                    198     1.0     1.0  0.0     0.26     1.0    1.0
# 199                    199     1.0     1.0  0.0     0.26     1.0    1.0
# 200  mip_fmaxc1noclq_200_2  5997.0  5997.0  0.0  1772.66  3771.0  200.0
#
#         tk   tmax
# 0      NaN    NaN
# 1      NaN    NaN
# 2      NaN    NaN
# 3      NaN    NaN
# 4      NaN    NaN
# ..     ...    ...
# 196    NaN    NaN
# 197    NaN    NaN
# 198    NaN    NaN
# 199    NaN    NaN
# 200  153.0  66.15
#
# [201 rows x 9 columns]

# %%
form_="fmaxc2"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_c2 = table
mip_internet_c2

#print(mip_internet_c2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#               vertice      bb      bs  gap    time   nodes    opt     tk  tmax
# 0                   0   138.0   138.0  0.0   17.76    80.0    1.0    NaN   NaN
# 1                   1   138.0   138.0  0.0   14.16   143.0    1.0    NaN   NaN
# 2                   2   138.0   138.0  0.0   13.17   115.0    1.0    NaN   NaN
# 3                   3   138.0   138.0  0.0   11.65    42.0    1.0    NaN   NaN
# 4                   4   138.0   138.0  0.0   14.54   123.0    1.0    NaN   NaN
# ..                ...     ...     ...  ...     ...     ...    ...    ...   ...
# 196               196     1.0     1.0  0.0    0.00     0.0    1.0    NaN   NaN
# 197               197     1.0     1.0  0.0    0.00     0.0    1.0    NaN   NaN
# 198               198     1.0     1.0  0.0    0.00     0.0    1.0    NaN   NaN
# 199               199     1.0     1.0  0.0    0.00     0.0    1.0    NaN   NaN
# 200  mip_fmaxc2_200_2  5997.0  5997.0  0.0  697.67  5534.0  200.0  153.0  29.9
#
# [201 rows x 9 columns]

# %%
form_="fmaxmisetc2"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_misetc2 = table
mip_internet_misetc2

#print(mip_internet_misetc2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap    time  nodes    opt     tk  \
# 0                        0   138.0   138.0  0.0   15.25   17.0    1.0    NaN
# 1                        1   138.0   138.0  0.0   13.70   15.0    1.0    NaN
# 2                        2   138.0   138.0  0.0   17.23   15.0    1.0    NaN
# 3                        3   138.0   138.0  0.0   14.04    7.0    1.0    NaN
# 4                        4   138.0   138.0  0.0   11.16   21.0    1.0    NaN
# ..                     ...     ...     ...  ...     ...    ...    ...    ...
# 196                    196     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 197                    197     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 198                    198     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 199                    199     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 200  mip_fmaxmisetc2_200_2  5997.0  5997.0  0.0  695.79  962.0  200.0  153.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  27.81
#
# [201 rows x 9 columns]

# %%
form_="fmaxmisetc3"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_misetc3 = table
mip_internet_misetc3

#print(mip_internet_misetc3[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap    time   nodes    opt     tk  \
# 0                        0   138.0   138.0  0.0   11.09    19.0    1.0    NaN
# 1                        1   138.0   138.0  0.0   13.65    23.0    1.0    NaN
# 2                        2   138.0   138.0  0.0   12.39    17.0    1.0    NaN
# 3                        3   138.0   138.0  0.0    9.54     9.0    1.0    NaN
# 4                        4   138.0   138.0  0.0   11.51    19.0    1.0    NaN
# ..                     ...     ...     ...  ...     ...     ...    ...    ...
# 196                    196     1.0     1.0  0.0    0.00     0.0    1.0    NaN
# 197                    197     1.0     1.0  0.0    0.00     0.0    1.0    NaN
# 198                    198     1.0     1.0  0.0    0.00     0.0    1.0    NaN
# 199                    199     1.0     1.0  0.0    0.00     0.0    1.0    NaN
# 200  mip_fmaxmisetc3_200_2  5997.0  5997.0  0.0  588.96  1017.0  200.0  153.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  19.58
#
# [201 rows x 9 columns]

# %%
form_="fmaxmiset"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_miset = table
mip_internet_miset

#print(mip_internet_miset[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                  vertice      bb      bs  gap  time   nodes    opt     tk  \
# 0                      0   127.0   127.0  0.0  0.10    29.0    1.0    NaN
# 1                      1   127.0   127.0  0.0  0.10    18.0    1.0    NaN
# 2                      2   127.0   127.0  0.0  0.11    14.0    1.0    NaN
# 3                      3   127.0   127.0  0.0  0.11    18.0    1.0    NaN
# 4                      4   127.0   127.0  0.0  0.12    29.0    1.0    NaN
# ..                   ...     ...     ...  ...   ...     ...    ...    ...
# 196                  196     1.0     1.0  0.0  0.00     0.0    1.0    NaN
# 197                  197     1.0     1.0  0.0  0.00     0.0    1.0    NaN
# 198                  198     1.0     1.0  0.0  0.00     0.0    1.0    NaN
# 199                  199     1.0     1.0  0.0  0.00     0.0    1.0    NaN
# 200  mip_fmaxmiset_200_2  5534.0  5534.0  0.0  4.77  1280.0  200.0  143.0
#
#      tmax
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 196   NaN
# 197   NaN
# 198   NaN
# 199   NaN
# 200  0.16
#
# [201 rows x 9 columns]

# %%
mip_merge = pd.DataFrame()

mip_merge = pd.merge(
    mip_internet_c0, mip_internet_c0noclq,
    on=['vertice'], 
    suffixes=("", "_b"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_c1,
    on=['vertice'], 
    suffixes=("", "_c"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_c1noclq,
    on=['vertice'], 
    suffixes=("", "_d"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_c2,
    on=['vertice'], 
    suffixes=("", "_e"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_misetc2,
    on=['vertice'], 
    suffixes=("", "_f"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_misetc3,
    on=['vertice'], 
    suffixes=("", "_g"),
    )

mip_merge = pd.merge(
    mip_merge, mip_internet_miset,
    on=['vertice'], 
    suffixes=("", "_h"),
    )


mip_merge[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',
    ]]
# Out:
#     vertice     bs  gap   time  opt  tk  tmax   bs_b  gap_b  time_b  ...  \
# 0         0  138.0  0.0  40.12  1.0 NaN   NaN  138.0    0.0   37.11  ...
# 1         1  138.0  0.0  56.18  1.0 NaN   NaN  138.0    0.0   54.30  ...
# 2         2  138.0  0.0  34.04  1.0 NaN   NaN  138.0    0.0   32.46  ...
# 3         3  138.0  0.0  33.12  1.0 NaN   NaN  138.0    0.0   31.50  ...
# 4         4  138.0  0.0  28.57  1.0 NaN   NaN  138.0    0.0   26.59  ...
# ..      ...    ...  ...    ...  ...  ..   ...    ...    ...     ...  ...
# 195     195    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.64  ...
# 196     196    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.64  ...
# 197     197    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.64  ...
# 198     198    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.65  ...
# 199     199    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.64  ...
#
#      time_d  opt_d  tk_d  tmax_d   bs_e  gap_e  time_e  opt_e  tk_e  tmax_e
# 0     32.08    1.0   NaN     NaN  138.0    0.0   17.76    1.0   NaN     NaN
# 1     28.58    1.0   NaN     NaN  138.0    0.0   14.16    1.0   NaN     NaN
# 2     22.83    1.0   NaN     NaN  138.0    0.0   13.17    1.0   NaN     NaN
# 3     27.08    1.0   NaN     NaN  138.0    0.0   11.65    1.0   NaN     NaN
# 4     27.89    1.0   NaN     NaN  138.0    0.0   14.54    1.0   NaN     NaN
# ..      ...    ...   ...     ...    ...    ...     ...    ...   ...     ...
# 195    0.26    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 196    0.26    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 197    0.26    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 198    0.26    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 199    0.26    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
#
# [200 rows x 31 columns]

# %%
print(
mip_merge[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',
    'bs_f','gap_f','time_f','opt_f','tk_f','tmax_f',
    'bs_g','gap_g','time_g','opt_g','tk_g','tmax_g',
    'bs_h','gap_h','time_h','opt_h','tk_h','tmax_h',
    ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr}
# \toprule
# vertice &    bs &  gap &  time &  opt &  tk &  tmax &  bs\_b &  gap\_b &  time\_b &  opt\_b &  tk\_b &  tmax\_b &  bs\_c &  gap\_c &  time\_c &  opt\_c &  tk\_c &  tmax\_c &  bs\_d &  gap\_d &  time\_d &  opt\_d &  tk\_d &  tmax\_d &  bs\_e &  gap\_e &  time\_e &  opt\_e &  tk\_e &  tmax\_e &  bs\_f &  gap\_f &  time\_f &  opt\_f &  tk\_f &  tmax\_f &  bs\_g &  gap\_g &  time\_g &  opt\_g &  tk\_g &  tmax\_g &  bs\_h &  gap\_h &  time\_h &  opt\_h &  tk\_h &  tmax\_h \\
# \midrule
#       0 & 138.0 &  0.0 &  40.1 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    37.1 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    32.3 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    32.1 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    17.8 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    15.2 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    11.1 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#       1 & 138.0 &  0.0 &  56.2 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    54.3 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    28.9 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    28.6 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    14.2 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    13.7 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    13.7 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#       2 & 138.0 &  0.0 &  34.0 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    32.5 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    22.9 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    22.8 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    13.2 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    17.2 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    12.4 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#       3 & 138.0 &  0.0 &  33.1 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    31.5 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    27.3 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    27.1 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    11.7 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    14.0 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &     9.5 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#       4 & 138.0 &  0.0 &  28.6 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    26.6 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    28.0 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    27.9 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    14.5 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    11.2 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    11.5 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#       5 & 138.0 &  0.0 &  25.1 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    22.4 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    17.2 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    17.4 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    15.3 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    16.2 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    12.5 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#       6 & 138.0 &  0.0 &  19.2 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    20.5 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    18.3 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    18.5 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    11.7 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    11.5 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &     7.3 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#       7 & 138.0 &  0.0 &  43.4 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    44.5 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    34.8 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    35.3 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    11.8 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    12.1 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &     9.0 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#       8 & 143.0 &  0.0 &  45.2 &  1.0 & NaN &   NaN & 143.0 &    0.0 &    38.1 &    1.0 &   NaN &     NaN & 143.0 &    0.0 &    27.0 &    1.0 &   NaN &     NaN & 143.0 &    0.0 &    27.3 &    1.0 &   NaN &     NaN & 143.0 &    0.0 &    12.1 &    1.0 &   NaN &     NaN & 143.0 &    0.0 &    10.9 &    1.0 &   NaN &     NaN & 143.0 &    0.0 &    11.4 &    1.0 &   NaN &     NaN & 136.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#       9 & 138.0 &  0.0 &  36.5 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    32.9 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    32.8 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    33.2 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    12.3 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    10.6 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    12.3 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#      10 & 138.0 &  0.0 &  26.7 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    23.6 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    20.7 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    20.9 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    11.2 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    11.9 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &     9.9 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#      11 & 138.0 &  0.0 &  49.0 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    47.6 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    40.3 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    40.5 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    17.9 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    13.1 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    13.3 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#      12 & 138.0 &  0.0 &  55.4 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    55.8 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    35.5 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    36.0 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    15.9 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    19.7 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    11.6 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#      13 & 138.0 &  0.0 &  41.2 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    41.8 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    38.2 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    38.8 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    19.5 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    16.8 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    12.6 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#      14 & 138.0 &  0.0 &  56.1 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    47.8 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    43.7 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    44.1 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    17.7 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    15.4 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    17.1 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#      15 & 138.0 &  0.0 &  45.1 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    38.9 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    50.8 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    51.6 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    16.1 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    18.4 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    17.5 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#      16 & 138.0 &  0.0 &  34.5 &  1.0 & NaN &   NaN & 138.0 &    0.0 &    31.3 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    30.9 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    31.1 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    10.5 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    19.4 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    12.3 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#
&    1.0 &   NaN &     NaN & 138.0 &    0.0 &    57.7 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    57.6 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    20.6 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    23.7 &    1.0 &   NaN &     NaN & 138.0 &    0.0 &    19.6 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#      44 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      45 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      46 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      47 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      48 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      49 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      50 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      51 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      52 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      53 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      54 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      55 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      56 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      57 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      58 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      59 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      60 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      61 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      62 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      63 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      64 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      65 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      66 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      67 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      68 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      69 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      70 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      71 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      72 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      73 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      74 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      75 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      76 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      77 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      78 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      79 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      80 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      81 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      82 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      83 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      84 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      85 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      86 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      87 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      88 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      89 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      90 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      91 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      92 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      93 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      94 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      95 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      96 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      97 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      98 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      99 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     100 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     101 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     102 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     103 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     104 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     105 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     106 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     107 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     108 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
# ...
#     164 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     165 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     166 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     167 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     168 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     169 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     170 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     171 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     172 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     173 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     174 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     175 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     176 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     177 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     178 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     179 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     180 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     181 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     182 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     183 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     184 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     185 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     186 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     187 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     188 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     189 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     190 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     191 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     192 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     193 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     194 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     195 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     196 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     197 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     198 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.7 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     199 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.6 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.3 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_22907/4240678320.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   mip_merge[[

# %%
mip_concat = pd.DataFrame()
mip_concat = pd.concat([mip_concat, mip_internet_c0.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c0noclq.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c1.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c1noclq.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_c2.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_misetc2.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_misetc3.loc[200:200]], ignore_index=True)
mip_concat = pd.concat([mip_concat, mip_internet_miset.loc[200:200]], ignore_index=True)
mip_concat
# Out:
#                  vertice      bb      bs  gap     time   nodes    opt     tk  \
# 0       mip_fmaxc0_200_2  5997.0  5997.0  0.0  2065.08  3534.0  200.0  153.0
# 1  mip_fmaxc0noclq_200_2  5997.0  5997.0  0.0  2031.08  3692.0  200.0  153.0
# 2       mip_fmaxc1_200_2  5997.0  5997.0  0.0  1736.12  3613.0  200.0  153.0
# 3  mip_fmaxc1noclq_200_2  5997.0  5997.0  0.0  1772.66  3771.0  200.0  153.0
# 4       mip_fmaxc2_200_2  5997.0  5997.0  0.0   697.67  5534.0  200.0  153.0
# 5  mip_fmaxmisetc2_200_2  5997.0  5997.0  0.0   695.79   962.0  200.0  153.0
# 6  mip_fmaxmisetc3_200_2  5997.0  5997.0  0.0   588.96  1017.0  200.0  153.0
# 7    mip_fmaxmiset_200_2  5534.0  5534.0  0.0     4.77  1280.0  200.0  143.0
#
#     tmax
# 0  94.48
# 1  84.30
# 2  67.22
# 3  66.15
# 4  29.90
# 5  27.81
# 6  19.58
# 7   0.16

# %%
print(
mip_concat[[
    'vertice','bs','gap','time','opt','tk','tmax',
    ]].to_latex(index=False,float_format="%.1f")
)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
#               vertice &     bs &  gap &   time &   opt &    tk &  tmax \\
# \midrule
#      mip\_fmaxc0\_200\_2 & 5997.0 &  0.0 & 2065.1 & 200.0 & 153.0 &  94.5 \\
# mip\_fmaxc0noclq\_200\_2 & 5997.0 &  0.0 & 2031.1 & 200.0 & 153.0 &  84.3 \\
#      mip\_fmaxc1\_200\_2 & 5997.0 &  0.0 & 1736.1 & 200.0 & 153.0 &  67.2 \\
# mip\_fmaxc1noclq\_200\_2 & 5997.0 &  0.0 & 1772.7 & 200.0 & 153.0 &  66.2 \\
#      mip\_fmaxc2\_200\_2 & 5997.0 &  0.0 &  697.7 & 200.0 & 153.0 &  29.9 \\
# mip\_fmaxmisetc2\_200\_2 & 5997.0 &  0.0 &  695.8 & 200.0 & 153.0 &  27.8 \\
# mip\_fmaxmisetc3\_200\_2 & 5997.0 &  0.0 &  589.0 & 200.0 & 153.0 &  19.6 \\
#   mip\_fmaxmiset\_200\_2 & 5534.0 &  0.0 &    4.8 & 200.0 & 143.0 &   0.2 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_22907/1047115439.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   mip_concat[[
