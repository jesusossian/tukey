# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="karate"
method_="lp"

form_="form0"

file=f"/home/jossian/repository/tukey/result/{method_}/{method_}_tukey_{inst_}_{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','time','opt']

resume = pd.DataFrame({
    'vertice':f"{inst_}",
    'bb':table["bb"].sum(),
    'time':table['time'].sum(),
    'opt':table['opt'].sum()
    },index=["lp_karate_form0"]
)

table = pd.concat([table, resume], ignore_index=True)
lp_karate_form0 = table

#print(lp_karate_form0[['vertice','bb','time','opt']].to_latex(index=False,float_format="%.2f"))

# %%
inst_="karate"
method_="lp"

form_="form1"

file=f"/home/jossian/repository/tukey/result/{method_}/{method_}_tukey_{inst_}_{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','time','opt']

resume = pd.DataFrame({
    'vertice':f"{inst_}",
    'bb':table["bb"].sum(),
    'time':table['time'].sum(),
    'opt':table['opt'].sum()
    },index=["lp_karate_form0"]
)

table = pd.concat([table, resume], ignore_index=True)
lp_karate_form1 = table

#print(lp_karate_form1[['vertice','bb','time','opt']].to_latex(index=False,float_format="%.2f"))

# %%
inst_="karate"
method_="lp"

form_="form1_maxindset"

file=f"/home/jossian/repository/tukey/result/{method_}/{method_}_tukey_{inst_}_{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','time','opt']

resume = pd.DataFrame({
    'vertice':f"{inst_}",
    'bb':table["bb"].sum(),
    'time':table['time'].sum(),
    'opt':table['opt'].sum()
    },index=["lp_karate_form0"]
)

table = pd.concat([table, resume], ignore_index=True)
lp_karate_maxindset = table

#print(lp_karate_cutInd[['vertice','bb','time','opt']].to_latex(index=False,float_format="%.2f"))

# %%
inst_="karate"
method_="lp"

form_="max_neighbors"

file=f"/home/jossian/repository/tukey/result/{method_}/{method_}_tukey_{inst_}_{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','time','opt']

resume = pd.DataFrame({
    'vertice':f"{inst_}",
    'bb':table["bb"].sum(),
    'time':table['time'].sum(),
    'opt':table['opt'].sum()
    },index=["lp_karate_max_neighbors"]
)

table = pd.concat([table, resume], ignore_index=True)
lp_karate_max_neighbors = table

#print(lp_karate_cutInd[['vertice','bb','time','opt']].to_latex(index=False,float_format="%.2f"))

# %%
inst_="karate"
method_="mip"

form_="form0"

file=f"/home/jossian/repository/tukey/result/{method_}/{method_}_tukey_{inst_}_{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{inst_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum()
    },index=["mip_karate_form0"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_form0 = table

#print(mip_karate_form0[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
inst_="karate"
method_="mip"

form_="form1"

file=f"/home/jossian/repository/tukey/result/{method_}/{method_}_tukey_{inst_}_{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{inst_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum()
    },index=["mip_karate_form0"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_form1 = table

#print(mip_karate_form1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
inst_="karate"
method_="mip"

form_="form1_maxindset"

file=f"/home/jossian/repository/tukey/result/{method_}/{method_}_tukey_{inst_}_{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{inst_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum()
    },index=["mip_karate_form0"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_maxindset = table

#print(mip_karate_indForm1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
inst_="karate"
method_="mip"

form_="max_neighbors"

file=f"/home/jossian/repository/tukey/result/{method_}/{method_}_tukey_{inst_}_{form_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{inst_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum()
    },index=["mip_karate_max_neighbors"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_karate_max_neighbors = table

#print(mip_karate_indForm1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))

# %%
result = pd.DataFrame()
result = pd.merge(
    lp_karate_form0, lp_karate_form1,
    on=['vertice'], 
    suffixes=("", "_f1"),
    )

result = pd.merge(
    result, lp_karate_maxindset,
    on=['vertice'], 
    suffixes=("", "_miset"),
    )

result = pd.merge(
    result, lp_karate_max_neighbors,
    on=['vertice'], 
    suffixes=("", "_nei"),
    )

result

#print(result[['vertice','bb','bb_f1','bb_miset']].to_latex(index=False,float_format="%.1f"))

with open('../result/table_lp.tex', 'w') as tf:
     tf.write(
          result[[
               'vertice',
               'bb',
               'bb_f1',
               'bb_miset',
               'bb_nei'
               ]].to_latex(index=False,float_format="%.1f")
               )

# %%
result = pd.DataFrame()
result = pd.merge(
    mip_karate_form0, mip_karate_form1,
    on=['vertice'], 
    suffixes=("", "_f1"),
    )

result = pd.merge(
    result, mip_karate_maxindset,
    on=['vertice'], 
    suffixes=("", "_miset"),
    )

result = pd.merge(
    result, mip_karate_max_neighbors,
    on=['vertice'], 
    suffixes=("", "_nei"),
    )

result

#print(result[['vertice','bb','bb_f1','bb_miset']].to_latex(index=False,float_format="%.1f"))

with open('../result/table_mip.tex', 'w') as tf:
     tf.write(
          result[[
               'vertice',
               'bs','time',
               'bs_f1','time_f1',
               'bs_miset','time_miset',
               'bs_nei','time_nei'
               ]].to_latex(index=False,float_format="%.1f")
               )

# %%
#print(result[[
#    'vertice',
#    'bs','gap','time',
#    'bs_f1','gap_f1','time_f1',
#    'bs_ind','gap_ind','time_ind',
#    'bs_rlt','gap_rlt','time_rlt'
#    ]].to_latex(index=False,float_format="%.1f"))

# %%
#with open('table.tex', 'w') as tf:
#     tf.write(
#          result[[
#               'vertice',
#               'bs','gap','time',
#               'bs_f1','gap_f1','time_f1',
#               'bs_ind','gap_ind','time_ind',
#               ]].to_latex(index=False,float_format="%.1f")
#               )

# %%
inst_="karate"
method_="rf"

file=f"/home/jossian/repository/tukey/result/{inst_}_{method_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bs','time']

resume = pd.DataFrame({
    'vertice':f"{inst_}",
    'bs':table['bs'].max(),
    'time':table['time'].sum(),
    },index=["rf"]
)

table = pd.concat([table, resume], ignore_index=True)
rf = table

print(rf[['vertice','bs','time']].to_latex(index=False,float_format="%.2f"))
