# %%
# %matplotlib inline

from pathlib import Path

import networkx as nx

import numpy as np

import gurobipy as gp
from gurobipy import GRB


from itertools import combinations

import time as trun

# %%
def is_subclique(G, nodelist):
    '''
    For each pair of nodes in nodelist whether there is an edge
    if any edge is missing, we know that it's not a subclique.
    if all edges are there, it is a subclique
    '''
    for (u,v) in combinations(nodelist,2):  #check each possible pair
        if not G.has_edge(u,v):
            return False #if any edge is missing we're done
    return True  #if we get to here, then every edge was there.  It's True.

# %%
def is_mindset(G, nodelist):
    for (u,v) in combinations(nodelist,2):
        if G.has_edge(u,v):
            return False
    return True

# %%
#instance

#inst_="internet_graph"
#dim_=75
#id_=1
#instance_=f"{inst_}_{dim_}_{id_}"
#G = nx.read_gml(f"../instances/{inst_}/{dim_}/{instance_}.gml.gz",destringizer=int)

inst_="karate"
instance_=f"{inst_}"
G = nx.read_gml(f"../instances/{inst_}/{instance_}.gml.gz",destringizer=int)

# %%
nx.draw(G,  with_labels = True)

# %%
nx.is_connected(G)
# Out:
# True

# %%
N = nx.number_of_nodes(G)
M = nx.number_of_edges(G)

dm = np.zeros((N,N), dtype=int)

p = nx.shortest_path(G)

for i in range(0,N):
    for j in range(0,N):
        dm[i][j] = len(p[i][j])-1

# %%
#for i in G:
#    Ni = nx.neighbors(G,i)
#
#    nodelist = []
#    for k in Ni:
#        nodelist.append(k)
#    
#    if(is_subclique(G, nodelist)):
#        print("vizinhanca de %d" %i)

# %%
#for u in range(0,N):
Nu = nx.neighbors(G,1)

listNu = []
for k in Nu:
    listNu.append(k)

#print(list0)

T = nx.Graph()
T.add_nodes_from(listNu)
for (a,b) in combinations(listNu,2):
    if G.has_edge(a,b):
        T.add_edge(a,b)

Im = nx.maximal_independent_set(T)

print(Im)

#nx.draw(T,  with_labels = True)
# Out:
# [2, 30, 19, 17, 21]

# %%
form_="fmin_miset"
method_="mip"

N = nx.number_of_nodes(G)
M = nx.number_of_edges(G)

lb = np.zeros((N), dtype=float)
ub = np.zeros((N), dtype=float)
time = np.zeros((N), dtype=float)
gap = np.zeros((N), dtype=float)
nodes = np.zeros((N), dtype=float)
status = np.zeros((N), dtype=float)

con_geo = 0
con_neighb = 0
con_miset = 0
con_miset_neighb = 1

result_path = Path('../result/')

for i in G:

    Ni = nx.neighbors(G,i)

    listNi = []
    for k in Ni:
        listNi.append(k)

    tstart = trun.time()
    status_clique = is_subclique(G, listNi)
    tend = trun.time()

    elapsed_time = tend - tstart
    
    if(status_clique):
        #print("tukey[%d] = 1" %i)
        lb[i] = 1
        ub[i] = 1
        gap[i] = 0.0
        time[i] = elapsed_time
        nodes[i] = 0
        status[i] = 1
    else:

        model = gp.Model(f"{instance_}")

        if (method_=="mip"):
            x = model.addVars(N, vtype=GRB.BINARY, name="x")
        else:
            x = model.addVars(N, lb=0.0, ub=1.0, vtype=GRB.CONTINUOUS, name="x")
    
        obj = 0
        for j in G:
            obj += 1 * x[j]
         
        model.setObjective(obj, GRB.MINIMIZE)
    
        # configurando parametros
        # model.Params.TimeLimit = 60
        model.Params.MIPGap = 1.e-6
        model.Params.Threads = 1
        # model.Params.Presolve = 0
        # model.Params.Cuts = 0
 
        # Turn off display and heuristics
        gp.setParam('OutputFlag', 0)
        gp.setParam('Heuristics', 0)

        model.addConstr(x[i] == 1, "fix_x")

        # geodesic
        if con_geo == 1:
            for u in range(0,N):
                for w in range(u+1,N):
                    #if dm[u,w] <= N:
                    for s in range(0,N):
                        if (s != u) and (s != w):
                            if (dm[u,s] + dm[s,w] == dm[u,w]):
                                model.addConstr(x[u] + x[w] >= x[s], "geodesic")

        # geodesic neighbors
        if con_neighb == 1:
            for u in range(0,N):
                Nu = nx.neighbors(G,u)

                listNu = []
                for j in Nu:
                    listNu.append(j)

                for w in range(u+1,N):
                    if (w != u) and (w not in listNu):
                        for s in listNu:
                            if (s != w) and (dm[u,s] + dm[s,w] == dm[u,w]):
                                model.addConstr(x[u] + x[w] >= x[s], "geodesic_neighb")

        # maximal independent set
        if con_miset == 1:
            for u in range(0,N):
                Nu = nx.neighbors(G,u)

                listNu = []
                for k in Nu:
                    listNu.append(k)

                T = nx.Graph()
                T.add_nodes_from(listNu)
                for (a,b) in combinations(listNu,2):
                    if G.has_edge(a,b):
                        T.add_edge(a,b)

                #nx.draw(T,  with_labels = True)

                Im = nx.maximal_independent_set(T)

                if (len(Im) > 0):
                    constr = 0
                    for k in Im:
                        constr += 1 * x[k]
                    model.addConstr(constr >= (len(Im)- 1)*x[u], "miset")

        # maximal independent set
        if con_miset_neighb == 1:

            for u in range(0,N):
                Nu = nx.neighbors(G,u)

                listNu = []
                for k in Nu:
                    listNu.append(k)

                T = nx.Graph()
                T.add_nodes_from(listNu)
                for (a,b) in combinations(listNu,2):
                    if G.has_edge(a,b):
                        T.add_edge(a,b)

                #nx.draw(T,  with_labels = True)

                Im = nx.maximal_independent_set(T)

                if (len(Im) > 0):
                    constr = 0
                    for k in Im:
                        constr += 1 * x[k]
                    model.addConstr(constr >= (len(Im)- 1)*x[u], "miset")

            for u in range(0,N):
                Nu = nx.neighbors(G,u)

                listNu = []
                for j in Nu:
                    listNu.append(j)

                for w in range(u+1,N):
                    if (w != u) and (w not in listNu):
                        for s in listNu:
                            if (s != w) and (dm[u,s] + dm[s,w] == dm[u,w]) and (dm[u,w] >= 3):
                                model.addConstr(x[u] + x[w] >= x[s], "geodesic_miset_neighb")

                T.clear()

        model.optimize()

        tmp = 0
        if model.status == GRB.OPTIMAL:
            tmp = 1
    
        if (method_=="mip"):
            lb[i] = model.objBound
            ub[i] = model.objVal
            gap[i] = model.MIPGap
            time[i] = model.Runtime
            nodes[i] = model.NodeCount
            status[i] = tmp
        else:
            ub[i] = model.objVal
            time[i] = model.Runtime
            status[i] = tmp

        model.dispose()

# %%
tksum = np.sum(ub)
tkmax = np.max(ub)
tktime = np.sum(time)

# %%
if method_ == "lp":
    for i in G:
        print(
            "node:%d, ub: %2f, time: %2f " % (i, ub[i], time[i])
            )
    
    print("tksum : %.2f" %(tksum))
    print("tkmax : %.2f" %(tkmax))
    print("tktime : %.2f" %(tktime))

if method_ == "mip":
    for i in G:
        print(
            "node:%d, lb: %d, ub: %d, gap: %.2f, time: %.2f, nodes: %d, status: %d " 
            % (i, lb[i], ub[i], gap[i], time[i], nodes[i], status[i])
            )
    
    print("tksum : %.2f" %(tksum))
    print("tkmax : %.2f" %(tkmax))
    print("tktime : %.2f" %(tktime))

#G.clear()
# Out:
# node:0, lb: 20, ub: 20, gap: 0.00, time: 0.03, nodes: 1, status: 1
# node:1, lb: 7, ub: 7, gap: 0.00, time: 0.00, nodes: 1, status: 1
# node:2, lb: 17, ub: 17, gap: 0.00, time: 0.01, nodes: 1, status: 1
# node:3, lb: 3, ub: 3, gap: 0.00, time: 0.00, nodes: 1, status: 1
# node:4, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 1, status: 1
# node:5, lb: 2, ub: 2, gap: 0.00, time: 0.00, nodes: 1, status: 1
# node:6, lb: 2, ub: 2, gap: 0.00, time: 0.00, nodes: 1, status: 1
# node:7, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 0, status: 1
# node:8, lb: 16, ub: 16, gap: 0.00, time: 0.04, nodes: 4, status: 1
# node:9, lb: 16, ub: 16, gap: 0.00, time: 0.04, nodes: 2, status: 1
# node:10, lb: 2, ub: 2, gap: 0.00, time: 0.00, nodes: 1, status: 1
# node:11, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 0, status: 1
# node:12, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 0, status: 1
# node:13, lb: 17, ub: 17, gap: 0.00, time: 0.02, nodes: 8, status: 1
# node:14, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 0, status: 1
# node:15, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 0, status: 1
# node:16, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 0, status: 1
# node:17, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 0, status: 1
# node:18, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 0, status: 1
# node:19, lb: 14, ub: 14, gap: 0.00, time: 0.00, nodes: 1, status: 1
# node:20, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 0, status: 1
# node:21, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 0, status: 1
# node:22, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 0, status: 1
# node:23, lb: 3, ub: 3, gap: 0.00, time: 0.00, nodes: 1, status: 1
# node:24, lb: 16, ub: 16, gap: 0.00, time: 0.09, nodes: 13, status: 1
# node:25, lb: 3, ub: 3, gap: 0.00, time: 0.00, nodes: 1, status: 1
# node:26, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 0, status: 1
# node:27, lb: 16, ub: 16, gap: 0.00, time: 0.05, nodes: 4, status: 1
# node:28, lb: 16, ub: 16, gap: 0.00, time: 0.06, nodes: 10, status: 1
# node:29, lb: 1, ub: 1, gap: 0.00, time: 0.00, nodes: 1, status: 1
# node:30, lb: 12, ub: 12, gap: 0.00, time: 0.01, nodes: 1, status: 1
# node:31, lb: 17, ub: 17, gap: 0.00, time: 0.02, nodes: 1, status: 1
# node:32, lb: 15, ub: 15, gap: 0.00, time: 0.04, nodes: 2, status: 1
# node:33, lb: 17, ub: 17, gap: 0.00, time: 0.01, nodes: 1, status: 1
# tksum : 245.00
# tkmax : 20.00
# tktime : 0.43
