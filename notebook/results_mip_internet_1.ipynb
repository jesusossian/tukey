# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="internet_graph"
method_="mip"
dim_=200
id_=1

# %%
form_="fminc1"
ver_="fmin"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fminc1 = table
mip_internet_fminc1

#print(mip_internet_fminc1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#               vertice      bb      bs  gap     time   nodes    opt     tk  \
# 0                   0   143.0   143.0  0.0    24.34    49.0    1.0    NaN
# 1                   1   124.0   124.0  0.0    17.19     1.0    1.0    NaN
# 2                   2   127.0   127.0  0.0     3.06     1.0    1.0    NaN
# 3                   3   124.0   124.0  0.0    22.32    13.0    1.0    NaN
# 4                   4   124.0   124.0  0.0    36.69    47.0    1.0    NaN
# ..                ...     ...     ...  ...      ...     ...    ...    ...
# 196               196     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 197               197     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 198               198     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 199               199     1.0     1.0  0.0     0.00     0.0    1.0    NaN
# 200  mip_fminc1_200_1  5092.0  5092.0  0.0  1495.44  1678.0  200.0  149.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  65.93
#
# [201 rows x 9 columns]

# %%
form_="fminc2"
ver_="fmin"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fminc2 = table
mip_internet_fminc2

#print(mip_internet_fminc1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#               vertice      bb      bs  gap    time   nodes    opt     tk  \
# 0                   0   143.0   143.0  0.0    7.54    65.0    1.0    NaN
# 1                   1   124.0   124.0  0.0    6.90     1.0    1.0    NaN
# 2                   2   127.0   127.0  0.0    2.72     1.0    1.0    NaN
# 3                   3   124.0   124.0  0.0   17.17    21.0    1.0    NaN
# 4                   4   124.0   124.0  0.0   10.43    67.0    1.0    NaN
# ..                ...     ...     ...  ...     ...     ...    ...    ...
# 196               196     1.0     1.0  0.0    0.00     0.0    1.0    NaN
# 197               197     1.0     1.0  0.0    0.00     0.0    1.0    NaN
# 198               198     1.0     1.0  0.0    0.00     0.0    1.0    NaN
# 199               199     1.0     1.0  0.0    0.00     0.0    1.0    NaN
# 200  mip_fminc2_200_1  5092.0  5092.0  0.0  562.01  2350.0  200.0  149.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  24.64
#
# [201 rows x 9 columns]

# %%
form_="fminmiset"
ver_="fmin"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fminmiset = table
mip_internet_fminmiset

#print(mip_internet_fminmiset[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                  vertice      bb      bs  gap  time  nodes    opt     tk  tmax
# 0                      0   137.0   137.0  0.0  0.11   11.0    1.0    NaN   NaN
# 1                      1   120.0   120.0  0.0  0.10    5.0    1.0    NaN   NaN
# 2                      2   122.0   122.0  0.0  0.03    1.0    1.0    NaN   NaN
# 3                      3   120.0   120.0  0.0  0.11   13.0    1.0    NaN   NaN
# 4                      4   120.0   120.0  0.0  0.14   17.0    1.0    NaN   NaN
# ..                   ...     ...     ...  ...   ...    ...    ...    ...   ...
# 196                  196     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 197                  197     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 198                  198     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 199                  199     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 200  mip_fminmiset_200_1  4931.0  4931.0  0.0  4.37  624.0  200.0  146.0  0.17
#
# [201 rows x 9 columns]

# %%
form_="fminmisetc2"
ver_="fmin"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fminmisetc2 = table
mip_internet_fminmisetc2

#print(mip_internet_fminmisetc2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap    time  nodes    opt     tk  \
# 0                        0   143.0   143.0  0.0   10.12    9.0    1.0    NaN
# 1                        1   124.0   124.0  0.0    4.58    1.0    1.0    NaN
# 2                        2   127.0   127.0  0.0    2.15    1.0    1.0    NaN
# 3                        3   124.0   124.0  0.0   12.03   13.0    1.0    NaN
# 4                        4   124.0   124.0  0.0   10.76   11.0    1.0    NaN
# ..                     ...     ...     ...  ...     ...    ...    ...    ...
# 196                    196     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 197                    197     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 198                    198     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 199                    199     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 200  mip_fminmisetc2_200_1  5092.0  5092.0  0.0  552.59  454.0  200.0  149.0
#
#      tmax
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 196   NaN
# 197   NaN
# 198   NaN
# 199   NaN
# 200  24.7
#
# [201 rows x 9 columns]

# %%
form_="fminmisetc3"
ver_="fmin"

file=f"../result/{inst_}/{method_}/{ver_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fminmisetc3 = table
mip_internet_fminmisetc3

#print(mip_internet_fminmisetc2[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap    time  nodes    opt     tk  \
# 0                        0   143.0   143.0  0.0    7.19    9.0    1.0    NaN
# 1                        1   124.0   124.0  0.0    4.73    1.0    1.0    NaN
# 2                        2   127.0   127.0  0.0    2.08    1.0    1.0    NaN
# 3                        3   124.0   124.0  0.0   14.13    9.0    1.0    NaN
# 4                        4   124.0   124.0  0.0   11.86    9.0    1.0    NaN
# ..                     ...     ...     ...  ...     ...    ...    ...    ...
# 196                    196     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 197                    197     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 198                    198     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 199                    199     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 200  mip_fminmisetc3_200_1  5092.0  5092.0  0.0  496.03  468.0  200.0  149.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  21.45
#
# [201 rows x 9 columns]

# %%
fmin_200_1 = pd.DataFrame()

fmin_200_1 = pd.merge(
    mip_internet_fminc1, mip_internet_fminc2,
    on=['vertice'], 
    suffixes=("", "_b"),
    )

fmin_200_1 = pd.merge(
    fmin_200_1, mip_internet_fminmiset,
    on=['vertice'], 
    suffixes=("", "_c"),
    )

fmin_200_1 = pd.merge(
    fmin_200_1, mip_internet_fminmisetc2,
    on=['vertice'], 
    suffixes=("", "_d"),
    )

fmin_200_1 = pd.merge(
    fmin_200_1, mip_internet_fminmisetc3,
    on=['vertice'], 
    suffixes=("", "_e"),
    )


fmin_200_1[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',
    ]]
# Out:
#     vertice     bs  gap   time  opt  tk  tmax   bs_b  gap_b  time_b  ...  \
# 0         0  143.0  0.0  24.34  1.0 NaN   NaN  143.0    0.0    7.54  ...
# 1         1  124.0  0.0  17.19  1.0 NaN   NaN  124.0    0.0    6.90  ...
# 2         2  127.0  0.0   3.06  1.0 NaN   NaN  127.0    0.0    2.72  ...
# 3         3  124.0  0.0  22.32  1.0 NaN   NaN  124.0    0.0   17.17  ...
# 4         4  124.0  0.0  36.69  1.0 NaN   NaN  124.0    0.0   10.43  ...
# ..      ...    ...  ...    ...  ...  ..   ...    ...    ...     ...  ...
# 195     195    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.00  ...
# 196     196    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.00  ...
# 197     197    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.00  ...
# 198     198    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.00  ...
# 199     199    1.0  0.0   0.00  1.0 NaN   NaN    1.0    0.0    0.00  ...
#
#      time_d  opt_d  tk_d  tmax_d   bs_e  gap_e  time_e  opt_e  tk_e  tmax_e
# 0     10.12    1.0   NaN     NaN  143.0    0.0    7.19    1.0   NaN     NaN
# 1      4.58    1.0   NaN     NaN  124.0    0.0    4.73    1.0   NaN     NaN
# 2      2.15    1.0   NaN     NaN  127.0    0.0    2.08    1.0   NaN     NaN
# 3     12.03    1.0   NaN     NaN  124.0    0.0   14.13    1.0   NaN     NaN
# 4     10.76    1.0   NaN     NaN  124.0    0.0   11.86    1.0   NaN     NaN
# ..      ...    ...   ...     ...    ...    ...     ...    ...   ...     ...
# 195    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 196    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 197    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 198    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
# 199    0.00    1.0   NaN     NaN    1.0    0.0    0.00    1.0   NaN     NaN
#
# [200 rows x 31 columns]

# %%
print(
fmin_200_1[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_b','gap_b','time_b','opt_b','tk_b','tmax_b',
    'bs_c','gap_c','time_c','opt_c','tk_c','tmax_c',
    'bs_d','gap_d','time_d','opt_d','tk_d','tmax_d',
    'bs_e','gap_e','time_e','opt_e','tk_e','tmax_e',
    ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr}
# \toprule
# vertice &    bs &  gap &  time &  opt &  tk &  tmax &  bs\_b &  gap\_b &  time\_b &  opt\_b &  tk\_b &  tmax\_b &  bs\_c &  gap\_c &  time\_c &  opt\_c &  tk\_c &  tmax\_c &  bs\_d &  gap\_d &  time\_d &  opt\_d &  tk\_d &  tmax\_d &  bs\_e &  gap\_e &  time\_e &  opt\_e &  tk\_e &  tmax\_e \\
# \midrule
#       0 & 143.0 &  0.0 &  24.3 &  1.0 & NaN &   NaN & 143.0 &    0.0 &     7.5 &    1.0 &   NaN &     NaN & 137.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 143.0 &    0.0 &    10.1 &    1.0 &   NaN &     NaN & 143.0 &    0.0 &     7.2 &    1.0 &   NaN &     NaN \\
#       1 & 124.0 &  0.0 &  17.2 &  1.0 & NaN &   NaN & 124.0 &    0.0 &     6.9 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &     4.6 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &     4.7 &    1.0 &   NaN &     NaN \\
#       2 & 127.0 &  0.0 &   3.1 &  1.0 & NaN &   NaN & 127.0 &    0.0 &     2.7 &    1.0 &   NaN &     NaN & 122.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     2.1 &    1.0 &   NaN &     NaN & 127.0 &    0.0 &     2.1 &    1.0 &   NaN &     NaN \\
#       3 & 124.0 &  0.0 &  22.3 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    17.2 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    12.0 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    14.1 &    1.0 &   NaN &     NaN \\
#       4 & 124.0 &  0.0 &  36.7 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    10.4 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    10.8 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    11.9 &    1.0 &   NaN &     NaN \\
#       5 &  16.0 &  0.0 &   0.6 &  1.0 & NaN &   NaN &  16.0 &    0.0 &     0.2 &    1.0 &   NaN &     NaN &  16.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &  16.0 &    0.0 &     0.2 &    1.0 &   NaN &     NaN &  16.0 &    0.0 &     0.2 &    1.0 &   NaN &     NaN \\
#       6 & 124.0 &  0.0 &  28.0 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    10.9 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    11.6 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &     8.2 &    1.0 &   NaN &     NaN \\
#       7 & 124.0 &  0.0 &  31.2 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    12.1 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    12.0 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &     8.9 &    1.0 &   NaN &     NaN \\
#       8 & 125.0 &  0.0 &   4.1 &  1.0 & NaN &   NaN & 125.0 &    0.0 &     3.1 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN & 125.0 &    0.0 &     2.1 &    1.0 &   NaN &     NaN & 125.0 &    0.0 &     1.9 &    1.0 &   NaN &     NaN \\
#       9 & 124.0 &  0.0 &  27.7 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    10.5 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    13.2 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    12.1 &    1.0 &   NaN &     NaN \\
#      10 & 149.0 &  0.0 &  17.4 &  1.0 & NaN &   NaN & 149.0 &    0.0 &     8.7 &    1.0 &   NaN &     NaN & 146.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 149.0 &    0.0 &     9.5 &    1.0 &   NaN &     NaN & 149.0 &    0.0 &     8.2 &    1.0 &   NaN &     NaN \\
#      11 & 124.0 &  0.0 &  22.7 &  1.0 & NaN &   NaN & 124.0 &    0.0 &     9.9 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    11.3 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    10.3 &    1.0 &   NaN &     NaN \\
#      12 & 124.0 &  0.0 &  65.9 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    18.4 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    16.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    17.8 &    1.0 &   NaN &     NaN \\
#      13 & 124.0 &  0.0 &  62.2 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    17.7 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    17.4 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    16.9 &    1.0 &   NaN &     NaN \\
#      14 & 124.0 &  0.0 &  39.9 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    17.2 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    16.8 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    13.8 &    1.0 &   NaN &     NaN \\
#      15 & 124.0 &  0.0 &  30.7 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    11.5 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    12.5 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    11.2 &    1.0 &   NaN &     NaN \\
#      16 & 124.0 &  0.0 &  44.6 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    19.6 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    17.2 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    17.0 &    1.0 &   NaN &     NaN \\
#      17 & 124.0 &  0.0 &  32.4 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    14.8 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.2 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &     9.2 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    10.5 &    1.0 &   NaN &     NaN \\
#      18 & 124.0 &  0.0 &  33.8 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    23.3 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    24.7 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    20.6 &    1.0 &   NaN &     NaN \\
#      19 & 124.0 &  0.0 &  52.1 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    13.8 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    11.6 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &     9.1 &    1.0 &   NaN &     NaN \\
#      20 & 125.0 &  0.0 &  35.1 &  1.0 & NaN &   NaN & 125.0 &    0.0 &    17.5 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 125.0 &    0.0 &    15.5 &    1.0 &   NaN &     NaN & 125.0 &    0.0 &    11.6 &    1.0 &   NaN &     NaN \\
#      21 & 124.0 &  0.0 &  53.3 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    16.3 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    13.8 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    13.3 &    1.0 &   NaN &     NaN \\
#      22 & 124.0 &  0.0 &  31.3 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    10.3 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    11.4 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &     9.2 &    1.0 &   NaN &     NaN \\
#      23 & 124.0 &  0.0 &  30.4 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    10.6 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    11.2 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    13.2 &    1.0 &   NaN &     NaN \\
#      24 & 124.0 &  0.0 &  20.5 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    13.4 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    15.7 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    15.1 &    1.0 &   NaN &     NaN \\
#      25 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      26 & 124.0 &  0.0 &  38.0 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    16.3 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    12.6 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    16.2 &    1.0 &   NaN &     NaN \\
#      27 & 124.0 &  0.0 &  60.7 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    14.0 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    14.7 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    12.1 &    1.0 &   NaN &     NaN \\
#      28 & 124.0 &  0.0 &  47.1 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    15.5 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    16.3 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    14.8 &    1.0 &   NaN &     NaN \\
#      29 & 125.0 &  0.0 &  40.5 &  1.0 & NaN &   NaN & 125.0 &    0.0 &    18.3 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 125.0 &    0.0 &    16.9 &    1.0 &   NaN &     NaN & 125.0 &    0.0 &    15.2 &    1.0 &   NaN &     NaN \\
#      30 & 124.0 &  0.0 &  50.6 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    13.8 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    19.2 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    15.6 &    1.0 &   NaN &     NaN \\
#      31 & 124.0 &  0.0 &  26.0 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    12.1 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    17.3 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    10.4 &    1.0 &   NaN &     NaN \\
#      32 & 124.0 &  0.0 &  57.1 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    24.6 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    24.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    14.6 &    1.0 &   NaN &     NaN \\
#      33 & 124.0 &  0.0 &  47.0 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    15.7 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    22.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    21.2 &    1.0 &   NaN &     NaN \\
#      34 & 124.0 &  0.0 &  52.6 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    14.9 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    17.9 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    17.1 &    1.0 &   NaN &     NaN \\
#      35 &  16.0 &  0.0 &   0.5 &  1.0 & NaN &   NaN &  16.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN &  16.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &  16.0 &    0.0 &     0.2 &    1.0 &   NaN &     NaN &  16.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#      36 & 124.0 &  0.0 &  59.5 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    20.3 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    19.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    12.1 &    1.0 &   NaN &     NaN \\
#      37 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      38 & 124.0 &  0.0 &  58.3 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    22.6 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    18.5 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    15.1 &    1.0 &   NaN &     NaN \\
#      39 & 124.0 &  0.0 &  40.7 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    21.1 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    21.7 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    16.3 &    1.0 &   NaN &     NaN \\
#      40 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      41 & 124.0 &  0.0 &  48.8 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    15.6 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    12.3 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    13.3 &    1.0 &   NaN &     NaN \\
#      42 & 124.0 &  0.0 &  47.3 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    15.8 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    14.2 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    21.4 &    1.0 &   NaN &     NaN \\
#      43 & 124.0 &  0.0 &  52.8 &  1.0 & NaN &   NaN & 124.0 &    0.0 &    16.3 &    1.0 &   NaN &     NaN & 120.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    12.5 &    1.0 &   NaN &     NaN & 124.0 &    0.0 &    11.4 &    1.0 &   NaN &     NaN \\
#      44 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      45 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      46 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      47 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      48 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      49 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      50 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      51 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      52 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      53 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      54 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      55 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      56 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      57 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      58 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      59 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      60 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      61 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      62 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      63 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      64 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      65 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      66 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      67 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      68 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      69 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      70 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      71 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      72 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      73 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      74 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      75 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      76 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      77 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      78 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      79 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      80 &  16.0 &  0.0 &   0.5 &  1.0 & NaN &   NaN &  16.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN &  16.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &  16.0 &    0.0 &     0.2 &    1.0 &   NaN &     NaN &  16.0 &    0.0 &     0.1 &    1.0 &   NaN &     NaN \\
#      81 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      82 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      83 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      84 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      85 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      86 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      87 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      88 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      89 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      90 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      91 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      92 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      93 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      94 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      95 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      96 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      97 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      98 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#      99 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     100 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     101 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     102 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     103 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     104 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     105 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     106 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     107 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     108 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     109 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     110 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     111 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     112 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     113 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     114 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     115 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     116 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     117 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     118 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     119 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     120 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     121 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     122 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     123 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     124 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     125 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     126 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     127 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     128 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     129 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     130 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     131 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     132 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     133 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     134 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     135 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     136 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     137 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     138 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     139 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     140 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     141 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     142 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     143 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     144 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     145 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     146 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     147 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     148 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     149 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     150 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     151 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     152 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     153 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     154 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     155 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     156 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     157 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     158 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     159 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     160 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     161 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     162 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     163 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     164 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     165 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     166 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     167 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     168 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     169 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     170 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     171 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     172 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     173 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     174 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     175 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     176 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     177 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     178 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     179 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     180 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     181 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     182 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     183 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     184 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     185 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     186 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     187 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     188 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     189 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     190 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     191 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     192 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     193 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     194 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     195 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     196 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     197 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     198 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
#     199 &   1.0 &  0.0 &   0.0 &  1.0 & NaN &   NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN &   1.0 &    0.0 &     0.0 &    1.0 &   NaN &     NaN \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_5977/1957958473.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   fmin_200_1[[

# %%
resume_200_1 = pd.DataFrame()
resume_200_1 = pd.concat([resume_200_1, mip_internet_fminc1.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_fminc2.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_fminmiset.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_fminmisetc2.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_fminmisetc3.loc[200:200]], ignore_index=True)
resume_200_1
# Out:
#                  vertice      bb      bs  gap     time   nodes    opt     tk  \
# 0       mip_fminc1_200_1  5092.0  5092.0  0.0  1495.44  1678.0  200.0  149.0
# 1       mip_fminc2_200_1  5092.0  5092.0  0.0   562.01  2350.0  200.0  149.0
# 2    mip_fminmiset_200_1  4931.0  4931.0  0.0     4.37   624.0  200.0  146.0
# 3  mip_fminmisetc2_200_1  5092.0  5092.0  0.0   552.59   454.0  200.0  149.0
# 4  mip_fminmisetc3_200_1  5092.0  5092.0  0.0   496.03   468.0  200.0  149.0
#
#     tmax
# 0  65.93
# 1  24.64
# 2   0.17
# 3  24.70
# 4  21.45

# %%
print(
resume_200_1[[
    'vertice','bs','gap','time','opt','tk','tmax',
    ]].to_latex(index=False,float_format="%.1f")
)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
#               vertice &     bs &  gap &   time &   opt &    tk &  tmax \\
# \midrule
#      mip\_fminc1\_200\_1 & 5092.0 &  0.0 & 1495.4 & 200.0 & 149.0 &  65.9 \\
#      mip\_fminc2\_200\_1 & 5092.0 &  0.0 &  562.0 & 200.0 & 149.0 &  24.6 \\
#   mip\_fminmiset\_200\_1 & 4931.0 &  0.0 &    4.4 & 200.0 & 146.0 &   0.2 \\
# mip\_fminmisetc2\_200\_1 & 5092.0 &  0.0 &  552.6 & 200.0 & 149.0 &  24.7 \\
# mip\_fminmisetc3\_200\_1 & 5092.0 &  0.0 &  496.0 & 200.0 & 149.0 &  21.4 \\
# \bottomrule
# \end{tabular}
# /tmp/ipykernel_5977/329633122.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   resume_200_1[[
