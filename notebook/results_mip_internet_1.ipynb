# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inst_="internet_graph"
method_="mip"

# %%
form_="fmin"
dim_=200
id_=1

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fmin_200_1 = table
mip_internet_fmin_200_1

#print(mip_internet_fmin_200_1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#             vertice      bb      bs  gap    time   nodes    opt     tk   tmax
# 0                 0   143.0   143.0  0.0    8.19    65.0    1.0    NaN    NaN
# 1                 1   124.0   124.0  0.0    8.46     1.0    1.0    NaN    NaN
# 2                 2   127.0   127.0  0.0    3.35     1.0    1.0    NaN    NaN
# 3                 3   124.0   124.0  0.0   21.64    21.0    1.0    NaN    NaN
# 4                 4   124.0   124.0  0.0   11.74    67.0    1.0    NaN    NaN
# ..              ...     ...     ...  ...     ...     ...    ...    ...    ...
# 196             196     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 197             197     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 198             198     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 199             199     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 200  mip_fmin_200_1  5092.0  5092.0  0.0  613.07  2350.0  200.0  149.0  27.17
#
# [201 rows x 9 columns]

# %%
form_="fmax"
dim_=200
id_=1

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fmax_200_1 = table
mip_internet_fmax_200_1

#print(mip_internet_fmax_200_1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#             vertice      bb      bs  gap    time   nodes    opt     tk   tmax
# 0                 0   143.0   143.0  0.0   11.26    61.0    1.0    NaN    NaN
# 1                 1   124.0   124.0  0.0    6.75     1.0    1.0    NaN    NaN
# 2                 2   127.0   127.0  0.0    3.60     1.0    1.0    NaN    NaN
# 3                 3   124.0   124.0  0.0   16.90    15.0    1.0    NaN    NaN
# 4                 4   124.0   124.0  0.0   15.62    67.0    1.0    NaN    NaN
# ..              ...     ...     ...  ...     ...     ...    ...    ...    ...
# 196             196     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 197             197     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 198             198     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 199             199     1.0     1.0  0.0    0.00     0.0    1.0    NaN    NaN
# 200  mip_fmax_200_1  5092.0  5092.0  0.0  747.21  2260.0  200.0  149.0  50.21
#
# [201 rows x 9 columns]

# %%
form_="fmaxmisetn0"
dim_=200
id_=1

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fmaxmisetn0_200_1 = table
mip_internet_fmaxmisetn0_200_1

#print(mip_internet_fmaxmisetn0_200_1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap     time  nodes    opt     tk
# 0                        0   143.0   143.0  0.0    14.76   11.0    1.0    NaN  \
# 1                        1   124.0   124.0  0.0    14.79    1.0    1.0    NaN
# 2                        2   127.0   127.0  0.0     4.14    1.0    1.0    NaN
# 3                        3   124.0   124.0  0.0    20.46   12.0    1.0    NaN
# 4                        4   124.0   124.0  0.0    38.53   13.0    1.0    NaN
# ..                     ...     ...     ...  ...      ...    ...    ...    ...
# 196                    196     1.0     1.0  0.0     0.00    0.0    1.0    NaN
# 197                    197     1.0     1.0  0.0     0.00    0.0    1.0    NaN
# 198                    198     1.0     1.0  0.0     0.00    0.0    1.0    NaN
# 199                    199     1.0     1.0  0.0     0.00    0.0    1.0    NaN
# 200  mip_fmaxmisetn0_200_1  5092.0  5092.0  0.0  1648.47  580.0  200.0  149.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  80.96
#
# [201 rows x 9 columns]

# %%
form_="fminmiset"
dim_=200
id_=1

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fminmiset_200_1 = table
mip_internet_fminmiset_200_1

#print(mip_internet_fminmiset_200_1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                  vertice      bb      bs  gap  time  nodes    opt     tk  tmax
# 0                      0   105.0   105.0  0.0  0.03   10.0    1.0    NaN   NaN
# 1                      1    93.0    93.0  0.0  0.04    9.0    1.0    NaN   NaN
# 2                      2    96.0    96.0  0.0  0.03    7.0    1.0    NaN   NaN
# 3                      3    91.0    91.0  0.0  0.04   20.0    1.0    NaN   NaN
# 4                      4    82.0    82.0  0.0  0.04   13.0    1.0    NaN   NaN
# ..                   ...     ...     ...  ...   ...    ...    ...    ...   ...
# 196                  196     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 197                  197     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 198                  198     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 199                  199     1.0     1.0  0.0  0.00    0.0    1.0    NaN   NaN
# 200  mip_fminmiset_200_1  3485.0  3485.0  0.0  1.44  714.0  200.0  116.0  0.05
#
# [201 rows x 9 columns]

# %%
form_="fminmisetn0"
dim_=200
id_=1

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fminmisetn0_200_1 = table
mip_internet_fminmisetn0_200_1

#print(mip_internet_fminmisetn0_200_1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap    time  nodes    opt     tk
# 0                        0   143.0   143.0  0.0    7.86   13.0    1.0    NaN  \
# 1                        1   124.0   124.0  0.0    7.98    1.0    1.0    NaN
# 2                        2   127.0   127.0  0.0    2.13    1.0    1.0    NaN
# 3                        3   124.0   124.0  0.0   11.62   15.0    1.0    NaN
# 4                        4   124.0   124.0  0.0   13.64   13.0    1.0    NaN
# ..                     ...     ...     ...  ...     ...    ...    ...    ...
# 196                    196     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 197                    197     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 198                    198     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 199                    199     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 200  mip_fminmisetn0_200_1  5092.0  5092.0  0.0  565.33  584.0  200.0  149.0
#
#      tmax
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 196   NaN
# 197   NaN
# 198   NaN
# 199   NaN
# 200  24.5
#
# [201 rows x 9 columns]

# %%
form_="fminmisetn1"
dim_=200
id_=1

file=f"../result/{inst_}/{method_}/{method_}_{form_}_{inst_}_{dim_}_{id_}.txt"

df = pd.DataFrame()
df = pd.read_csv(file,header=None,sep=';')

table = pd.DataFrame()
table = pd.concat([table, df], ignore_index=True)
table.columns = ['vertice','bb','bs','gap','time','nodes','opt']

resume = pd.DataFrame({
    'vertice':f"{method_}_{form_}_{dim_}_{id_}",
    'bb':table["bb"].sum(),
    'bs':table["bs"].sum(),
    'gap':table['gap'].sum(),
    'time':table['time'].sum(),
    'nodes':table['nodes'].sum(),
    'opt':table['opt'].sum(),
    "tk":table["bs"].max(),
    "tmax":table["time"].max()
    },index=[f"{form_}_{inst_}_{dim_}_{id_}"]
)

table = pd.concat([table, resume], ignore_index=True)
mip_internet_fminmisetn1_200_1 = table
mip_internet_fminmisetn1_200_1

#print(mip_internet_fminmisetn1_200_1[['vertice','bb','bs','gap','time','nodes','opt']].to_latex(index=False,float_format="%.2f"))
# Out:
#                    vertice      bb      bs  gap    time  nodes    opt     tk
# 0                        0   143.0   143.0  0.0   10.82   15.0    1.0    NaN  \
# 1                        1   124.0   124.0  0.0   10.71    5.0    1.0    NaN
# 2                        2   127.0   127.0  0.0    3.25    1.0    1.0    NaN
# 3                        3   124.0   124.0  0.0   12.32   15.0    1.0    NaN
# 4                        4   124.0   124.0  0.0   12.80   15.0    1.0    NaN
# ..                     ...     ...     ...  ...     ...    ...    ...    ...
# 196                    196     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 197                    197     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 198                    198     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 199                    199     1.0     1.0  0.0    0.00    0.0    1.0    NaN
# 200  mip_fminmisetn1_200_1  5092.0  5092.0  0.0  618.72  806.0  200.0  149.0
#
#       tmax
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 196    NaN
# 197    NaN
# 198    NaN
# 199    NaN
# 200  30.21
#
# [201 rows x 9 columns]

# %%
result_200_1 = pd.DataFrame()

result_200_1 = pd.merge(
    mip_internet_fmin_200_1, mip_internet_fmax_200_1,
    on=['vertice'], 
    suffixes=("", "_fmax"),
    )

result_200_1 = pd.merge(
    result_200_1, mip_internet_fminmisetn0_200_1,
    on=['vertice'], 
    suffixes=("", "_fminmisetn0"),
    )

result_200_1 = pd.merge(
    result_200_1, mip_internet_fmaxmisetn0_200_1,
    on=['vertice'], 
    suffixes=("", "_fmaxmisetn0"),
    )

result_200_1 = pd.merge(
    result_200_1, mip_internet_fminmiset_200_1,
    on=['vertice'], 
    suffixes=("", "_fminmiset"),
    )

result_200_1 = pd.merge(
    result_200_1, mip_internet_fminmisetn1_200_1,
    on=['vertice'], 
    suffixes=("", "_fminmisetn1"),
    )

result_200_1[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_fmax','gap_fmax','time_fmax','opt_fmax','tk_fmax','tmax_fmax',
    'bs_fminmisetn0','gap_fminmisetn0','time_fminmisetn0','opt_fminmisetn0','tk_fminmisetn0','tmax_fminmisetn0',
    'bs_fmaxmisetn0','gap_fmaxmisetn0','time_fmaxmisetn0','opt_fmaxmisetn0','tk_fmaxmisetn0','tmax_fmaxmisetn0',
    'bs_fminmiset','gap_fminmiset','time_fminmiset','opt_fminmiset','tk_fminmiset','tmax_fminmiset',
    'bs_fminmisetn1','gap_fminmisetn1','time_fminmisetn1','opt_fminmisetn1','tk_fminmisetn1','tmax_fminmisetn1'
    ]]
# Out:
#     vertice     bs  gap   time  opt  tk  tmax  bs_fmax  gap_fmax  time_fmax
# 0         0  143.0  0.0   8.19  1.0 NaN   NaN    143.0       0.0      11.26  \
# 1         1  124.0  0.0   8.46  1.0 NaN   NaN    124.0       0.0       6.75
# 2         2  127.0  0.0   3.35  1.0 NaN   NaN    127.0       0.0       3.60
# 3         3  124.0  0.0  21.64  1.0 NaN   NaN    124.0       0.0      16.90
# 4         4  124.0  0.0  11.74  1.0 NaN   NaN    124.0       0.0      15.62
# ..      ...    ...  ...    ...  ...  ..   ...      ...       ...        ...
# 195     195    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 196     196    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 197     197    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 198     198    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
# 199     199    1.0  0.0   0.00  1.0 NaN   NaN      1.0       0.0       0.00
#
#      ...  time_fminmiset  opt_fminmiset  tk_fminmiset  tmax_fminmiset
# 0    ...            0.03            1.0           NaN             NaN  \
# 1    ...            0.04            1.0           NaN             NaN
# 2    ...            0.03            1.0           NaN             NaN
# 3    ...            0.04            1.0           NaN             NaN
# 4    ...            0.04            1.0           NaN             NaN
# ..   ...             ...            ...           ...             ...
# 195  ...            0.00            1.0           NaN             NaN
# 196  ...            0.00            1.0           NaN             NaN
# 197  ...            0.00            1.0           NaN             NaN
# 198  ...            0.00            1.0           NaN             NaN
# 199  ...            0.00            1.0           NaN             NaN
#
#      bs_fminmisetn1  gap_fminmisetn1  time_fminmisetn1  opt_fminmisetn1
# 0             143.0              0.0             10.82              1.0  \
# 1             124.0              0.0             10.71              1.0
# 2             127.0              0.0              3.25              1.0
# 3             124.0              0.0             12.32              1.0
# 4             124.0              0.0             12.80              1.0
# ..              ...              ...               ...              ...
# 195             1.0              0.0              0.00              1.0
# 196             1.0              0.0              0.00              1.0
# 197             1.0              0.0              0.00              1.0
# 198             1.0              0.0              0.00              1.0
# 199             1.0              0.0              0.00              1.0
#
#      tk_fminmisetn1  tmax_fminmisetn1
# 0               NaN               NaN
# 1               NaN               NaN
# 2               NaN               NaN
# 3               NaN               NaN
# 4               NaN               NaN
# ..              ...               ...
# 195             NaN               NaN
# 196             NaN               NaN
# 197             NaN               NaN
# 198             NaN               NaN
# 199             NaN               NaN
#
# [200 rows x 37 columns]

# %%
print(
result_200_1[[
    'vertice',
    'bs','gap','time','opt','tk','tmax',
    'bs_fmax','gap_fmax','time_fmax','opt_fmax','tk_fmax','tmax_fmax',
    'bs_fminmisetn0','gap_fminmisetn0','time_fminmisetn0','opt_fminmisetn0','tk_fminmisetn0','tmax_fminmisetn0',
    'bs_fmaxmisetn0','gap_fmaxmisetn0','time_fmaxmisetn0','opt_fmaxmisetn0','tk_fmaxmisetn0','tmax_fmaxmisetn0',
    'bs_fminmiset','gap_fminmiset','time_fminmiset','opt_fminmiset','tk_fminmiset','tmax_fminmiset',
    'bs_fminmisetn1','gap_fminmisetn1','time_fminmisetn1','opt_fminmisetn1','tk_fminmisetn1','tmax_fminmisetn1'
    ]].to_latex(index=False,float_format="%.1f")
    )
# Out:
# \begin{tabular}{lrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrrr}
# \toprule
# vertice & bs & gap & time & opt & tk & tmax & bs_fmax & gap_fmax & time_fmax & opt_fmax & tk_fmax & tmax_fmax & bs_fminmisetn0 & gap_fminmisetn0 & time_fminmisetn0 & opt_fminmisetn0 & tk_fminmisetn0 & tmax_fminmisetn0 & bs_fmaxmisetn0 & gap_fmaxmisetn0 & time_fmaxmisetn0 & opt_fmaxmisetn0 & tk_fmaxmisetn0 & tmax_fmaxmisetn0 & bs_fminmiset & gap_fminmiset & time_fminmiset & opt_fminmiset & tk_fminmiset & tmax_fminmiset & bs_fminmisetn1 & gap_fminmisetn1 & time_fminmisetn1 & opt_fminmisetn1 & tk_fminmisetn1 & tmax_fminmisetn1 \\
# \midrule
# 0 & 143.0 & 0.0 & 8.2 & 1.0 & NaN & NaN & 143.0 & 0.0 & 11.3 & 1.0 & NaN & NaN & 143.0 & 0.0 & 7.9 & 1.0 & NaN & NaN & 143.0 & 0.0 & 14.8 & 1.0 & NaN & NaN & 105.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 143.0 & 0.0 & 10.8 & 1.0 & NaN & NaN \\
# 1 & 124.0 & 0.0 & 8.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 6.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 8.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.8 & 1.0 & NaN & NaN & 93.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.7 & 1.0 & NaN & NaN \\
# 2 & 127.0 & 0.0 & 3.4 & 1.0 & NaN & NaN & 127.0 & 0.0 & 3.6 & 1.0 & NaN & NaN & 127.0 & 0.0 & 2.1 & 1.0 & NaN & NaN & 127.0 & 0.0 & 4.1 & 1.0 & NaN & NaN & 96.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 127.0 & 0.0 & 3.2 & 1.0 & NaN & NaN \\
# 3 & 124.0 & 0.0 & 21.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 16.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 20.5 & 1.0 & NaN & NaN & 91.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 12.3 & 1.0 & NaN & NaN \\
# 4 & 124.0 & 0.0 & 11.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 38.5 & 1.0 & NaN & NaN & 82.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 12.8 & 1.0 & NaN & NaN \\
# 5 & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.7 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN \\
# 6 & 124.0 & 0.0 & 12.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 20.0 & 1.0 & NaN & NaN & 88.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.5 & 1.0 & NaN & NaN \\
# 7 & 124.0 & 0.0 & 13.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 28.2 & 1.0 & NaN & NaN & 81.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.7 & 1.0 & NaN & NaN \\
# 8 & 125.0 & 0.0 & 3.5 & 1.0 & NaN & NaN & 125.0 & 0.0 & 3.5 & 1.0 & NaN & NaN & 125.0 & 0.0 & 2.7 & 1.0 & NaN & NaN & 125.0 & 0.0 & 3.4 & 1.0 & NaN & NaN & 106.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 125.0 & 0.0 & 4.5 & 1.0 & NaN & NaN \\
# 9 & 124.0 & 0.0 & 11.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 29.8 & 1.0 & NaN & NaN & 86.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.5 & 1.0 & NaN & NaN \\
# 10 & 149.0 & 0.0 & 9.6 & 1.0 & NaN & NaN & 149.0 & 0.0 & 10.2 & 1.0 & NaN & NaN & 149.0 & 0.0 & 11.3 & 1.0 & NaN & NaN & 149.0 & 0.0 & 18.5 & 1.0 & NaN & NaN & 116.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 149.0 & 0.0 & 10.9 & 1.0 & NaN & NaN \\
# 11 & 124.0 & 0.0 & 10.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 8.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 20.2 & 1.0 & NaN & NaN & 91.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 16.9 & 1.0 & NaN & NaN \\
# 12 & 124.0 & 0.0 & 20.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 81.0 & 1.0 & NaN & NaN & 81.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 30.2 & 1.0 & NaN & NaN \\
# 13 & 124.0 & 0.0 & 19.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 41.0 & 1.0 & NaN & NaN & 72.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 20.5 & 1.0 & NaN & NaN \\
# 14 & 124.0 & 0.0 & 18.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 20.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 50.4 & 1.0 & NaN & NaN & 91.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 22.7 & 1.0 & NaN & NaN \\
# 15 & 124.0 & 0.0 & 12.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 26.6 & 1.0 & NaN & NaN & 66.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.9 & 1.0 & NaN & NaN \\
# 16 & 124.0 & 0.0 & 25.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 22.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 69.0 & 1.0 & NaN & NaN & 83.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.4 & 1.0 & NaN & NaN \\
# 17 & 124.0 & 0.0 & 18.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 39.2 & 1.0 & NaN & NaN & 42.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 12.8 & 1.0 & NaN & NaN \\
# 18 & 124.0 & 0.0 & 27.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 24.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 22.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 57.5 & 1.0 & NaN & NaN & 99.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.5 & 1.0 & NaN & NaN \\
# 19 & 124.0 & 0.0 & 14.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 35.0 & 1.0 & NaN & NaN & 103.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.3 & 1.0 & NaN & NaN \\
# 20 & 125.0 & 0.0 & 18.6 & 1.0 & NaN & NaN & 125.0 & 0.0 & 18.7 & 1.0 & NaN & NaN & 125.0 & 0.0 & 12.9 & 1.0 & NaN & NaN & 125.0 & 0.0 & 50.7 & 1.0 & NaN & NaN & 97.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 125.0 & 0.0 & 16.3 & 1.0 & NaN & NaN \\
# 21 & 124.0 & 0.0 & 17.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 17.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 55.8 & 1.0 & NaN & NaN & 3.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.1 & 1.0 & NaN & NaN \\
# 22 & 124.0 & 0.0 & 10.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 28.1 & 1.0 & NaN & NaN & 98.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.6 & 1.0 & NaN & NaN \\
# 23 & 124.0 & 0.0 & 11.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 47.8 & 1.0 & NaN & NaN & 100.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.8 & 1.0 & NaN & NaN \\
# 24 & 124.0 & 0.0 & 14.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 16.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 33.8 & 1.0 & NaN & NaN & 88.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 22.0 & 1.0 & NaN & NaN \\
# 25 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 26 & 124.0 & 0.0 & 17.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 49.7 & 1.0 & NaN & NaN & 81.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.8 & 1.0 & NaN & NaN \\
# 27 & 124.0 & 0.0 & 14.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 27.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 17.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 45.9 & 1.0 & NaN & NaN & 4.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.5 & 1.0 & NaN & NaN \\
# 28 & 124.0 & 0.0 & 16.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 50.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 75.2 & 1.0 & NaN & NaN & 91.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 11.7 & 1.0 & NaN & NaN \\
# 29 & 125.0 & 0.0 & 19.1 & 1.0 & NaN & NaN & 125.0 & 0.0 & 37.8 & 1.0 & NaN & NaN & 125.0 & 0.0 & 16.7 & 1.0 & NaN & NaN & 125.0 & 0.0 & 45.3 & 1.0 & NaN & NaN & 95.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 125.0 & 0.0 & 17.4 & 1.0 & NaN & NaN \\
# 30 & 124.0 & 0.0 & 14.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 26.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 56.2 & 1.0 & NaN & NaN & 86.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 17.0 & 1.0 & NaN & NaN \\
# 31 & 124.0 & 0.0 & 12.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 25.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 25.3 & 1.0 & NaN & NaN & 93.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 10.5 & 1.0 & NaN & NaN \\
# 32 & 124.0 & 0.0 & 25.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 34.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 66.5 & 1.0 & NaN & NaN & 84.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 22.8 & 1.0 & NaN & NaN \\
# 33 & 124.0 & 0.0 & 16.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 21.9 & 1.0 & NaN & NaN & 124.0 & 0.0 & 16.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 65.9 & 1.0 & NaN & NaN & 81.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 23.0 & 1.0 & NaN & NaN \\
# 34 & 124.0 & 0.0 & 15.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 21.3 & 1.0 & NaN & NaN & 124.0 & 0.0 & 68.4 & 1.0 & NaN & NaN & 94.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.6 & 1.0 & NaN & NaN \\
# 35 & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.3 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.5 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN \\
# 36 & 124.0 & 0.0 & 21.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 24.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 21.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 56.6 & 1.0 & NaN & NaN & 62.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.9 & 1.0 & NaN & NaN \\
# 37 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 38 & 124.0 & 0.0 & 23.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 34.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 56.1 & 1.0 & NaN & NaN & 90.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.2 & 1.0 & NaN & NaN \\
# 39 & 124.0 & 0.0 & 22.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 17.8 & 1.0 & NaN & NaN & 124.0 & 0.0 & 13.6 & 1.0 & NaN & NaN & 124.0 & 0.0 & 45.2 & 1.0 & NaN & NaN & 98.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 17.4 & 1.0 & NaN & NaN \\
# 40 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 41 & 124.0 & 0.0 & 16.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.2 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 44.8 & 1.0 & NaN & NaN & 96.0 & 0.0 & 0.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 19.2 & 1.0 & NaN & NaN \\
# 42 & 124.0 & 0.0 & 16.7 & 1.0 & NaN & NaN & 124.0 & 0.0 & 18.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 24.5 & 1.0 & NaN & NaN & 124.0 & 0.0 & 72.3 & 1.0 & NaN & NaN & 81.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 15.6 & 1.0 & NaN & NaN \\
# 43 & 124.0 & 0.0 & 17.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 16.1 & 1.0 & NaN & NaN & 124.0 & 0.0 & 14.4 & 1.0 & NaN & NaN & 124.0 & 0.0 & 45.0 & 1.0 & NaN & NaN & 85.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 124.0 & 0.0 & 17.6 & 1.0 & NaN & NaN \\
# 44 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 45 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 46 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 47 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 48 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 49 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 50 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 51 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 52 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 53 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 54 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 55 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 56 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 57 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 58 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 59 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 60 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 61 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 62 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 63 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 64 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 65 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 66 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 67 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 68 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 69 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 70 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 71 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 72 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 73 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 74 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 75 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 76 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 77 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 78 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 79 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 80 & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.5 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 16.0 & 0.0 & 0.2 & 1.0 & NaN & NaN \\
# 81 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 82 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 83 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 84 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 85 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 86 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 87 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 88 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 89 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 90 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 91 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 92 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 93 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 94 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 95 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 96 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 97 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 98 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 99 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 100 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 101 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 102 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 103 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 104 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 105 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 106 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 107 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 108 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 109 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 110 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 111 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 112 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 113 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 114 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 115 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 116 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 117 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 118 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 119 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 120 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 121 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 122 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 123 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 124 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 125 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 126 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 127 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 128 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 129 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 130 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 131 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 132 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 133 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 134 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 135 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 136 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 137 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 138 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 139 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 140 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 141 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 142 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 143 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 144 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 145 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 146 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 147 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 148 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 149 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 150 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 151 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 152 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 153 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 154 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 155 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 156 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 157 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 158 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 159 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 160 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 161 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 162 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 163 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 164 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 165 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 166 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 167 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 168 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 169 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 170 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 171 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 172 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 173 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 174 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 175 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 176 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 177 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 178 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 179 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 180 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 181 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 182 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 183 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 184 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 185 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 186 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 187 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 188 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 189 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 190 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 191 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 192 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 193 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 194 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 195 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 196 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 197 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 198 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# 199 & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN & 1.0 & 0.0 & 0.0 & 1.0 & NaN & NaN \\
# \bottomrule
# \end{tabular}

# %%
resume_200_1 = pd.DataFrame()
resume_200_1 = pd.concat([resume_200_1, mip_internet_fmin_200_1.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_fmax_200_1.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_fminmisetn0_200_1.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_fmaxmisetn0_200_1.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_fminmiset_200_1.loc[200:200]], ignore_index=True)
resume_200_1 = pd.concat([resume_200_1, mip_internet_fminmisetn1_200_1.loc[200:200]], ignore_index=True)
resume_200_1
# Out:
#                  vertice      bb      bs  gap     time   nodes    opt     tk
# 0         mip_fmin_200_1  5092.0  5092.0  0.0   613.07  2350.0  200.0  149.0  \
# 1         mip_fmax_200_1  5092.0  5092.0  0.0   747.21  2260.0  200.0  149.0
# 2  mip_fminmisetn0_200_1  5092.0  5092.0  0.0   565.33   584.0  200.0  149.0
# 3  mip_fmaxmisetn0_200_1  5092.0  5092.0  0.0  1648.47   580.0  200.0  149.0
# 4    mip_fminmiset_200_1  3485.0  3485.0  0.0     1.44   714.0  200.0  116.0
# 5  mip_fminmisetn1_200_1  5092.0  5092.0  0.0   618.72   806.0  200.0  149.0
#
#     tmax
# 0  27.17
# 1  50.21
# 2  24.50
# 3  80.96
# 4   0.05
# 5  30.21

# %%
print(
resume_200_1[[
    'vertice','bs','gap','time','opt','tk','tmax',
    ]].to_latex(index=False,float_format="%.1f")
)
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# vertice & bs & gap & time & opt & tk & tmax \\
# \midrule
# mip_fmin_200_1 & 5092.0 & 0.0 & 613.1 & 200.0 & 149.0 & 27.2 \\
# mip_fmax_200_1 & 5092.0 & 0.0 & 747.2 & 200.0 & 149.0 & 50.2 \\
# mip_fminmisetn0_200_1 & 5092.0 & 0.0 & 565.3 & 200.0 & 149.0 & 24.5 \\
# mip_fmaxmisetn0_200_1 & 5092.0 & 0.0 & 1648.5 & 200.0 & 149.0 & 81.0 \\
# mip_fminmiset_200_1 & 3485.0 & 0.0 & 1.4 & 200.0 & 116.0 & 0.1 \\
# mip_fminmisetn1_200_1 & 5092.0 & 0.0 & 618.7 & 200.0 & 149.0 & 30.2 \\
# \bottomrule
# \end{tabular}
